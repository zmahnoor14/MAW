# %% [markdown]
# # Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
def isNaN(string):
    return string != string
import kaleido
import plotly.graph_objects as go
#Import libraries
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline
import plotly.io as pio

# %%
cl = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/MZML/MetabolomicsResults/Final_Candidate_List.csv")
class_data = cl[['superclass', 'class', 'subclass']]
class_data = class_data.dropna()

# %%
spclass = list(class_data['superclass']) # all superclasses
uniq_spclass = list(np.unique(list(class_data['superclass']))) # only unique super classes
#uniq_spc = [s for s in uniq_spclass if 'nan' not in s ] # only unique super classes with no NA values
len(uniq_spclass)
clss = list(class_data['class'])
uniq_class = list(np.unique(list(class_data['class'])))
#uniq_c = [s for s in uniq_class if 'nan' not in s ]
len(uniq_class)
sbclass = list(class_data['subclass'])
uniq_sbclass = list(np.unique(list(class_data['subclass'])))
#uniq_sbc = [s for s in uniq_sbclass if 'nan' not in s ]
len(uniq_sbclass)

#all characters
Names = ['Organic Compounds'] + uniq_spclass+uniq_class+uniq_sbclass

df = pd.DataFrame(Names)
df['values'] = ''
df['parents'] = ''

df = df.rename(columns={0: 'characters'})
df
# Out:
#                               characters values parents
# 0                      Organic Compounds
# 1              Alkaloids and derivatives
# 2                             Benzenoids
# 3                           Hydrocarbons
# 4        Lipids and lipid-like molecules
# ..                                   ...    ...     ...
# 167           Thiophosphoric acid esters
# 168                            Triazoles
# 169  Tricarboxylic acids and derivatives
# 170                   Triradylcglycerols
# 171                        Triterpenoids
#
# [172 rows x 3 columns]

# %%
for i, row in df.iterrows():
    if 'Organic Compounds' in df['characters'][i]:
        df.loc[i, 'values'] = 0
        df.loc[i, 'parents'] = ''
        
    elif df['characters'][i] in uniq_spclass:
        
        df.loc[i, 'values'] = spclass.count(df['characters'][i])
        df.loc[i, 'parents'] = 'Organic Compounds'
        
    elif df['characters'][i] in uniq_class:
        
        df.loc[i, 'values'] = clss.count(df['characters'][i])
        df.loc[i, 'parents'] = 'Organic Compounds'
        
        df.loc[i, 'values'] = clss.count(df['characters'][i])
        clsp = class_data['superclass'][class_data[class_data['class'] == df['characters'][i]].index.tolist()[0]]
        df.loc[i, 'parents'] = clsp
        
        
    elif df['characters'][i] in uniq_sbclass:
        df.loc[i, 'values'] = sbclass.count(df['characters'][i])
        sbclsp = class_data['class'][class_data[class_data['subclass'] == df['characters'][i]].index.tolist()[0]]
        df.loc[i, 'parents'] = sbclsp

# %%
data = dict(character = df['characters'], parents = df['parents'], values = df['values'])

# %%
fig = px.sunburst(
    data,
    names='character',
    parents='parents',
    values='values',
)
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
fig.show()
# Out:
# <div>                            <div id="99158a33-2ffb-407b-9d0a-da2a54c7a83f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99158a33-2ffb-407b-9d0a-da2a54c7a83f")) {                    Plotly.newPlot(                        "99158a33-2ffb-407b-9d0a-da2a54c7a83f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"character=%{label}<br>value=%{value}<br>parent=%{parent}<extra></extra>","labels":["Organic Compounds","Alkaloids and derivatives","Benzenoids","Hydrocarbons","Lipids and lipid-like molecules","Nucleosides, nucleotides, and analogues","Organic 1,3-dipolar compounds","Organic acids and derivatives","Organic nitrogen compounds","Organic oxygen compounds","Organohalogen compounds","Organoheterocyclic compounds","Organosulfur compounds","Phenylpropanoids and polyketides","5'-deoxyribonucleosides","Acyl halides","Allyl-type 1,3-dipolar organic compounds","Anthracenes","Azoles","Benzene and substituted derivatives","Benzofurans","Benzophenanthridine alkaloids","Benzopyrans","Benzothiazines","Carboximidic acids and derivatives","Carboxylic acids and derivatives","Cinnamic acids and derivatives","Coumarins and derivatives","Diazinanes","Diazines","Ergoline and derivatives","Fatty Acyls","Flavonoids","Glycerolipids","Glycerophospholipids","Hydroxy acids and derivatives","Imidazopyrimidines","Indoles and derivatives","Isocoumarans","Isoindoles and derivatives","Keto acids and derivatives","Lupin alkaloids","Organic phosphonic acids and derivatives","Organic phosphoric acids and derivatives","Organic sulfonic acids and derivatives","Organic sulfuric acids and derivatives","Organic thiophosphoric acids and derivatives","Organonitrogen compounds","Organooxygen compounds","Oxazinanes","Peptidomimetics","Phenol ethers","Phenols","Piperidines","Prenol lipids","Pyrans","Pyridines and derivatives","Pyrimidine nucleotides","Pyrroles","Pyrrolidines","Sphingolipids","Steroids and steroid derivatives","Sulfonyls","Tetrapyrroles and derivatives","Thiohydroximic acids and derivatives","Thiophenes","Unsaturated hydrocarbons","1-benzopyrans","1-hydroxy-2-unsubstituted benzenoids","1-hydroxy-4-unsubstituted benzenoids","5'-deoxy-5'-thionucleosides","Acyl bromides","Alcohols and polyols","Alpha-keto acids and derivatives","Amines","Amino acids, peptides, and analogues","Anisoles","Anthraquinones","Benzenediols","Benzenesulfonamides","Benzenesulfonic acids and derivatives","Benzofuranones","Benzoic acids and derivatives","Benzoyl derivatives","Beta hydroxy acids and derivatives","Bile acids, alcohols and derivatives","Branched unsaturated hydrocarbons","Carbohydrates and carbohydrate conjugates","Carbonyl compounds","Carboximidic acids","Carboxylic acid derivatives","Carboxylic acids","Chlorins","Cinnamic acid amides","Depsipeptides","Dicarboxylic acids and derivatives","Diradylglycerols","Diterpenoids","Ethers","Fatty acid esters","Fatty acids and conjugates","Fatty acyl glycosides","Fatty alcohols","Fatty amides","Flavans","Flavones","Flavonoid glycosides","Glycerophosphates","Glycerophosphocholines","Glycerophosphoethanolamines","Glycerophosphoglycerols","Glycerophosphoinositols","Glycosphingolipids","Glycosylglycerols","Guanidines","Halopyridines","Hexahydrobenzophenanthridine alkaloids","Hydroxycoumarins","Hydroxysteroids","Imidazoles","Indoles","Indolyl carboxylic acids and derivatives","Isobenzofuranones","Isoindolines","Lineolic acids and derivatives","Lysergic acids and derivatives","Matrine alkaloids","Medium-chain hydroxy acids and derivatives","Methoxyphenols","Monocarboxylic acids and derivatives","Monoradylglycerols","Monoterpenoids","Morpholines","N-acylpyrrolidines","Nitrobenzenes","Organic nitro compounds","Organic phosphonic acids","Organosulfonic acids and der ...

# %%
fig.write_image("Sunburst_Chart.png")

# %%
### for Suspect List

# %%
sl = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/SuspectList/Use_This_CURATED_SUSPECT_LIST_with_classes_noDups.csv")
class_data = sl[['superclass', 'class', 'subclass']]
class_data = class_data.dropna()

# %%
spclass = list(class_data['superclass']) # all superclasses
uniq_spclass = list(np.unique(list(class_data['superclass']))) # only unique super classes
#uniq_spc = [s for s in uniq_spclass if 'nan' not in s ] # only unique super classes with no NA values
len(uniq_spclass)
clss = list(class_data['class'])
uniq_class = list(np.unique(list(class_data['class'])))
#uniq_c = [s for s in uniq_class if 'nan' not in s ]
len(uniq_class)
sbclass = list(class_data['subclass'])
uniq_sbclass = list(np.unique(list(class_data['subclass'])))
#uniq_sbc = [s for s in uniq_sbclass if 'nan' not in s ]
len(uniq_sbclass)

#all characters
Names = ['Organic Compounds'] + uniq_spclass+uniq_class+uniq_sbclass

df = pd.DataFrame(Names)
df['values'] = ''
df['parents'] = ''

df = df.rename(columns={0: 'characters'})
df
# Out:
#                                     characters values parents
# 0                            Organic Compounds
# 1                                   Benzenoids
# 2              Homogeneous non-metal compounds
# 3                                 Hydrocarbons
# 4    Lignans, neolignans and related compounds
# ..                                         ...    ...     ...
# 157                                   Toluenes
# 158        Tricarboxylic acids and derivatives
# 159                              Triterpenoids
# 160                Tryptamines and derivatives
# 161                                      Ureas
#
# [162 rows x 3 columns]

# %%
for i, row in df.iterrows():
    if 'Organic Compounds' in df['characters'][i]:
        df.loc[i, 'values'] = 0
        df.loc[i, 'parents'] = ''
        
    elif df['characters'][i] in uniq_spclass:
        
        df.loc[i, 'values'] = spclass.count(df['characters'][i])
        df.loc[i, 'parents'] = 'Organic Compounds'
        
    elif df['characters'][i] in uniq_class:
        
        df.loc[i, 'values'] = clss.count(df['characters'][i])
        df.loc[i, 'parents'] = 'Organic Compounds'
        
        df.loc[i, 'values'] = clss.count(df['characters'][i])
        clsp = class_data['superclass'][class_data[class_data['class'] == df['characters'][i]].index.tolist()[0]]
        df.loc[i, 'parents'] = clsp
        
        
    elif df['characters'][i] in uniq_sbclass:
        df.loc[i, 'values'] = sbclass.count(df['characters'][i])
        sbclsp = class_data['class'][class_data[class_data['subclass'] == df['characters'][i]].index.tolist()[0]]
        df.loc[i, 'parents'] = sbclsp

# %%
data = dict(character = df['characters'], parents = df['parents'], values = df['values'])

# %%
fig = px.sunburst(
    data,
    names='character',
    parents='parents',
    values='values',
)
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
fig.show()
# Out:
# <div>                            <div id="8fb0c26e-f501-433a-ad3e-dc80fe5cc628" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fb0c26e-f501-433a-ad3e-dc80fe5cc628")) {                    Plotly.newPlot(                        "8fb0c26e-f501-433a-ad3e-dc80fe5cc628",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"character=%{label}<br>value=%{value}<br>parent=%{parent}<extra></extra>","labels":["Organic Compounds","Benzenoids","Homogeneous non-metal compounds","Hydrocarbons","Lignans, neolignans and related compounds","Lipids and lipid-like molecules","Nucleosides, nucleotides, and analogues","Organic acids and derivatives","Organic nitrogen compounds","Organic oxygen compounds","Organoheterocyclic compounds","Phenylpropanoids and polyketides","5'-deoxyribonucleosides","Azoles","Benzene and substituted derivatives","Benzoxazines","Carboximidic acids and derivatives","Carboxylic acids and derivatives","Cinnamic acids and derivatives","Coumarins and derivatives","Diazinanes","Diazines","Dibenzylbutane lignans","Dihydrofurans","Epoxides","Fatty Acyls","Flavonoids","Furanoid lignans","Furans","Furofurans","Glycerolipids","Hydroxy acids and derivatives","Indoles and derivatives","Isoquinolines and derivatives","Keto acids and derivatives","Lactones","Non-metal oxoanionic compounds","Organic carbonic acids and derivatives","Organic oxoanionic compounds","Organic phosphoric acids and derivatives","Organic sulfonic acids and derivatives","Organonitrogen compounds","Organooxygen compounds","Other non-metal organides","Phenol ethers","Phenols","Prenol lipids","Pteridines and derivatives","Purine nucleosides","Purine nucleotides","Pyrans","Pyridines and derivatives","Pyrimidine nucleosides","Pyrimidine nucleotides","Pyrrolopyrimidines","Quinolines and derivatives","Steroids and steroid derivatives","Tetrapyrroles and derivatives","Thiohydroximic acids and derivatives","Unsaturated hydrocarbons","1-hydroxy-2-unsubstituted benzenoids","5'-deoxy-5'-thionucleosides","Alcohols and polyols","Alloxazines and isoalloxazines","Alpha hydroxy acids and derivatives","Alpha-keto acids and derivatives","Amines","Amino acids, peptides, and analogues","Aminoxides","Anilides","Aniline and substituted anilines","Anisoles","Benzenediols","Benzoic acids and derivatives","Benzylisoquinolines","Beta hydroxy acids and derivatives","Bilirubins","Carbohydrates and carbohydrate conjugates","Carbonyl compounds","Carboximidic acids","Carboxylic acids","Chlorins","Cholestane steroids","Cinnamic acids","Corrinoids","Coumarin glycosides","Cresols","Cyanates","Cyclic purine nucleotides","Dibenzylbutanediol lignans","Dicarboxylic acids and derivatives","Diterpenoids","Eicosanoids","Fatty acids and conjugates","Fatty acyl glycosides","Fatty acyl thioesters","Fatty alcohols","Flavones","Flavonoid glycosides","Furanones","Furoic acid and derivatives","Gamma butyrolactones","Gamma-keto acids and derivatives","Glycosylglycerols","Halobenzenes","Hydroxycinnamic acids and derivatives","Hydroxycoumarins","Hydroxyindoles","Indolecarboxylic acids and derivatives","Indoles","Indolines","Indolyl carboxylic acids and derivatives","Isosorbides","Lineolic acids and derivatives","Medium-chain hydroxy acids and derivatives","Medium-chain keto acids and derivatives","Metallotetrapyrroles","Methoxybenzenes","Methoxyphenols","Monoradylglycerols","Non-metal phosphates","Non-metal pyrophosphates","Olefins","Organic pyrophosphates","Organosulfonic acids and derivatives","Other non-metal nitrides","Oxirane carboxylic acids and derivatives","Phenethylamines","Phenoxazines","Phenylacetaldehydes","Phosphate esters","Piperazines","Porphyrins","Pterins and derivatives","Purine 2'-deoxyribonucleosides","Purine nucleotide sugars","P ...

# %% [markdown]
# ## Venn Diagram

# %%
cl = pd.read_csv("Candidate_list.csv")
cl.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id_X', 'premz', 'rtmed', 'int',
#        'col_eng', 'pol', 'Formula', 'MCSS_SMILES', 'most_specific_class',
#        'level _5', 'subclass', 'class', 'superclass', 'all_classifications',
#        'KG_MCSS_SMILES', 'PC_MCSS_SMILES', 'Annotation_Source', 'SMILES_final',
#        'Classification_Source', 'Molecular_mass', 'Name', 'Occurence'],
#       dtype='object')

# %%
sl = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/SuspectList/Use_This_CURATED_SUSPECT_LIST_with_classes_noDups.csv")
sl
# Out:
#      Unnamed: 0                                               Name  \
# 0             1                           N-Acetyl-L-glutamic acid
# 1             2                                     Threonic acid
# 2             3                                       L-citrulline
# 3             5                                       DL-HISTIDINE
# 4             6                                         DL-Leucine
# ..          ...                                                ...
# 898         948                            (2E,4Z)-octa-2,4-dienal
# 899         949                                                NaN
# 900         950  cobalt(2+);3-[7,13,17-tris(2-carboxyethyl)-3,8...
# 901         951  7,8-dimethyl-4-oxo-10-(2,3,4,5-tetrahydroxypen...
# 902         952  6,7-dimethyl-4-oxo-8-(2,3,4,5-tetrahydroxypent...
#
#            Formula      Species  \
# 0         C7H11NO5   S. marinoi
# 1           C4H8O5   S. marinoi
# 2        C6H13N3O3  S. costatum
# 3         C6H9N3O2  S. costatum
# 4         C6H13NO2  S. costatum
# ..             ...          ...
# 898         C8H12O  S .costatum
# 899       C40H56O5  S .costatum
# 900  C42H44CoN4O16  S .costatum
# 901    C17H19N4O6-  S .costatum
# 902    C13H17N4O6-  S .costatum
#
#                                                 SMILES  \
# 0                        CC(=O)N[C@@H](CCC(=O)O)C(=O)O
# 1                                   C(C(C(C(=O)O)O)O)O
# 2                          C(C[C@@H](C(=O)O)N)CNC(=O)N
# 3                                NC(Cc1c[nH]cn1)C(O)=O
# 4                                     CC(C)CC(N)C(O)=O
# ..                                                 ...
# 898                                    CCC/C=C\C=C\C=O
# 899  CC(=CC=CC=C(C)C=CC=C(C)C(=O)CC12C(CC(CC1(O2)C)...
# 900  CC1(C(C2=NC1=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(=C...
# 901  CC1=CC2=C(C=C1C)N(C3=NC(=NC(=O)C3=N2)[O-])CC(C...
# 902  CC1=C(N(C2=NC(=NC(=O)C2=N1)[O-])CC(C(C(CO)O)O)O)C
#
#                                                  InChI  Monoisotopic_mass  \
# 0    InChI=1S/C7H11NO5/c1-4(9)8-5(7(12)13)2-3-6(10)...         189.063722
# 1    InChI=1S/C4H8O5/c5-1-2(6)3(7)4(8)9/h2-3,5-7H,1...         136.037173
# 2    InChI=1S/C6H13N3O3/c7-4(5(10)11)2-1-3-9-6(8)12...         175.095691
# 3    InChI=1S/C6H9N3O2/c7-5(6(10)11)1-4-2-8-3-9-4/h...         155.069477
# 4    InChI=1S/C6H13NO2/c1-4(2)3-5(7)6(8)9/h4-5H,3,7...         131.094629
# ..                                                 ...                ...
# 898  InChI=1S/C8H12O/c1-2-3-4-5-6-7-8-9/h4-8H,2-3H2...         124.088815
# 899  InChI=1S/C40H56O5/c1-28(17-13-18-30(3)21-22-35...         616.412775
# 900  InChI=1S/C42H46N4O16.Co/c1-41(17-39(59)60)23(5...         919.208425
# 901  InChI=1S/C17H20N4O6/c1-7-3-9-10(4-8(7)2)21(5-1...         375.130459
# 902  InChI=1S/C13H18N4O6/c1-5-6(2)17(3-7(19)10(21)8...         325.114809
#
#          ChEBIid  KEGGid   PubChemId  ...  \
# 0    CHEBI:44337  C00624     70914.0  ...
# 1    CHEBI:26984     NaN    439535.0  ...
# 2    CHEBI:16349  C00327      9750.0  ...
# 3    CHEBI:27570     NaN       773.0  ...
# 4    CHEBI:25017     NaN       857.0  ...
# ..           ...     ...         ...  ...
# 898          NaN     NaN   5352875.0  ...
# 899          NaN     NaN    607588.0  ...
# 900          NaN     NaN  75144734.0  ...
# 901          NaN     NaN    122171.0  ...
# 902          NaN     NaN  25244683.0  ...
#
#                                                 Source  \
# 0    Vidoudez C, Pohnert G. Comparative metabolomic...
# 1    Vidoudez C, Pohnert G. Comparative metabolomic...
# 2    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# 3    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# 4    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# ..                                                 ...
# 898                                                NaN
# 899                                                NaN
# 900                                                NaN
# 901                                                NaN
# 902                                                NaN
#
#     nonIsomeric_SMILES_byRDKit  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 898                        NaN
# 899                        NaN
# 900                        NaN
# 901                        NaN
# 902                        NaN
#
#                                                  iupac  \
# 0                    (2S)-2-acetamidopentanedioic acid
# 1                        2,3,4-trihydroxybutanoic acid
# 2        (2S)-2-amino-5-(carbamoylamino)pentanoic acid
# 3           2-amino-3-(1H-imidazol-5-yl)propanoic acid
# 4                       2-amino-4-methylpentanoic acid
# ..                                                 ...
# 898                            (2E,4Z)-octa-2,4-dienal
# 899                                                NaN
# 900  cobalt(2+);3-[7,13,17-tris(2-carboxyethyl)-3,8...
# 901  7,8-dimethyl-4-oxo-10-(2,3,4,5-tetrahydroxypen...
# 902  6,7-dimethyl-4-oxo-8-(2,3,4,5-tetrahydroxypent...
#
#                                               synonyms  \
# 0    ['N-Acetyl-L-glutamic acid', '1188-37-0', 'ace...
# 1                                                  NaN
# 2    ['L-citrulline', 'citrulline', '372-75-8', 'H-...
# 3    ['DL-HISTIDINE', '4998-57-6', 'H-DL-His-OH', '...
# 4    ['DL-Leucine', '328-39-2', 'H-DL-Leu-OH', '2-A...
# ..                                                 ...
# 898  ['2E,4Z-Octadienal', '2,4-Octadienal, (E,Z)-',...
# 899                                                 []
# 900                                                 []
# 901  ['Fad semiquinone', '35919-91-6', '7,8-dimethy...
# 902                                                 []
#
#                             PubChemPY correct_Name Molecular mass  \
# 0                   checked; NEW name          NaN         189.17
# 1            checked; structure added          NaN         136.10
# 2                   checked; NEW name          NaN         175.19
# 3                   checked; NEW name          NaN         155.15
# 4                   checked; NEW name          NaN         131.17
# ..                                ...          ...            ...
# 898              added with PubChemPY          NaN         124.18
# 899  KekulizedSMILES with a PubChemid          NaN         616.90
# 900  KekulizedSMILES with a PubChemid          NaN         919.70
# 901  KekulizedSMILES with a PubChemid          NaN         375.40
# 902  KekulizedSMILES with a PubChemid          NaN         325.30
#
#                                       subclass  \
# 0         Amino acids, peptides, and analogues
# 1    Carbohydrates and carbohydrate conjugates
# 2         Amino acids, peptides, and analogues
# 3         Amino acids, peptides, and analogues
# 4         Amino acids, peptides, and analogues
# ..                                         ...
# 898                         Carbonyl compounds
# 899                            Tetraterpenoids
# 900                                        NaN
# 901             Alloxazines and isoalloxazines
# 902                                        NaN
#
#                                 class                       superclass
# 0    Carboxylic acids and derivatives    Organic acids and derivatives
# 1              Organooxygen compounds         Organic oxygen compounds
# 2    Carboxylic acids and derivatives    Organic acids and derivatives
# 3    Carboxylic acids and derivatives    Organic acids and derivatives
# 4    Carboxylic acids and derivatives    Organic acids and derivatives
# ..                                ...                              ...
# 898            Organooxygen compounds         Organic oxygen compounds
# 899                     Prenol lipids  Lipids and lipid-like molecules
# 900                               NaN                              NaN
# 901        Pteridines and derivatives     Organoheterocyclic compounds
# 902                               NaN                              NaN
#
# [903 rows x 21 columns]

# %%
LS22 = cl.loc[-isNaN(cl['SMILES_final'])]

# %%
cl.loc[cl['SMILES_final'] == 'S']

# %%
# only in SIRIUS_formula
ls2 = list(LS22['Annotation_Source'])
len([x for x in ls2 if 'SuspectList' in x])
# Out:
# 105

# %%
venn2(subsets = (903, 771, 28), set_labels = ('Suspect List', 'Metabolomics Data'), set_colors=('skyblue', 'lightgreen'), alpha = 0.7);

# %%
venn2(subsets = (102, 105, 44), set_labels = ('Suspect List Subclasses', 'Metabolomics Data Subclasses'), set_colors=('pink', 'yellow'), alpha = 0.7);

# %%
venn2(subsets = (62, 75, 35), set_labels = ('Suspect List Classes', 'Metabolomics Data Classes'), set_colors=('pink', 'yellow'), alpha = 0.7);

# %%
venn2(subsets = (12, 16, 10), set_labels = ('Suspect List Superclasses', 'Metabolomics Data Superclasses'), set_colors=('pink', 'yellow'), alpha = 0.7);

# %% [markdown]
# # Statistics

# %%
import pandas as pd
import numpy as np

# %%
#all results
results = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/MZML/MetabolomicsResults/Final_Candidate_List.csv")
results
# Out:
#       Unnamed: 0.1  Unnamed: 0          id_X       premz       rtmed  \
# 0                0           0   M185R138ID1  185.021500  138.437646
# 1                1           1   M259R133ID2  259.057556  133.058433
# 2                3           3   M143R152ID4  142.997726  152.119794
# 3                5           5   M227R156ID6  226.995239  156.163704
# 4                6           6    M99R156ID7   99.008179  156.366516
# ...            ...         ...           ...         ...         ...
# 1618          1848        1848  M145R349ID69  145.097107  349.070949
# 1619          1849        1849  M143R366ID70  143.081360  366.229470
# 1620          1850        1850  M338R389ID71  337.969147  389.379822
# 1621          1851        1851  M265R391ID72  265.015442  390.517248
# 1622          1854        1854  M215R401ID75  214.917496  401.357670
#
#                int  col_eng  pol     Formula  \
# 0     0.000000e+00       30  neg    C6H6N2O5
# 1     0.000000e+00       30  neg   C9H12N2O7
# 2     0.000000e+00       30  neg      C5H4O5
# 3     0.000000e+00       30  neg  C6H13O3PS2
# 4     0.000000e+00       30  neg      C4H4O3
# ...            ...      ...  ...         ...
# 1618  1.241231e+08       30  pos   C6H12N2O2
# 1619  1.562070e+07       30  pos         NaN
# 1620  1.448262e+07       30  pos   C9H5N3O8S
# 1621  1.642149e+08       30  pos         NaN
# 1622  2.277173e+07       30  pos    C5H5OPS2
#
#                                 MCSS_SMILES  ...                     level _5  \
# 0                               C:C:C(:N)CO  ...  Amino acids and derivatives
# 1     O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1  ...           Glycosyl compounds
# 2                                       NaN  ...                          NaN
# 3                                       OPO  ...       Carboxylic acid esters
# 4                                  CCC(=O)O  ...                      Ketones
# ...                                     ...  ...                          ...
# 1618                                 CCNCCN  ...  Amino acids and derivatives
# 1619                                    NaN  ...                          NaN
# 1620                                 CCCCCC  ...                          NaN
# 1621                                    NaN  ...                          NaN
# 1622                                    NaN  ...                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 2                                           NaN
# 3                   Carboxylic acid derivatives
# 4                            Carbonyl compounds
# ...                                         ...
# 1618       Amino acids, peptides, and analogues
# 1619                                        NaN
# 1620                              Nitrobenzenes
# 1621       Bile acids, alcohols and derivatives
# 1622                                        NaN
#
#                                     class                       superclass  \
# 0        Carboxylic acids and derivatives    Organic acids and derivatives
# 1                  Organooxygen compounds         Organic oxygen compounds
# 2                                     NaN                              NaN
# 3        Carboxylic acids and derivatives    Organic acids and derivatives
# 4                  Organooxygen compounds         Organic oxygen compounds
# ...                                   ...                              ...
# 1618     Carboxylic acids and derivatives    Organic acids and derivatives
# 1619                                  NaN                              NaN
# 1620  Benzene and substituted derivatives                       Benzenoids
# 1621     Steroids and steroid derivatives  Lipids and lipid-like molecules
# 1622                                  NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 2                                                   NaN            NaN
# 3     Organic compounds; Organic acids and derivativ...            NaN
# 4     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1618  Organic compounds; Organoheterocyclic compound...            NaN
# 1619                                                NaN            NaN
# 1620  Organic compounds; Organoheterocyclic compound...            NaN
# 1621                                                NaN            NaN
# 1622                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 0               NaN    SIRIUS_Formula
# 1               NaN    SIRIUS_Formula
# 2               NaN    SIRIUS_Formula
# 3               NaN    SIRIUS_Formula
# 4               NaN    SIRIUS_Formula
# ...             ...               ...
# 1618            NaN            SIRIUS
# 1619       CCC(=O)O           PubChem
# 1620            NaN            SIRIUS
# 1621            NaN              GNPS
# 1622            NaN    SIRIUS_Formula
#
#                                            SMILES_final Classification_Source
# 0                                                   NaN               CANOPUS
# 1                                                   NaN               CANOPUS
# 2                                                   NaN                   NaN
# 3                                                   NaN               CANOPUS
# 4                                                   NaN               CANOPUS
# ...                                                 ...                   ...
# 1618                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1619                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1620  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1621  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
# 1622                                                NaN                   NaN
#
# [1623 rows x 21 columns]

# %%
#remove duplicates based on features
resultsmzrt = results.drop_duplicates(['premz', 'rtmed'],keep= 'last')
resultsmzrt
# Out:
#       Unnamed: 0.1  Unnamed: 0          id_X       premz       rtmed  \
# 0                0           0   M185R138ID1  185.021500  138.437646
# 1                1           1   M259R133ID2  259.057556  133.058433
# 2                3           3   M143R152ID4  142.997726  152.119794
# 3                5           5   M227R156ID6  226.995239  156.163704
# 4                6           6    M99R156ID7   99.008179  156.366516
# ...            ...         ...           ...         ...         ...
# 1618          1848        1848  M145R349ID69  145.097107  349.070949
# 1619          1849        1849  M143R366ID70  143.081360  366.229470
# 1620          1850        1850  M338R389ID71  337.969147  389.379822
# 1621          1851        1851  M265R391ID72  265.015442  390.517248
# 1622          1854        1854  M215R401ID75  214.917496  401.357670
#
#                int  col_eng  pol     Formula  \
# 0     0.000000e+00       30  neg    C6H6N2O5
# 1     0.000000e+00       30  neg   C9H12N2O7
# 2     0.000000e+00       30  neg      C5H4O5
# 3     0.000000e+00       30  neg  C6H13O3PS2
# 4     0.000000e+00       30  neg      C4H4O3
# ...            ...      ...  ...         ...
# 1618  1.241231e+08       30  pos   C6H12N2O2
# 1619  1.562070e+07       30  pos         NaN
# 1620  1.448262e+07       30  pos   C9H5N3O8S
# 1621  1.642149e+08       30  pos         NaN
# 1622  2.277173e+07       30  pos    C5H5OPS2
#
#                                 MCSS_SMILES  ...                     level _5  \
# 0                               C:C:C(:N)CO  ...  Amino acids and derivatives
# 1     O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1  ...           Glycosyl compounds
# 2                                       NaN  ...                          NaN
# 3                                       OPO  ...       Carboxylic acid esters
# 4                                  CCC(=O)O  ...                      Ketones
# ...                                     ...  ...                          ...
# 1618                                 CCNCCN  ...  Amino acids and derivatives
# 1619                                    NaN  ...                          NaN
# 1620                                 CCCCCC  ...                          NaN
# 1621                                    NaN  ...                          NaN
# 1622                                    NaN  ...                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 2                                           NaN
# 3                   Carboxylic acid derivatives
# 4                            Carbonyl compounds
# ...                                         ...
# 1618       Amino acids, peptides, and analogues
# 1619                                        NaN
# 1620                              Nitrobenzenes
# 1621       Bile acids, alcohols and derivatives
# 1622                                        NaN
#
#                                     class                       superclass  \
# 0        Carboxylic acids and derivatives    Organic acids and derivatives
# 1                  Organooxygen compounds         Organic oxygen compounds
# 2                                     NaN                              NaN
# 3        Carboxylic acids and derivatives    Organic acids and derivatives
# 4                  Organooxygen compounds         Organic oxygen compounds
# ...                                   ...                              ...
# 1618     Carboxylic acids and derivatives    Organic acids and derivatives
# 1619                                  NaN                              NaN
# 1620  Benzene and substituted derivatives                       Benzenoids
# 1621     Steroids and steroid derivatives  Lipids and lipid-like molecules
# 1622                                  NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 2                                                   NaN            NaN
# 3     Organic compounds; Organic acids and derivativ...            NaN
# 4     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1618  Organic compounds; Organoheterocyclic compound...            NaN
# 1619                                                NaN            NaN
# 1620  Organic compounds; Organoheterocyclic compound...            NaN
# 1621                                                NaN            NaN
# 1622                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 0               NaN    SIRIUS_Formula
# 1               NaN    SIRIUS_Formula
# 2               NaN    SIRIUS_Formula
# 3               NaN    SIRIUS_Formula
# 4               NaN    SIRIUS_Formula
# ...             ...               ...
# 1618            NaN            SIRIUS
# 1619       CCC(=O)O           PubChem
# 1620            NaN            SIRIUS
# 1621            NaN              GNPS
# 1622            NaN    SIRIUS_Formula
#
#                                            SMILES_final Classification_Source
# 0                                                   NaN               CANOPUS
# 1                                                   NaN               CANOPUS
# 2                                                   NaN                   NaN
# 3                                                   NaN               CANOPUS
# 4                                                   NaN               CANOPUS
# ...                                                 ...                   ...
# 1618                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1619                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1620  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1621  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
# 1622                                                NaN                   NaN
#
# [1622 rows x 21 columns]

# %%
resultsmzrt[resultsmzrt['pol'] == 'pos']
resultsmzrt[resultsmzrt['pol'] == 'neg']
# Out:
#       Unnamed: 0.1  Unnamed: 0          id_X       premz       rtmed  \
# 0                0           0   M185R138ID1  185.021500  138.437646
# 1                1           1   M259R133ID2  259.057556  133.058433
# 2                3           3   M143R152ID4  142.997726  152.119794
# 3                5           5   M227R156ID6  226.995239  156.163704
# 4                6           6    M99R156ID7   99.008179  156.366516
# ...            ...         ...           ...         ...         ...
# 1327          1091        1091  M237R104ID55  236.929657  103.991940
# 1328          1096        1096  M377R133ID60  377.085876  133.081638
# 1329          1098        1098  M330R170ID62  330.050293  169.801956
# 1330          1099        1099  M213R192ID63  213.049484  191.577429
# 1331          1102        1102  M255R323ID66  254.916870  322.500675
#
#                int  col_eng  pol     Formula  \
# 0     0.000000e+00       30  neg    C6H6N2O5
# 1     0.000000e+00       30  neg   C9H12N2O7
# 2     0.000000e+00       30  neg      C5H4O5
# 3     0.000000e+00       30  neg  C6H13O3PS2
# 4     0.000000e+00       30  neg      C4H4O3
# ...            ...      ...  ...         ...
# 1327  5.750620e+06       30  neg   C2H7O7PS2
# 1328  3.523510e+07       30  neg  C11H23O12P
# 1329  8.702480e+06       30  neg  C9H17NO10S
# 1330  9.737681e+06       30  neg   C8H10N2O5
# 1331  1.036818e+06       30  neg         NaN
#
#                                 MCSS_SMILES  ...  \
# 0                               C:C:C(:N)CO  ...
# 1     O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1  ...
# 2                                       NaN  ...
# 3                                       OPO  ...
# 4                                  CCC(=O)O  ...
# ...                                     ...  ...
# 1327                                    NaN  ...
# 1328                                  CCCCC  ...
# 1329                C:C(:C(N):C:C:CN)N(=O)O  ...
# 1330                              CCC(=O)NC  ...
# 1331                                    NaN  ...
#
#                                   level _5  \
# 0              Amino acids and derivatives
# 1                       Glycosyl compounds
# 2                                      NaN
# 3                   Carboxylic acid esters
# 4                                  Ketones
# ...                                    ...
# 1327  Alkanesulfonic acids and derivatives
# 1328                                   NaN
# 1329           Sugar acids and derivatives
# 1330                              Peptides
# 1331                                   NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 2                                           NaN
# 3                   Carboxylic acid derivatives
# 4                            Carbonyl compounds
# ...                                         ...
# 1327       Organosulfonic acids and derivatives
# 1328                      Fatty acyl glycosides
# 1329  Carbohydrates and carbohydrate conjugates
# 1330       Amino acids, peptides, and analogues
# 1331                                        NaN
#
#                                        class                       superclass  \
# 0           Carboxylic acids and derivatives    Organic acids and derivatives
# 1                     Organooxygen compounds         Organic oxygen compounds
# 2                                        NaN                              NaN
# 3           Carboxylic acids and derivatives    Organic acids and derivatives
# 4                     Organooxygen compounds         Organic oxygen compounds
# ...                                      ...                              ...
# 1327  Organic sulfonic acids and derivatives    Organic acids and derivatives
# 1328                             Fatty Acyls  Lipids and lipid-like molecules
# 1329                  Organooxygen compounds         Organic oxygen compounds
# 1330        Carboxylic acids and derivatives    Organic acids and derivatives
# 1331                                     NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 2                                                   NaN            NaN
# 3     Organic compounds; Organic acids and derivativ...            NaN
# 4     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1327  Organic compounds; Organosulfur compounds; Org...            NaN
# 1328                                                NaN            NaN
# 1329  Organic compounds; Organoheterocyclic compound...            NaN
# 1330  Organic compounds; Organoheterocyclic compound...            NaN
# 1331                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 0               NaN    SIRIUS_Formula
# 1               NaN    SIRIUS_Formula
# 2               NaN    SIRIUS_Formula
# 3               NaN    SIRIUS_Formula
# 4               NaN    SIRIUS_Formula
# ...             ...               ...
# 1327            NaN            SIRIUS
# 1328            NaN            SIRIUS
# 1329            NaN            SIRIUS
# 1330            NaN            SIRIUS
# 1331            CCC           PubChem
#
#                                         SMILES_final Classification_Source
# 0                                                NaN               CANOPUS
# 1                                                NaN               CANOPUS
# 2                                                NaN                   NaN
# 3                                                NaN               CANOPUS
# 4                                                NaN               CANOPUS
# ...                                              ...                   ...
# 1327                      CS(=O)(=O)OP(O)OS(=O)(=O)C               CANOPUS
# 1328   CC1C(C(C(C(O1)OC(COP(=O)(O)O)C(C(CO)O)O)O)O)O            ClassyFire
# 1329  C(C1C(C(C(C(O1)(C(=O)C(CS(=O)(=O)O)N)O)O)O)O)O               CANOPUS
# 1330                 C1C(=O)N(C1=O)C(CCC(=O)N)C(=O)O               CANOPUS
# 1331          C1=CC(C(N=C1)(S(=O)(=O)Cl)Cl)C(=O)[O-]            ClassyFire
#
# [737 rows x 21 columns]

# %%
# only take entries with some SMILES Entry
resultsmzrt2 = resultsmzrt[-resultsmzrt['SMILES_final'].isna()]
resultsmzrt2
# Out:
#       Unnamed: 0.1  Unnamed: 0          id_X       premz       rtmed  \
# 851              4           4   M173R153ID5  173.008163  152.503416
# 852              8           8   M173R158ID9  173.055679  157.904502
# 853              9           9  M498R160ID10  498.259705  160.214106
# 854             11          11  M861R186ID12  860.502197  186.021606
# 855             12          12  M863R190ID13  862.502380  189.772890
# ...            ...         ...           ...         ...         ...
# 1617          1847        1847  M179R328ID68  179.035263  328.295220
# 1618          1848        1848  M145R349ID69  145.097107  349.070949
# 1619          1849        1849  M143R366ID70  143.081360  366.229470
# 1620          1850        1850  M338R389ID71  337.969147  389.379822
# 1621          1851        1851  M265R391ID72  265.015442  390.517248
#
#                int  col_eng  pol      Formula  \
# 851   0.000000e+00       30  neg          NaN
# 852   0.000000e+00       30  neg    C6H10N2O4
# 853   0.000000e+00       30  neg   C25H42NO7P
# 854   0.000000e+00       30  neg  C44H71N5O12
# 855   0.000000e+00       30  neg  C45H69N9O6S
# ...            ...      ...  ...          ...
# 1617  4.067382e+06       30  pos     C6H9N2OP
# 1618  1.241231e+08       30  pos    C6H12N2O2
# 1619  1.562070e+07       30  pos          NaN
# 1620  1.448262e+07       30  pos    C9H5N3O8S
# 1621  1.642149e+08       30  pos          NaN
#
#                                    MCSS_SMILES  ...  \
# 851                                        NaN  ...
# 852                                CC(=O)NCC=O  ...
# 853                    CCC=CCC=CCC=CCC=CCC=CCC  ...
# 854   C:CCC(NC(=O)CCC(:C):C:C:C:C)C(=O)NC(C)CC  ...
# 855                                  CCCCCCCCC  ...
# ...                                        ...  ...
# 1617                                       NaN  ...
# 1618                                    CCNCCN  ...
# 1619                                       NaN  ...
# 1620                                    CCCCCC  ...
# 1621                                       NaN  ...
#
#                          level _5                              subclass  \
# 851                           NaN                                   NaN
# 852   Amino acids and derivatives  Amino acids, peptides, and analogues
# 853   Amino acids and derivatives  Amino acids, peptides, and analogues
# 854                           NaN                                   NaN
# 855                           NaN                                   NaN
# ...                           ...                                   ...
# 1617                          NaN                                   NaN
# 1618  Amino acids and derivatives  Amino acids, peptides, and analogues
# 1619                          NaN                                   NaN
# 1620                          NaN                         Nitrobenzenes
# 1621                          NaN  Bile acids, alcohols and derivatives
#
#                                     class                       superclass  \
# 851                                   NaN                              NaN
# 852      Carboxylic acids and derivatives    Organic acids and derivatives
# 853      Carboxylic acids and derivatives    Organic acids and derivatives
# 854                                   NaN                              NaN
# 855                                   NaN                              NaN
# ...                                   ...                              ...
# 1617  Benzene and substituted derivatives                       Benzenoids
# 1618     Carboxylic acids and derivatives    Organic acids and derivatives
# 1619                                  NaN                              NaN
# 1620  Benzene and substituted derivatives                       Benzenoids
# 1621     Steroids and steroid derivatives  Lipids and lipid-like molecules
#
#                                     all_classifications KG_MCSS_SMILES  \
# 851                                                 NaN            NaN
# 852   Organic compounds; Lipids and lipid-like molec...            NaN
# 853   Organic compounds; Lipids and lipid-like molec...            NaN
# 854                                                 NaN            NaN
# 855                                                 NaN            NaN
# ...                                                 ...            ...
# 1617                                                NaN            NaN
# 1618  Organic compounds; Organoheterocyclic compound...            NaN
# 1619                                                NaN            NaN
# 1620  Organic compounds; Organoheterocyclic compound...            NaN
# 1621                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 851             CCN           PubChem
# 852             NaN            SIRIUS
# 853             NaN            SIRIUS
# 854             NaN            SIRIUS
# 855             NaN            SIRIUS
# ...             ...               ...
# 1617            NaN            SIRIUS
# 1618            NaN            SIRIUS
# 1619       CCC(=O)O           PubChem
# 1620            NaN            SIRIUS
# 1621            NaN              GNPS
#
#                                            SMILES_final Classification_Source
# 851                C1=C(C(=O)NC(=O)[NH+]1O)[N+](=O)[O-]            ClassyFire
# 852                             CC(=O)NC(CC(=O)O)C(=O)N               CANOPUS
# 853   CCC=CCC=CCC=CCC=CCC=CCCCC(=O)OCC(COP(=O)(O)OCCN)O               CANOPUS
# 854   CCCCCCCCCCCCCCCC=CC(=O)N(CCCCC(C(=O)OC(C)CC(=O...            ClassyFire
# 855   CC1CCN2C1C(=O)NC(C(=O)NC(C(=NCC2=O)NC(C(=O)NC(...            ClassyFire
# ...                                                 ...                   ...
# 1617                             C1=CC=C(C=C1)P(=O)(N)N            ClassyFire
# 1618                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1619                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1620  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1621  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
#
# [771 rows x 21 columns]

# %%
#np.unique(list(resultsmzrt2['SMILES_final']))

# %%
# only take entries without SMILES Entry
resultsmzrtna = resultsmzrt[resultsmzrt['SMILES_final'].isna()]
resultsmzrtna
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 0              0   M185R138ID1  185.021500  138.437646  0.000000e+00       30
# 1              1   M259R133ID2  259.057556  133.058433  0.000000e+00       30
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 5              5   M227R156ID6  226.995239  156.163704  0.000000e+00       30
# 6              6    M99R156ID7   99.008179  156.366516  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1842        1842  M201R170ID63  201.134094  170.287662  3.410628e+06       30
# 1843        1843  M283R205ID64  283.069489  205.108926  1.456003e+07       30
# 1852        1852  M220R391ID73  219.984314  390.980169  4.266630e+07       30
# 1853        1853   M98R401ID74   97.991364  400.871613  4.474369e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol     Formula                            MCSS_SMILES  \
# 0     neg    C6H6N2O5                            C:C:C(:N)CO
# 1     neg   C9H12N2O7  O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1
# 3     neg      C5H4O5                                    NaN
# 5     neg  C6H13O3PS2                                    OPO
# 6     neg      C4H4O3                               CCC(=O)O
# ...   ...         ...                                    ...
# 1842  pos   C8H16N4O2                                   CCNC
# 1843  pos  C7H14N4O6S                     CCN=CNP(=O)(OC)SSC
# 1852  pos     C4H7NO7                                    CCN
# 1853  pos      H3NO3S                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
#
#                        most_specific_class                     level _5  \
# 0        Alpha amino acids and derivatives  Amino acids and derivatives
# 1                           Glycosylamines           Glycosyl compounds
# 3                                      NaN                          NaN
# 5                   Carboxylic acid esters       Carboxylic acid esters
# 6                                  Ketones                      Ketones
# ...                                    ...                          ...
# 1842           Amino acids and derivatives  Amino acids and derivatives
# 1843  Organosulfonic acids and derivatives                          NaN
# 1852                      Carboxylic acids                          NaN
# 1853                                   NaN                          NaN
# 1854                                   NaN                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 3                                           NaN
# 5                   Carboxylic acid derivatives
# 6                            Carbonyl compounds
# ...                                         ...
# 1842       Amino acids, peptides, and analogues
# 1843       Organosulfonic acids and derivatives
# 1852                           Carboxylic acids
# 1853                                        NaN
# 1854                                        NaN
#
#                                        class                     superclass  \
# 0           Carboxylic acids and derivatives  Organic acids and derivatives
# 1                     Organooxygen compounds       Organic oxygen compounds
# 3                                        NaN                            NaN
# 5           Carboxylic acids and derivatives  Organic acids and derivatives
# 6                     Organooxygen compounds       Organic oxygen compounds
# ...                                      ...                            ...
# 1842        Carboxylic acids and derivatives  Organic acids and derivatives
# 1843  Organic sulfonic acids and derivatives  Organic acids and derivatives
# 1852        Carboxylic acids and derivatives  Organic acids and derivatives
# 1853                                     NaN                            NaN
# 1854                                     NaN                            NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 3                                                   NaN            NaN
# 5     Organic compounds; Organic acids and derivativ...            NaN
# 6     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1842  Organic compounds; Amidines; Amino acids, pept...            NaN
# 1843  Organic compounds; Organosulfur compounds; Org...            NaN
# 1852  Organic compounds; Alcohols and polyols; Organ...            NaN
# 1853                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source SMILES_final Classification_Source
# 0               NaN    SIRIUS_Formula          NaN               CANOPUS
# 1               NaN    SIRIUS_Formula          NaN               CANOPUS
# 3               NaN    SIRIUS_Formula          NaN                   NaN
# 5               NaN    SIRIUS_Formula          NaN               CANOPUS
# 6               NaN    SIRIUS_Formula          NaN               CANOPUS
# ...             ...               ...          ...                   ...
# 1842            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1843            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1852            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1853            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
#
# [851 rows x 20 columns]

# %%
#remove duplicated SMILES entries from resultsmzrt
smiles = resultsmzrt.drop_duplicates(['SMILES_final'],keep= 'last')
smiles
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 4              4   M173R153ID5  173.008163  152.503416  0.000000e+00       30
# 8              8   M173R158ID9  173.055679  157.904502  0.000000e+00       30
# 9              9  M498R160ID10  498.259705  160.214106  0.000000e+00       30
# 11            11  M861R186ID12  860.502197  186.021606  0.000000e+00       30
# 12            12  M863R190ID13  862.502380  189.772890  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1848        1848  M145R349ID69  145.097107  349.070949  1.241231e+08       30
# 1849        1849  M143R366ID70  143.081360  366.229470  1.562070e+07       30
# 1850        1850  M338R389ID71  337.969147  389.379822  1.448262e+07       30
# 1851        1851  M265R391ID72  265.015442  390.517248  1.642149e+08       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol      Formula                               MCSS_SMILES  \
# 4     neg          NaN                                       NaN
# 8     neg    C6H10N2O4                               CC(=O)NCC=O
# 9     neg   C25H42NO7P                   CCC=CCC=CCC=CCC=CCC=CCC
# 11    neg  C44H71N5O12  C:CCC(NC(=O)CCC(:C):C:C:C:C)C(=O)NC(C)CC
# 12    neg  C45H69N9O6S                                 CCCCCCCCC
# ...   ...          ...                                       ...
# 1848  pos    C6H12N2O2                                    CCNCCN
# 1849  pos          NaN                                       NaN
# 1850  pos    C9H5N3O8S                                    CCCCCC
# 1851  pos          NaN                                       NaN
# 1854  pos     C5H5OPS2                                       NaN
#
#                     most_specific_class                     level _5  \
# 4                                   NaN                          NaN
# 8     Alpha amino acids and derivatives  Amino acids and derivatives
# 9           Amino acids and derivatives  Amino acids and derivatives
# 11                                  NaN                          NaN
# 12                                  NaN                          NaN
# ...                                 ...                          ...
# 1848                  Alpha amino acids  Amino acids and derivatives
# 1849                                NaN                          NaN
# 1850                      Nitrobenzenes                          NaN
# 1851                                NaN                          NaN
# 1854                                NaN                          NaN
#
#                                   subclass  \
# 4                                      NaN
# 8     Amino acids, peptides, and analogues
# 9     Amino acids, peptides, and analogues
# 11                                     NaN
# 12                                     NaN
# ...                                    ...
# 1848  Amino acids, peptides, and analogues
# 1849                                   NaN
# 1850                         Nitrobenzenes
# 1851  Bile acids, alcohols and derivatives
# 1854                                   NaN
#
#                                     class                       superclass  \
# 4                                     NaN                              NaN
# 8        Carboxylic acids and derivatives    Organic acids and derivatives
# 9        Carboxylic acids and derivatives    Organic acids and derivatives
# 11                                    NaN                              NaN
# 12                                    NaN                              NaN
# ...                                   ...                              ...
# 1848     Carboxylic acids and derivatives    Organic acids and derivatives
# 1849                                  NaN                              NaN
# 1850  Benzene and substituted derivatives                       Benzenoids
# 1851     Steroids and steroid derivatives  Lipids and lipid-like molecules
# 1854                                  NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 4                                                   NaN            NaN
# 8     Organic compounds; Lipids and lipid-like molec...            NaN
# 9     Organic compounds; Lipids and lipid-like molec...            NaN
# 11                                                  NaN            NaN
# 12                                                  NaN            NaN
# ...                                                 ...            ...
# 1848  Organic compounds; Organoheterocyclic compound...            NaN
# 1849                                                NaN            NaN
# 1850  Organic compounds; Organoheterocyclic compound...            NaN
# 1851                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 4               CCN           PubChem
# 8               NaN            SIRIUS
# 9               NaN            SIRIUS
# 11              NaN            SIRIUS
# 12              NaN            SIRIUS
# ...             ...               ...
# 1848            NaN            SIRIUS
# 1849       CCC(=O)O           PubChem
# 1850            NaN            SIRIUS
# 1851            NaN              GNPS
# 1854            NaN    SIRIUS_Formula
#
#                                            SMILES_final Classification_Source
# 4                  C1=C(C(=O)NC(=O)[NH+]1O)[N+](=O)[O-]            ClassyFire
# 8                               CC(=O)NC(CC(=O)O)C(=O)N               CANOPUS
# 9     CCC=CCC=CCC=CCC=CCC=CCCCC(=O)OCC(COP(=O)(O)OCCN)O               CANOPUS
# 11    CCCCCCCCCCCCCCCC=CC(=O)N(CCCCC(C(=O)OC(C)CC(=O...            ClassyFire
# 12    CC1CCN2C1C(=O)NC(C(=O)NC(C(=NCC2=O)NC(C(=O)NC(...            ClassyFire
# ...                                                 ...                   ...
# 1848                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1849                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1850  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1851  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
# 1854                                                NaN                   NaN
#
# [772 rows x 20 columns]

# %%
resultsx = pd.concat([resultsmzrtna, smiles])
resultsx# this is unduplicated final list of features
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 0              0   M185R138ID1  185.021500  138.437646  0.000000e+00       30
# 1              1   M259R133ID2  259.057556  133.058433  0.000000e+00       30
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 5              5   M227R156ID6  226.995239  156.163704  0.000000e+00       30
# 6              6    M99R156ID7   99.008179  156.366516  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1848        1848  M145R349ID69  145.097107  349.070949  1.241231e+08       30
# 1849        1849  M143R366ID70  143.081360  366.229470  1.562070e+07       30
# 1850        1850  M338R389ID71  337.969147  389.379822  1.448262e+07       30
# 1851        1851  M265R391ID72  265.015442  390.517248  1.642149e+08       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol     Formula                            MCSS_SMILES  \
# 0     neg    C6H6N2O5                            C:C:C(:N)CO
# 1     neg   C9H12N2O7  O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1
# 3     neg      C5H4O5                                    NaN
# 5     neg  C6H13O3PS2                                    OPO
# 6     neg      C4H4O3                               CCC(=O)O
# ...   ...         ...                                    ...
# 1848  pos   C6H12N2O2                                 CCNCCN
# 1849  pos         NaN                                    NaN
# 1850  pos   C9H5N3O8S                                 CCCCCC
# 1851  pos         NaN                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
#
#                     most_specific_class                     level _5  \
# 0     Alpha amino acids and derivatives  Amino acids and derivatives
# 1                        Glycosylamines           Glycosyl compounds
# 3                                   NaN                          NaN
# 5                Carboxylic acid esters       Carboxylic acid esters
# 6                               Ketones                      Ketones
# ...                                 ...                          ...
# 1848                  Alpha amino acids  Amino acids and derivatives
# 1849                                NaN                          NaN
# 1850                      Nitrobenzenes                          NaN
# 1851                                NaN                          NaN
# 1854                                NaN                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 3                                           NaN
# 5                   Carboxylic acid derivatives
# 6                            Carbonyl compounds
# ...                                         ...
# 1848       Amino acids, peptides, and analogues
# 1849                                        NaN
# 1850                              Nitrobenzenes
# 1851       Bile acids, alcohols and derivatives
# 1854                                        NaN
#
#                                     class                       superclass  \
# 0        Carboxylic acids and derivatives    Organic acids and derivatives
# 1                  Organooxygen compounds         Organic oxygen compounds
# 3                                     NaN                              NaN
# 5        Carboxylic acids and derivatives    Organic acids and derivatives
# 6                  Organooxygen compounds         Organic oxygen compounds
# ...                                   ...                              ...
# 1848     Carboxylic acids and derivatives    Organic acids and derivatives
# 1849                                  NaN                              NaN
# 1850  Benzene and substituted derivatives                       Benzenoids
# 1851     Steroids and steroid derivatives  Lipids and lipid-like molecules
# 1854                                  NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 3                                                   NaN            NaN
# 5     Organic compounds; Organic acids and derivativ...            NaN
# 6     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1848  Organic compounds; Organoheterocyclic compound...            NaN
# 1849                                                NaN            NaN
# 1850  Organic compounds; Organoheterocyclic compound...            NaN
# 1851                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 0               NaN    SIRIUS_Formula
# 1               NaN    SIRIUS_Formula
# 3               NaN    SIRIUS_Formula
# 5               NaN    SIRIUS_Formula
# 6               NaN    SIRIUS_Formula
# ...             ...               ...
# 1848            NaN            SIRIUS
# 1849       CCC(=O)O           PubChem
# 1850            NaN            SIRIUS
# 1851            NaN              GNPS
# 1854            NaN    SIRIUS_Formula
#
#                                            SMILES_final Classification_Source
# 0                                                   NaN               CANOPUS
# 1                                                   NaN               CANOPUS
# 3                                                   NaN                   NaN
# 5                                                   NaN               CANOPUS
# 6                                                   NaN               CANOPUS
# ...                                                 ...                   ...
# 1848                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1849                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1850  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1851  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
# 1854                                                NaN                   NaN
#
# [1623 rows x 20 columns]

# %%
resultsx.to_csv("Final_Candidate_List.csv")

# %%
XS = resultsx[resultsx['Annotation_Source'] == 'SIRIUS_Formula']
XS
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 0              0   M185R138ID1  185.021500  138.437646  0.000000e+00       30
# 1              1   M259R133ID2  259.057556  133.058433  0.000000e+00       30
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 5              5   M227R156ID6  226.995239  156.163704  0.000000e+00       30
# 6              6    M99R156ID7   99.008179  156.366516  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1843        1843  M283R205ID64  283.069489  205.108926  1.456003e+07       30
# 1852        1852  M220R391ID73  219.984314  390.980169  4.266630e+07       30
# 1853        1853   M98R401ID74   97.991364  400.871613  4.474369e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol     Formula                            MCSS_SMILES  \
# 0     neg    C6H6N2O5                            C:C:C(:N)CO
# 1     neg   C9H12N2O7  O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1
# 3     neg      C5H4O5                                    NaN
# 5     neg  C6H13O3PS2                                    OPO
# 6     neg      C4H4O3                               CCC(=O)O
# ...   ...         ...                                    ...
# 1843  pos  C7H14N4O6S                     CCN=CNP(=O)(OC)SSC
# 1852  pos     C4H7NO7                                    CCN
# 1853  pos      H3NO3S                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
#
#                        most_specific_class                     level _5  \
# 0        Alpha amino acids and derivatives  Amino acids and derivatives
# 1                           Glycosylamines           Glycosyl compounds
# 3                                      NaN                          NaN
# 5                   Carboxylic acid esters       Carboxylic acid esters
# 6                                  Ketones                      Ketones
# ...                                    ...                          ...
# 1843  Organosulfonic acids and derivatives                          NaN
# 1852                      Carboxylic acids                          NaN
# 1853                                   NaN                          NaN
# 1854                                   NaN                          NaN
# 1854                                   NaN                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 3                                           NaN
# 5                   Carboxylic acid derivatives
# 6                            Carbonyl compounds
# ...                                         ...
# 1843       Organosulfonic acids and derivatives
# 1852                           Carboxylic acids
# 1853                                        NaN
# 1854                                        NaN
# 1854                                        NaN
#
#                                        class                     superclass  \
# 0           Carboxylic acids and derivatives  Organic acids and derivatives
# 1                     Organooxygen compounds       Organic oxygen compounds
# 3                                        NaN                            NaN
# 5           Carboxylic acids and derivatives  Organic acids and derivatives
# 6                     Organooxygen compounds       Organic oxygen compounds
# ...                                      ...                            ...
# 1843  Organic sulfonic acids and derivatives  Organic acids and derivatives
# 1852        Carboxylic acids and derivatives  Organic acids and derivatives
# 1853                                     NaN                            NaN
# 1854                                     NaN                            NaN
# 1854                                     NaN                            NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 3                                                   NaN            NaN
# 5     Organic compounds; Organic acids and derivativ...            NaN
# 6     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1843  Organic compounds; Organosulfur compounds; Org...            NaN
# 1852  Organic compounds; Alcohols and polyols; Organ...            NaN
# 1853                                                NaN            NaN
# 1854                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source SMILES_final Classification_Source
# 0               NaN    SIRIUS_Formula          NaN               CANOPUS
# 1               NaN    SIRIUS_Formula          NaN               CANOPUS
# 3               NaN    SIRIUS_Formula          NaN                   NaN
# 5               NaN    SIRIUS_Formula          NaN               CANOPUS
# 6               NaN    SIRIUS_Formula          NaN               CANOPUS
# ...             ...               ...          ...                   ...
# 1843            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1852            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1853            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
#
# [790 rows x 20 columns]

# %%
XSS = XS[isNaN(XS['Classification_Source'])]
XSS[-isNaN(XSS['Annotation_Source'])]
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 10            10  M303R170ID11  303.049133  170.032038  0.000000e+00       30
# 13            13  M283R204ID14  283.033081  204.212844  0.000000e+00       30
# 41            41  M343R338ID42  343.049377  337.723671  0.000000e+00       30
# 42            42  M365R338ID43  365.074585  338.293104  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1832        1832   M379R85ID53  378.971130   84.519606  1.349073e+07       30
# 1836        1836  M172R106ID57  172.036728  105.761448  4.863573e+07       30
# 1853        1853   M98R401ID74   97.991364  400.871613  4.474369e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol       Formula      MCSS_SMILES most_specific_class level _5  \
# 3     neg        C5H4O5              NaN                 NaN      NaN
# 10    neg     C11H8N6O5  C:N:C:N:C(:C):N                 NaN      NaN
# 13    neg    C7H13N2O8P    CCCOP(=O)(O)O                 NaN      NaN
# 41    neg  C13H17N2O5PS       CC:NCC:C:N                 NaN      NaN
# 42    neg  C10H18N6O5S2          CC:C:CC                 NaN      NaN
# ...   ...           ...              ...                 ...      ...
# 1832  pos      C16H4O10              NaN                 NaN      NaN
# 1836  pos       C8H7NO2              NaN                 NaN      NaN
# 1853  pos        H3NO3S              NaN                 NaN      NaN
# 1854  pos      C5H5OPS2              NaN                 NaN      NaN
# 1854  pos      C5H5OPS2              NaN                 NaN      NaN
#
#      subclass class superclass all_classifications KG_MCSS_SMILES  \
# 3         NaN   NaN        NaN                 NaN            NaN
# 10        NaN   NaN        NaN                 NaN            NaN
# 13        NaN   NaN        NaN                 NaN            NaN
# 41        NaN   NaN        NaN                 NaN            NaN
# 42        NaN   NaN        NaN                 NaN            NaN
# ...       ...   ...        ...                 ...            ...
# 1832      NaN   NaN        NaN                 NaN            NaN
# 1836      NaN   NaN        NaN                 NaN            NaN
# 1853      NaN   NaN        NaN                 NaN            NaN
# 1854      NaN   NaN        NaN                 NaN            NaN
# 1854      NaN   NaN        NaN                 NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source SMILES_final Classification_Source
# 3               NaN    SIRIUS_Formula          NaN                   NaN
# 10              NaN    SIRIUS_Formula          NaN                   NaN
# 13              NaN    SIRIUS_Formula          NaN                   NaN
# 41              NaN    SIRIUS_Formula          NaN                   NaN
# 42              NaN    SIRIUS_Formula          NaN                   NaN
# ...             ...               ...          ...                   ...
# 1832            NaN    SIRIUS_Formula          NaN                   NaN
# 1836            NaN    SIRIUS_Formula          NaN                   NaN
# 1853            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
#
# [291 rows x 20 columns]

# %%
np.unique(list(XSS['Annotation_Source']))
# Out:
# array(['SIRIUS_Formula'], dtype='<U14')

# %%
#resultsx2 = resultsx[resultsx['Annotation_Source'] != 'SIRIUS_Formula']
#resultsx2# with some database annotation

# %%
# counting number of candidates in different annotation sources

# %%
results2 = resultsx[-resultsx['Annotation_Source'].isna()]
results2#with a source of annotation
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 0              0   M185R138ID1  185.021500  138.437646  0.000000e+00       30
# 1              1   M259R133ID2  259.057556  133.058433  0.000000e+00       30
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 5              5   M227R156ID6  226.995239  156.163704  0.000000e+00       30
# 6              6    M99R156ID7   99.008179  156.366516  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1848        1848  M145R349ID69  145.097107  349.070949  1.241231e+08       30
# 1849        1849  M143R366ID70  143.081360  366.229470  1.562070e+07       30
# 1850        1850  M338R389ID71  337.969147  389.379822  1.448262e+07       30
# 1851        1851  M265R391ID72  265.015442  390.517248  1.642149e+08       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol     Formula                            MCSS_SMILES  \
# 0     neg    C6H6N2O5                            C:C:C(:N)CO
# 1     neg   C9H12N2O7  O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1
# 3     neg      C5H4O5                                    NaN
# 5     neg  C6H13O3PS2                                    OPO
# 6     neg      C4H4O3                               CCC(=O)O
# ...   ...         ...                                    ...
# 1848  pos   C6H12N2O2                                 CCNCCN
# 1849  pos         NaN                                    NaN
# 1850  pos   C9H5N3O8S                                 CCCCCC
# 1851  pos         NaN                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
#
#                     most_specific_class                     level _5  \
# 0     Alpha amino acids and derivatives  Amino acids and derivatives
# 1                        Glycosylamines           Glycosyl compounds
# 3                                   NaN                          NaN
# 5                Carboxylic acid esters       Carboxylic acid esters
# 6                               Ketones                      Ketones
# ...                                 ...                          ...
# 1848                  Alpha amino acids  Amino acids and derivatives
# 1849                                NaN                          NaN
# 1850                      Nitrobenzenes                          NaN
# 1851                                NaN                          NaN
# 1854                                NaN                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 3                                           NaN
# 5                   Carboxylic acid derivatives
# 6                            Carbonyl compounds
# ...                                         ...
# 1848       Amino acids, peptides, and analogues
# 1849                                        NaN
# 1850                              Nitrobenzenes
# 1851       Bile acids, alcohols and derivatives
# 1854                                        NaN
#
#                                     class                       superclass  \
# 0        Carboxylic acids and derivatives    Organic acids and derivatives
# 1                  Organooxygen compounds         Organic oxygen compounds
# 3                                     NaN                              NaN
# 5        Carboxylic acids and derivatives    Organic acids and derivatives
# 6                  Organooxygen compounds         Organic oxygen compounds
# ...                                   ...                              ...
# 1848     Carboxylic acids and derivatives    Organic acids and derivatives
# 1849                                  NaN                              NaN
# 1850  Benzene and substituted derivatives                       Benzenoids
# 1851     Steroids and steroid derivatives  Lipids and lipid-like molecules
# 1854                                  NaN                              NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 3                                                   NaN            NaN
# 5     Organic compounds; Organic acids and derivativ...            NaN
# 6     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1848  Organic compounds; Organoheterocyclic compound...            NaN
# 1849                                                NaN            NaN
# 1850  Organic compounds; Organoheterocyclic compound...            NaN
# 1851                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 0               NaN    SIRIUS_Formula
# 1               NaN    SIRIUS_Formula
# 3               NaN    SIRIUS_Formula
# 5               NaN    SIRIUS_Formula
# 6               NaN    SIRIUS_Formula
# ...             ...               ...
# 1848            NaN            SIRIUS
# 1849       CCC(=O)O           PubChem
# 1850            NaN            SIRIUS
# 1851            NaN              GNPS
# 1854            NaN    SIRIUS_Formula
#
#                                            SMILES_final Classification_Source
# 0                                                   NaN               CANOPUS
# 1                                                   NaN               CANOPUS
# 3                                                   NaN                   NaN
# 5                                                   NaN               CANOPUS
# 6                                                   NaN               CANOPUS
# ...                                                 ...                   ...
# 1848                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1849                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1850  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1851  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
# 1854                                                NaN                   NaN
#
# [1561 rows x 20 columns]

# %%
results3 = results2[results2['Annotation_Source'] != 'SIRIUS_Formula']
results3# with some database annotation
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 4              4   M173R153ID5  173.008163  152.503416  0.000000e+00       30
# 8              8   M173R158ID9  173.055679  157.904502  0.000000e+00       30
# 9              9  M498R160ID10  498.259705  160.214106  0.000000e+00       30
# 11            11  M861R186ID12  860.502197  186.021606  0.000000e+00       30
# 12            12  M863R190ID13  862.502380  189.772890  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1847        1847  M179R328ID68  179.035263  328.295220  4.067382e+06       30
# 1848        1848  M145R349ID69  145.097107  349.070949  1.241231e+08       30
# 1849        1849  M143R366ID70  143.081360  366.229470  1.562070e+07       30
# 1850        1850  M338R389ID71  337.969147  389.379822  1.448262e+07       30
# 1851        1851  M265R391ID72  265.015442  390.517248  1.642149e+08       30
#
#       pol      Formula                               MCSS_SMILES  \
# 4     neg          NaN                                       NaN
# 8     neg    C6H10N2O4                               CC(=O)NCC=O
# 9     neg   C25H42NO7P                   CCC=CCC=CCC=CCC=CCC=CCC
# 11    neg  C44H71N5O12  C:CCC(NC(=O)CCC(:C):C:C:C:C)C(=O)NC(C)CC
# 12    neg  C45H69N9O6S                                 CCCCCCCCC
# ...   ...          ...                                       ...
# 1847  pos     C6H9N2OP                                       NaN
# 1848  pos    C6H12N2O2                                    CCNCCN
# 1849  pos          NaN                                       NaN
# 1850  pos    C9H5N3O8S                                    CCCCCC
# 1851  pos          NaN                                       NaN
#
#                     most_specific_class                     level _5  \
# 4                                   NaN                          NaN
# 8     Alpha amino acids and derivatives  Amino acids and derivatives
# 9           Amino acids and derivatives  Amino acids and derivatives
# 11                                  NaN                          NaN
# 12                                  NaN                          NaN
# ...                                 ...                          ...
# 1847                                NaN                          NaN
# 1848                  Alpha amino acids  Amino acids and derivatives
# 1849                                NaN                          NaN
# 1850                      Nitrobenzenes                          NaN
# 1851                                NaN                          NaN
#
#                                   subclass  \
# 4                                      NaN
# 8     Amino acids, peptides, and analogues
# 9     Amino acids, peptides, and analogues
# 11                                     NaN
# 12                                     NaN
# ...                                    ...
# 1847                                   NaN
# 1848  Amino acids, peptides, and analogues
# 1849                                   NaN
# 1850                         Nitrobenzenes
# 1851  Bile acids, alcohols and derivatives
#
#                                     class                       superclass  \
# 4                                     NaN                              NaN
# 8        Carboxylic acids and derivatives    Organic acids and derivatives
# 9        Carboxylic acids and derivatives    Organic acids and derivatives
# 11                                    NaN                              NaN
# 12                                    NaN                              NaN
# ...                                   ...                              ...
# 1847  Benzene and substituted derivatives                       Benzenoids
# 1848     Carboxylic acids and derivatives    Organic acids and derivatives
# 1849                                  NaN                              NaN
# 1850  Benzene and substituted derivatives                       Benzenoids
# 1851     Steroids and steroid derivatives  Lipids and lipid-like molecules
#
#                                     all_classifications KG_MCSS_SMILES  \
# 4                                                   NaN            NaN
# 8     Organic compounds; Lipids and lipid-like molec...            NaN
# 9     Organic compounds; Lipids and lipid-like molec...            NaN
# 11                                                  NaN            NaN
# 12                                                  NaN            NaN
# ...                                                 ...            ...
# 1847                                                NaN            NaN
# 1848  Organic compounds; Organoheterocyclic compound...            NaN
# 1849                                                NaN            NaN
# 1850  Organic compounds; Organoheterocyclic compound...            NaN
# 1851                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source  \
# 4               CCN           PubChem
# 8               NaN            SIRIUS
# 9               NaN            SIRIUS
# 11              NaN            SIRIUS
# 12              NaN            SIRIUS
# ...             ...               ...
# 1847            NaN            SIRIUS
# 1848            NaN            SIRIUS
# 1849       CCC(=O)O           PubChem
# 1850            NaN            SIRIUS
# 1851            NaN              GNPS
#
#                                            SMILES_final Classification_Source
# 4                  C1=C(C(=O)NC(=O)[NH+]1O)[N+](=O)[O-]            ClassyFire
# 8                               CC(=O)NC(CC(=O)O)C(=O)N               CANOPUS
# 9     CCC=CCC=CCC=CCC=CCC=CCCCC(=O)OCC(COP(=O)(O)OCCN)O               CANOPUS
# 11    CCCCCCCCCCCCCCCC=CC(=O)N(CCCCC(C(=O)OC(C)CC(=O...            ClassyFire
# 12    CC1CCN2C1C(=O)NC(C(=O)NC(C(=NCC2=O)NC(C(=O)NC(...            ClassyFire
# ...                                                 ...                   ...
# 1847                             C1=CC=C(C=C1)P(=O)(N)N            ClassyFire
# 1848                                C1CN(C1)CC(C(=O)O)N               CANOPUS
# 1849                              C=C(/C=C\C(N)N)C(=O)O            ClassyFire
# 1850  C1=C2C=C(C(=O)NC2=CC(=C1[N+](=O)[O-])[N+](=O)[...               CANOPUS
# 1851  CC(C(O)CCC(C)(C)O)C1CCC2(O)C3=CC(=O)C4CC(O)C(O...            ClassyFire
#
# [771 rows x 20 columns]

# %%
#len(np.unique(list(results2['SMILES_final'])))

# %%
results2[results2['Annotation_Source'] == 'SIRIUS_Formula'] # with Formula annotation
# Out:
#       Unnamed: 0          id_X       premz       rtmed           int  col_eng  \
# 0              0   M185R138ID1  185.021500  138.437646  0.000000e+00       30
# 1              1   M259R133ID2  259.057556  133.058433  0.000000e+00       30
# 3              3   M143R152ID4  142.997726  152.119794  0.000000e+00       30
# 5              5   M227R156ID6  226.995239  156.163704  0.000000e+00       30
# 6              6    M99R156ID7   99.008179  156.366516  0.000000e+00       30
# ...          ...           ...         ...         ...           ...      ...
# 1843        1843  M283R205ID64  283.069489  205.108926  1.456003e+07       30
# 1852        1852  M220R391ID73  219.984314  390.980169  4.266630e+07       30
# 1853        1853   M98R401ID74   97.991364  400.871613  4.474369e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
# 1854        1854  M215R401ID75  214.917496  401.357670  2.277173e+07       30
#
#       pol     Formula                            MCSS_SMILES  \
# 0     neg    C6H6N2O5                            C:C:C(:N)CO
# 1     neg   C9H12N2O7  O=C1:C:C:N(C2OC(CO)C(O)C2O):C(=O):N:1
# 3     neg      C5H4O5                                    NaN
# 5     neg  C6H13O3PS2                                    OPO
# 6     neg      C4H4O3                               CCC(=O)O
# ...   ...         ...                                    ...
# 1843  pos  C7H14N4O6S                     CCN=CNP(=O)(OC)SSC
# 1852  pos     C4H7NO7                                    CCN
# 1853  pos      H3NO3S                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
# 1854  pos    C5H5OPS2                                    NaN
#
#                        most_specific_class                     level _5  \
# 0        Alpha amino acids and derivatives  Amino acids and derivatives
# 1                           Glycosylamines           Glycosyl compounds
# 3                                      NaN                          NaN
# 5                   Carboxylic acid esters       Carboxylic acid esters
# 6                                  Ketones                      Ketones
# ...                                    ...                          ...
# 1843  Organosulfonic acids and derivatives                          NaN
# 1852                      Carboxylic acids                          NaN
# 1853                                   NaN                          NaN
# 1854                                   NaN                          NaN
# 1854                                   NaN                          NaN
#
#                                        subclass  \
# 0          Amino acids, peptides, and analogues
# 1     Carbohydrates and carbohydrate conjugates
# 3                                           NaN
# 5                   Carboxylic acid derivatives
# 6                            Carbonyl compounds
# ...                                         ...
# 1843       Organosulfonic acids and derivatives
# 1852                           Carboxylic acids
# 1853                                        NaN
# 1854                                        NaN
# 1854                                        NaN
#
#                                        class                     superclass  \
# 0           Carboxylic acids and derivatives  Organic acids and derivatives
# 1                     Organooxygen compounds       Organic oxygen compounds
# 3                                        NaN                            NaN
# 5           Carboxylic acids and derivatives  Organic acids and derivatives
# 6                     Organooxygen compounds       Organic oxygen compounds
# ...                                      ...                            ...
# 1843  Organic sulfonic acids and derivatives  Organic acids and derivatives
# 1852        Carboxylic acids and derivatives  Organic acids and derivatives
# 1853                                     NaN                            NaN
# 1854                                     NaN                            NaN
# 1854                                     NaN                            NaN
#
#                                     all_classifications KG_MCSS_SMILES  \
# 0     Organic compounds; Organoheterocyclic compound...            NaN
# 1     Organic compounds; Organoheterocyclic compound...            NaN
# 3                                                   NaN            NaN
# 5     Organic compounds; Organic acids and derivativ...            NaN
# 6     Organic compounds; Ketones; Carboxylic acids a...            NaN
# ...                                                 ...            ...
# 1843  Organic compounds; Organosulfur compounds; Org...            NaN
# 1852  Organic compounds; Alcohols and polyols; Organ...            NaN
# 1853                                                NaN            NaN
# 1854                                                NaN            NaN
# 1854                                                NaN            NaN
#
#      PC_MCSS_SMILES Annotation_Source SMILES_final Classification_Source
# 0               NaN    SIRIUS_Formula          NaN               CANOPUS
# 1               NaN    SIRIUS_Formula          NaN               CANOPUS
# 3               NaN    SIRIUS_Formula          NaN                   NaN
# 5               NaN    SIRIUS_Formula          NaN               CANOPUS
# 6               NaN    SIRIUS_Formula          NaN               CANOPUS
# ...             ...               ...          ...                   ...
# 1843            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1852            NaN    SIRIUS_Formula          NaN               CANOPUS
# 1853            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
# 1854            NaN    SIRIUS_Formula          NaN                   NaN
#
# [790 rows x 20 columns]

# %%
ls2 = list(results3['Annotation_Source'])
#ls2

# %%
# only in spectral databases
len([x for x in ls2 if 'GNPS' in x or 'MassBank' in x or 'HMDB' in x])
# Out:
# 128

# %%
# only in SIRIUS and MetFrag databases
len([x for x in ls2 if 'PubChem' in x or 'KEGG' in x or 'SIRIUS' in x and not isNaN(["superclass"])])
# Out:
# 643

# %%
# only in SIRIUS_formula
len([x for x in ls2 if 'SuspectList' in x])
# Out:
# 43

# %%
# counting classification

# %%
classes = resultsx[-resultsx['superclass'].isna()]

# %%
lsc = np.unique(list(classes['superclass']))
lsc
lscc = list(classes['superclass'])

# %%
classesData = []
for i in lsc:
    num = lscc.count(i)
    classesData.append({
        'SuperClass':i,
        'Count':num
    })
classDB = pd.DataFrame(classesData)
classDB
# Out:
#                                    SuperClass  Count
# 0                   Alkaloids and derivatives      7
# 1                                  Benzenoids     41
# 2                     Hydrocarbon derivatives      2
# 3                                Hydrocarbons      3
# 4   Lignans, neolignans and related compounds      2
# 5             Lipids and lipid-like molecules    218
# 6     Nucleosides, nucleotides, and analogues     14
# 7               Organic 1,3-dipolar compounds      4
# 8               Organic acids and derivatives    356
# 9                  Organic nitrogen compounds     58
# 10                   Organic oxygen compounds     95
# 11                    Organohalogen compounds      1
# 12               Organoheterocyclic compounds    121
# 13                 Organophosphorus compounds      8
# 14                     Organosulfur compounds     12
# 15           Phenylpropanoids and polyketides      9

# %%
sl = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/SuspectList/Use_This_CURATED_SUSPECT_LIST_with_classes_noDups.csv")

# %%
sl.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Formula', 'Species', 'SMILES', 'InChI',
#        'Monoisotopic_mass', 'ChEBIid', 'KEGGid', 'PubChemId',
#        'source_database', 'Source', 'nonIsomeric_SMILES_byRDKit', 'iupac',
#        'synonyms', 'PubChemPY', 'correct_Name', 'Molecular mass', 'subclass',
#        'class', 'superclass'],
#       dtype='object')

# %%
classeSL = sl[-sl['superclass'].isna()]

# %%
lscSL = np.unique(list(classeSL['superclass']))
lscSL
lsccSL = list(classeSL['superclass'])

# %%
classesDataSL = []
for i in lscSL:
    num = lsccSL.count(i)
    classesDataSL.append({
        'SuperClass':i,
        'Count':num
    })
classDBSL = pd.DataFrame(classesDataSL)
classDBSL
# Out:
#                                    SuperClass  Count
# 0                                  Benzenoids     39
# 1                 Homogeneous metal compounds      1
# 2             Homogeneous non-metal compounds      8
# 3                                Hydrocarbons      2
# 4   Lignans, neolignans and related compounds     20
# 5             Lipids and lipid-like molecules     83
# 6     Nucleosides, nucleotides, and analogues     67
# 7               Organic acids and derivatives    166
# 8                  Organic nitrogen compounds     14
# 9                    Organic oxygen compounds    150
# 10               Organoheterocyclic compounds    212
# 11           Phenylpropanoids and polyketides     30

# %%
mergedStuff = pd.merge(classDBSL, classDB, on=['SuperClass'], how='inner')
mergedStuff
# Out:
#                                   SuperClass  Count_x  Count_y
# 0                                 Benzenoids       39       41
# 1                               Hydrocarbons        2        3
# 2  Lignans, neolignans and related compounds       20        2
# 3            Lipids and lipid-like molecules       83      218
# 4    Nucleosides, nucleotides, and analogues       67       14
# 5              Organic acids and derivatives      166      356
# 6                 Organic nitrogen compounds       14       58
# 7                   Organic oxygen compounds      150       95
# 8               Organoheterocyclic compounds      212      121
# 9           Phenylpropanoids and polyketides       30        9

# %%
classDB.sort_values(by = ['Count'], ascending=False).to_csv("topclasses.csv")

# %%
# names

# %%
namesdf = resultsx[-resultsx['Name'].isna()]
namesdfO = namesdf.sort_values(by = ['Occurence'], ascending=False)

# %%
namesdfO[namesdfO['Occurence'] >= 3].to_csv("top_annotations.csv")

# %% [markdown]
# ## Suspect list tables and diagrams

# %%
sl = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/SuspectList/Use_This_CURATED_SUSPECT_LIST_with_classes_noDups.csv")

# %%
sl.drop_duplicates(subset = ["Name"])
# Out:
#      Unnamed: 0                                               Name  \
# 0             1                           N-Acetyl-L-glutamic acid
# 1             2                                     Threonic acid
# 2             3                                       L-citrulline
# 3             5                                       DL-HISTIDINE
# 4             6                                         DL-Leucine
# ..          ...                                                ...
# 898         948                            (2E,4Z)-octa-2,4-dienal
# 899         949                                                NaN
# 900         950  cobalt(2+);3-[7,13,17-tris(2-carboxyethyl)-3,8...
# 901         951  7,8-dimethyl-4-oxo-10-(2,3,4,5-tetrahydroxypen...
# 902         952  6,7-dimethyl-4-oxo-8-(2,3,4,5-tetrahydroxypent...
#
#            Formula      Species  \
# 0         C7H11NO5   S. marinoi
# 1           C4H8O5   S. marinoi
# 2        C6H13N3O3  S. costatum
# 3         C6H9N3O2  S. costatum
# 4         C6H13NO2  S. costatum
# ..             ...          ...
# 898         C8H12O  S .costatum
# 899       C40H56O5  S .costatum
# 900  C42H44CoN4O16  S .costatum
# 901    C17H19N4O6-  S .costatum
# 902    C13H17N4O6-  S .costatum
#
#                                                 SMILES  \
# 0                        CC(=O)N[C@@H](CCC(=O)O)C(=O)O
# 1                                   C(C(C(C(=O)O)O)O)O
# 2                          C(C[C@@H](C(=O)O)N)CNC(=O)N
# 3                                NC(Cc1c[nH]cn1)C(O)=O
# 4                                     CC(C)CC(N)C(O)=O
# ..                                                 ...
# 898                                    CCC/C=C\C=C\C=O
# 899  CC(=CC=CC=C(C)C=CC=C(C)C(=O)CC12C(CC(CC1(O2)C)...
# 900  CC1(C(C2=NC1=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(=C...
# 901  CC1=CC2=C(C=C1C)N(C3=NC(=NC(=O)C3=N2)[O-])CC(C...
# 902  CC1=C(N(C2=NC(=NC(=O)C2=N1)[O-])CC(C(C(CO)O)O)O)C
#
#                                                  InChI  Monoisotopic_mass  \
# 0    InChI=1S/C7H11NO5/c1-4(9)8-5(7(12)13)2-3-6(10)...         189.063722
# 1    InChI=1S/C4H8O5/c5-1-2(6)3(7)4(8)9/h2-3,5-7H,1...         136.037173
# 2    InChI=1S/C6H13N3O3/c7-4(5(10)11)2-1-3-9-6(8)12...         175.095691
# 3    InChI=1S/C6H9N3O2/c7-5(6(10)11)1-4-2-8-3-9-4/h...         155.069477
# 4    InChI=1S/C6H13NO2/c1-4(2)3-5(7)6(8)9/h4-5H,3,7...         131.094629
# ..                                                 ...                ...
# 898  InChI=1S/C8H12O/c1-2-3-4-5-6-7-8-9/h4-8H,2-3H2...         124.088815
# 899  InChI=1S/C40H56O5/c1-28(17-13-18-30(3)21-22-35...         616.412775
# 900  InChI=1S/C42H46N4O16.Co/c1-41(17-39(59)60)23(5...         919.208425
# 901  InChI=1S/C17H20N4O6/c1-7-3-9-10(4-8(7)2)21(5-1...         375.130459
# 902  InChI=1S/C13H18N4O6/c1-5-6(2)17(3-7(19)10(21)8...         325.114809
#
#          ChEBIid  KEGGid   PubChemId  ...  \
# 0    CHEBI:44337  C00624     70914.0  ...
# 1    CHEBI:26984     NaN    439535.0  ...
# 2    CHEBI:16349  C00327      9750.0  ...
# 3    CHEBI:27570     NaN       773.0  ...
# 4    CHEBI:25017     NaN       857.0  ...
# ..           ...     ...         ...  ...
# 898          NaN     NaN   5352875.0  ...
# 899          NaN     NaN    607588.0  ...
# 900          NaN     NaN  75144734.0  ...
# 901          NaN     NaN    122171.0  ...
# 902          NaN     NaN  25244683.0  ...
#
#                                                 Source  \
# 0    Vidoudez C, Pohnert G. Comparative metabolomic...
# 1    Vidoudez C, Pohnert G. Comparative metabolomic...
# 2    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# 3    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# 4    Brown, M.R., Jeffrey, S.W. The amino acid and ...
# ..                                                 ...
# 898                                                NaN
# 899                                                NaN
# 900                                                NaN
# 901                                                NaN
# 902                                                NaN
#
#     nonIsomeric_SMILES_byRDKit  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 898                        NaN
# 899                        NaN
# 900                        NaN
# 901                        NaN
# 902                        NaN
#
#                                                  iupac  \
# 0                    (2S)-2-acetamidopentanedioic acid
# 1                        2,3,4-trihydroxybutanoic acid
# 2        (2S)-2-amino-5-(carbamoylamino)pentanoic acid
# 3           2-amino-3-(1H-imidazol-5-yl)propanoic acid
# 4                       2-amino-4-methylpentanoic acid
# ..                                                 ...
# 898                            (2E,4Z)-octa-2,4-dienal
# 899                                                NaN
# 900  cobalt(2+);3-[7,13,17-tris(2-carboxyethyl)-3,8...
# 901  7,8-dimethyl-4-oxo-10-(2,3,4,5-tetrahydroxypen...
# 902  6,7-dimethyl-4-oxo-8-(2,3,4,5-tetrahydroxypent...
#
#                                               synonyms  \
# 0    ['N-Acetyl-L-glutamic acid', '1188-37-0', 'ace...
# 1                                                  NaN
# 2    ['L-citrulline', 'citrulline', '372-75-8', 'H-...
# 3    ['DL-HISTIDINE', '4998-57-6', 'H-DL-His-OH', '...
# 4    ['DL-Leucine', '328-39-2', 'H-DL-Leu-OH', '2-A...
# ..                                                 ...
# 898  ['2E,4Z-Octadienal', '2,4-Octadienal, (E,Z)-',...
# 899                                                 []
# 900                                                 []
# 901  ['Fad semiquinone', '35919-91-6', '7,8-dimethy...
# 902                                                 []
#
#                             PubChemPY correct_Name Molecular mass  \
# 0                   checked; NEW name          NaN         189.17
# 1            checked; structure added          NaN         136.10
# 2                   checked; NEW name          NaN         175.19
# 3                   checked; NEW name          NaN         155.15
# 4                   checked; NEW name          NaN         131.17
# ..                                ...          ...            ...
# 898              added with PubChemPY          NaN         124.18
# 899  KekulizedSMILES with a PubChemid          NaN         616.90
# 900  KekulizedSMILES with a PubChemid          NaN         919.70
# 901  KekulizedSMILES with a PubChemid          NaN         375.40
# 902  KekulizedSMILES with a PubChemid          NaN         325.30
#
#                                       subclass  \
# 0         Amino acids, peptides, and analogues
# 1    Carbohydrates and carbohydrate conjugates
# 2         Amino acids, peptides, and analogues
# 3         Amino acids, peptides, and analogues
# 4         Amino acids, peptides, and analogues
# ..                                         ...
# 898                         Carbonyl compounds
# 899                            Tetraterpenoids
# 900                                        NaN
# 901             Alloxazines and isoalloxazines
# 902                                        NaN
#
#                                 class                       superclass
# 0    Carboxylic acids and derivatives    Organic acids and derivatives
# 1              Organooxygen compounds         Organic oxygen compounds
# 2    Carboxylic acids and derivatives    Organic acids and derivatives
# 3    Carboxylic acids and derivatives    Organic acids and derivatives
# 4    Carboxylic acids and derivatives    Organic acids and derivatives
# ..                                ...                              ...
# 898            Organooxygen compounds         Organic oxygen compounds
# 899                     Prenol lipids  Lipids and lipid-like molecules
# 900                               NaN                              NaN
# 901        Pteridines and derivatives     Organoheterocyclic compounds
# 902                               NaN                              NaN
#
# [885 rows x 21 columns]

# %%
sl.to_csv("/Users/mahnoorzulfiqar/OneDriveUNI/SuspectList/final_SUSPECT_LIST.csv")

# %%
cl = pd.read_csv("Final_Candidate_List.csv")

# %%
np.unique(list(cl["Annotation_Source"]))
# Out:
# array(['GNPS', 'GNPS, HMDB', 'GNPS, HMDB, MassBank, SuspectList',
#        'GNPS, HMDB, SuspectList', 'GNPS, MassBank',
#        'GNPS, MassBank, SuspectList', 'GNPS, SuspectList', 'HMDB',
#        'HMDB, SuspectList', 'KEGG', 'MassBank', 'MassBank, SuspectList',
#        'PubChem', 'SIRIUS', 'SIRIUS, SuspectList', 'SIRIUS_Formula',
#        'nan'], dtype='<U33')

# %%
sus = ['SIRIUS, SuspectList', 'MassBank, SuspectList', 'HMDB, SuspectList', 'GNPS, SuspectList', 'GNPS, MassBank, SuspectList',
           'GNPS, HMDB, SuspectList', 'GNPS, HMDB, MassBank, SuspectList']

# %%
cl_sus = cl[cl.Annotation_Source.str.contains("SuspectList", na=False)]
cl_sus
# Out:
#       Unnamed: 0  Unnamed: 0.1           id_X       premz       rtmed  \
# 906          127           127  M478R494ID128  478.138794  493.830636
# 940          211           211   M295R286ID78  294.993073  285.663291
# 964          263           263  M260R340ID130  260.105377  339.764136
# 970          274           274  M412R358ID141  412.206726  357.934938
# 982          297           297  M117R385ID164  117.066879  385.346490
# 985          302           302  M130R388ID169  130.085419  387.608724
# 986          303           303  M136R388ID170  136.074829  387.986094
# 1004         335           335  M481R425ID202  481.146362  425.143812
# 1018         373           373  M169R475ID240  169.057724  474.696828
# 1030         401           401  M189R696ID268  189.159622  695.909820
# 1092         572           572    M300R57ID30  299.776184   56.683998
# 1118         630           630    M347R43ID17  347.095490   43.351854
# 1169         744           744   M235R125ID60  234.819931  125.179665
# 1170         746           746   M229R161ID62  229.048645  160.553796
# 1182         774           774    M475R44ID19  475.182739   44.160019
# 1199         810           810   M380R103ID55  379.908966  102.709254
# 1204         822           822   M147R335ID67  146.966125  334.790082
# 1205         825           825   M276R392ID70  275.905884  391.575396
# 1207         835           835     M273R40ID9  272.883209   39.648636
# 1241         906           906     M274R39ID9  273.890900   39.497924
# 1274         982           982    M301R43ID16  301.217468   42.857672
# 1338        1137          1137    M641R45ID31  641.419678   44.896534
# 1351        1193          1193    M301R36ID12  300.920258   35.646046
# 1355        1200          1200    M313R39ID19  313.273621   39.189277
# 1375        1236          1236    M233R99ID55  232.987411   98.760984
# 1384        1262          1262     M273R33ID6  272.902649   32.965653
# 1394        1281          1281    M412R42ID25  412.207214   42.043459
# 1417        1332          1332      M89R30ID1   89.008263   30.179792
# 1420        1338          1338     M115R33ID7  114.964043   33.323160
# 1421        1339          1339     M160R34ID8  159.969177   33.801138
# 1437        1370          1370    M581R49ID39  581.398560   48.951167
# 1451        1400          1400   M175R355ID69  175.118896  355.321998
# 1473        1444          1444    M323R48ID38  323.221344   48.436699
# 1487        1467          1467   M157R138ID61  157.096939  138.492108
# 1493        1473          1473   M104R324ID67  104.106819  324.328362
# 1494        1480          1480   M102R401ID74  102.033852  401.174970
# 1499        1490          1490     M491R34ID9  490.816895   34.273788
# 1529        1576          1576    M309R40ID20  309.242401   39.725934
# 1537        1586          1586    M581R44ID30  581.398682   44.444157
# 1538        1589          1589    M408R46ID33  408.307220   45.987782
# 1583        1690          1690   M130R129ID60  130.086197  129.334314
# 1590        1799          1799    M285R40ID20  285.242523   40.311145
# 1615        1845          1845   M132R259ID66  132.102203  259.022496
#
#                int  col_eng  pol     Formula  \
# 906   0.000000e+00       30  neg         NaN
# 940   0.000000e+00       30  pos         NaN
# 964   0.000000e+00       30  pos         NaN
# 970   0.000000e+00       30  pos  MB_Formula
# 982   0.000000e+00       30  pos         NaN
# 985   0.000000e+00       30  pos    C6H11NO2
# 986   0.000000e+00       30  pos  MB_Formula
# 1004  0.000000e+00       30  pos  MB_Formula
# 1018  0.000000e+00       30  pos         NaN
# 1030  0.000000e+00       30  pos   C9H20N2O2
# 1092  2.383584e+06       30  neg         NaN
# 1118  6.291711e+05       30  neg  MB_Formula
# 1169  2.748721e+06       30  neg         NaN
# 1170  1.079435e+08       30  neg         NaN
# 1182  2.171902e+06       30  neg  MB_Formula
# 1199  2.465848e+06       30  neg  MB_Formula
# 1204  4.578593e+06       30  neg         NaN
# 1205  1.332907e+08       30  neg  MB_Formula
# 1207  2.235766e+07       30  neg  MB_Formula
# 1241  2.289700e+07       30  neg  MB_Formula
# 1274  2.757158e+06       30  neg  MB_Formula
# 1338  4.671771e+07       30  pos    C42H56O5
# 1351  1.221155e+06       30  pos         NaN
# 1355  1.574841e+07       30  pos    C19H36O3
# 1375  1.952314e+07       30  pos         NaN
# 1384  1.167646e+07       30  pos  MB_Formula
# 1394  9.134058e+05       30  pos         NaN
# 1417  0.000000e+00       30  pos         NaN
# 1420  3.045318e+07       30  pos  MB_Formula
# 1421  3.788796e+06       30  pos         NaN
# 1437  8.185866e+07       30  pos    C40H52O3
# 1451  1.500252e+07       30  pos  MB_Formula
# 1473  2.384984e+06       30  pos    C19H30O4
# 1487  1.642288e+07       30  pos         NaN
# 1493  7.287891e+07       30  pos     C5H13NO
# 1494  4.595035e+07       30  pos         NaN
# 1499  0.000000e+00       30  pos  MB_Formula
# 1529  8.779878e+06       30  pos    C19H32O3
# 1537  6.808519e+07       30  pos    C40H52O3
# 1538  1.162841e+06       30  pos  MB_Formula
# 1583  2.904768e+07       30  pos    C6H11NO2
# 1590  1.017634e+07       30  pos    C17H32O3
# 1615  1.562095e+07       30  pos  MB_Formula
#
#                                             MCSS_SMILES  ...  \
# 906                                                 NaN  ...
# 940                                                 NaN  ...
# 964                                                 NaN  ...
# 970                                                 NaN  ...
# 982                                                 NaN  ...
# 985                                        CCC(N)C(=O)O  ...
# 986                                                 NaN  ...
# 1004                                                NaN  ...
# 1018                                                NaN  ...
# 1030                                     CCCCC(N)C(=O)O  ...
# 1092                                                NaN  ...
# 1118                                                NaN  ...
# 1169                                                NaN  ...
# 1170                                                NaN  ...
# 1182                                                NaN  ...
# 1199                                                NaN  ...
# 1204                                                NaN  ...
# 1205                                                NaN  ...
# 1207                                                NaN  ...
# 1241                                                NaN  ...
# 1274                                                NaN  ...
# 1338                CC(C)=CC=CC(C)=CC=CC=C(C)C=CC=C(C)C  ...
# 1351                                                NaN  ...
# 1355                              CCCCCCCCCCCCCCCC(=O)O  ...
# 1375                                                NaN  ...
# 1384                                                NaN  ...
# 1394                                                NaN  ...
# 1417                                                NaN  ...
# 1420                                                NaN  ...
# 1421                                                NaN  ...
# 1437  CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=CC=C(C)C=C...  ...
# 1451                                                NaN  ...
# 1473                                           CCCCCCCO  ...
# 1487                                                NaN  ...
# 1493                                            CCN(C)C  ...
# 1494                                                NaN  ...
# 1499                                                NaN  ...
# 1529                                      CC=CCCCCCCCCC  ...
# 1537                          CC=CC=CC=CC=CC=CC(C)=CCCC  ...
# 1538                                                NaN  ...
# 1583                                         CCCCC(=O)O  ...
# 1590                             CCCCCCCCCCCCCCCCC(=O)O  ...
# 1615                                                NaN  ...
#
#                          level _5                                    subclass  \
# 906                           NaN        Amino acids, peptides, and analogues
# 940                           NaN        Amino acids, peptides, and analogues
# 964                           NaN                                         NaN
# 970                           NaN        Amino acids, peptides, and analogues
# 982                           NaN        Amino acids, peptides, and analogues
# 985   Amino acids and derivatives        Amino acids, peptides, and analogues
# 986                           NaN                             Tetraterpenoids
# 1004                          NaN    Indolyl carboxylic acids and derivatives
# 1018                          NaN        Amino acids, peptides, and analogues
# 1030  Amino acids and derivatives        Amino acids, peptides, and analogues
# 1092                          NaN  Medium-chain hydroxy acids and derivatives
# 1118                          NaN        Amino acids, peptides, and analogues
# 1169                          NaN        Amino acids, peptides, and analogues
# 1170                          NaN        Amino acids, peptides, and analogues
# 1182                          NaN   Carbohydrates and carbohydrate conjugates
# 1199                          NaN        Amino acids, peptides, and analogues
# 1204                          NaN                                         NaN
# 1205                          NaN        Amino acids, peptides, and analogues
# 1207                          NaN        Amino acids, peptides, and analogues
# 1241                          NaN   Carbohydrates and carbohydrate conjugates
# 1274                          NaN        Amino acids, peptides, and analogues
# 1338                  Carotenoids                             Tetraterpenoids
# 1351                          NaN        Amino acids, peptides, and analogues
# 1355            Monoacylglycerols                          Monoradylglycerols
# 1375                          NaN   Carbohydrates and carbohydrate conjugates
# 1384                          NaN        Amino acids, peptides, and analogues
# 1394                          NaN               Benzoic acids and derivatives
# 1417                          NaN        Amino acids, peptides, and analogues
# 1420                          NaN        Amino acids, peptides, and analogues
# 1421                          NaN        Amino acids, peptides, and analogues
# 1437                  Carotenoids                             Tetraterpenoids
# 1451                          NaN                                         NaN
# 1473                          NaN                          Monoradylglycerols
# 1487                          NaN                          Monoradylglycerols
# 1493                     Cholines                   Quaternary ammonium salts
# 1494                          NaN        Amino acids, peptides, and analogues
# 1499                          NaN        Amino acids, peptides, and analogues
# 1529                          NaN              Lineolic acids and derivatives
# 1537                  Carotenoids                             Tetraterpenoids
# 1538                          NaN                  Fatty acids and conjugates
# 1583  Amino acids and derivatives        Amino acids, peptides, and analogues
# 1590            Monoacylglycerols                          Monoradylglycerols
# 1615                          NaN        Amino acids, peptides, and analogues
#
#                                     class  \
# 906      Carboxylic acids and derivatives
# 940      Carboxylic acids and derivatives
# 964                    Purine nucleosides
# 970      Carboxylic acids and derivatives
# 982      Carboxylic acids and derivatives
# 985      Carboxylic acids and derivatives
# 986                         Prenol lipids
# 1004              Indoles and derivatives
# 1018     Carboxylic acids and derivatives
# 1030     Carboxylic acids and derivatives
# 1092        Hydroxy acids and derivatives
# 1118     Carboxylic acids and derivatives
# 1169     Carboxylic acids and derivatives
# 1170     Carboxylic acids and derivatives
# 1182               Organooxygen compounds
# 1199     Carboxylic acids and derivatives
# 1204                   Flavin nucleotides
# 1205     Carboxylic acids and derivatives
# 1207     Carboxylic acids and derivatives
# 1241               Organooxygen compounds
# 1274     Carboxylic acids and derivatives
# 1338                        Prenol lipids
# 1351     Carboxylic acids and derivatives
# 1355                        Glycerolipids
# 1375               Organooxygen compounds
# 1384     Carboxylic acids and derivatives
# 1394  Benzene and substituted derivatives
# 1417     Carboxylic acids and derivatives
# 1420     Carboxylic acids and derivatives
# 1421     Carboxylic acids and derivatives
# 1437                        Prenol lipids
# 1451                   Purine nucleosides
# 1473                        Glycerolipids
# 1487                        Glycerolipids
# 1493             Organonitrogen compounds
# 1494     Carboxylic acids and derivatives
# 1499     Carboxylic acids and derivatives
# 1529                          Fatty Acyls
# 1537                        Prenol lipids
# 1538                          Fatty Acyls
# 1583     Carboxylic acids and derivatives
# 1590                        Glycerolipids
# 1615     Carboxylic acids and derivatives
#
#                                    superclass  \
# 906             Organic acids and derivatives
# 940             Organic acids and derivatives
# 964   Nucleosides, nucleotides, and analogues
# 970             Organic acids and derivatives
# 982             Organic acids and derivatives
# 985             Organic acids and derivatives
# 986           Lipids and lipid-like molecules
# 1004             Organoheterocyclic compounds
# 1018            Organic acids and derivatives
# 1030            Organic acids and derivatives
# 1092            Organic acids and derivatives
# 1118            Organic acids and derivatives
# 1169            Organic acids and derivatives
# 1170            Organic acids and derivatives
# 1182                 Organic oxygen compounds
# 1199            Organic acids and derivatives
# 1204  Nucleosides, nucleotides, and analogues
# 1205            Organic acids and derivatives
# 1207            Organic acids and derivatives
# 1241                 Organic oxygen compounds
# 1274            Organic acids and derivatives
# 1338          Lipids and lipid-like molecules
# 1351            Organic acids and derivatives
# 1355          Lipids and lipid-like molecules
# 1375                 Organic oxygen compounds
# 1384            Organic acids and derivatives
# 1394                               Benzenoids
# 1417            Organic acids and derivatives
# 1420            Organic acids and derivatives
# 1421            Organic acids and derivatives
# 1437          Lipids and lipid-like molecules
# 1451  Nucleosides, nucleotides, and analogues
# 1473          Lipids and lipid-like molecules
# 1487          Lipids and lipid-like molecules
# 1493               Organic nitrogen compounds
# 1494            Organic acids and derivatives
# 1499            Organic acids and derivatives
# 1529          Lipids and lipid-like molecules
# 1537          Lipids and lipid-like molecules
# 1538          Lipids and lipid-like molecules
# 1583            Organic acids and derivatives
# 1590          Lipids and lipid-like molecules
# 1615            Organic acids and derivatives
#
#                                     all_classifications KG_MCSS_SMILES  \
# 906                                                 NaN            NaN
# 940                                                 NaN            NaN
# 964                                                 NaN            NaN
# 970                                                 NaN            NaN
# 982                                                 NaN            NaN
# 985   Organic compounds; Lipids and lipid-like molec...            NaN
# 986                                                 NaN            NaN
# 1004                                                NaN            NaN
# 1018                                                NaN            NaN
# 1030  Organic compounds; Lipids and lipid-like molec...            NaN
# 1092                                                NaN            NaN
# 1118                                                NaN            NaN
# 1169                                                NaN            NaN
# 1170                                                NaN            NaN
# 1182                                                NaN            NaN
# 1199                                                NaN            NaN
# 1204                                                NaN            NaN
# 1205                                                NaN            NaN
# 1207                                                NaN            NaN
# 1241                                                NaN            NaN
# 1274                                                NaN            NaN
# 1338  Organic compounds; Organoheterocyclic compound...            NaN
# 1351                                                NaN            NaN
# 1355  Organic compounds; Lipids and lipid-like molec...            NaN
# 1375                                                NaN            NaN
# 1384                                                NaN            NaN
# 1394                                                NaN            NaN
# 1417                                                NaN            NaN
# 1420                                                NaN            NaN
# 1421                                                NaN            NaN
# 1437  Organic compounds; Lipids and lipid-like molec...            NaN
# 1451                                                NaN            NaN
# 1473  Organic compounds; Lipids and lipid-like molec...            NaN
# 1487                                                NaN            NaN
# 1493  Organic compounds; Alcohols and polyols; Organ...            NaN
# 1494                                                NaN            NaN
# 1499                                                NaN            NaN
# 1529  Organic compounds; Lipids and lipid-like molec...            NaN
# 1537  Organic compounds; Organoheterocyclic compound...            NaN
# 1538                                                NaN            NaN
# 1583  Organic compounds; Amino acids, peptides, and ...            NaN
# 1590  Organic compounds; Lipids and lipid-like molec...            NaN
# 1615                                                NaN            NaN
#
#      PC_MCSS_SMILES                  Annotation_Source  \
# 906             NaN                  GNPS, SuspectList
# 940             NaN                  HMDB, SuspectList
# 964             NaN                  HMDB, SuspectList
# 970             NaN        GNPS, MassBank, SuspectList
# 982             NaN                  GNPS, SuspectList
# 985             NaN                SIRIUS, SuspectList
# 986             NaN              MassBank, SuspectList
# 1004            NaN              MassBank, SuspectList
# 1018            NaN                  GNPS, SuspectList
# 1030            NaN                SIRIUS, SuspectList
# 1092            NaN                  GNPS, SuspectList
# 1118            NaN              MassBank, SuspectList
# 1169            NaN                  GNPS, SuspectList
# 1170            NaN                  GNPS, SuspectList
# 1182            NaN              MassBank, SuspectList
# 1199            NaN  GNPS, HMDB, MassBank, SuspectList
# 1204            NaN                  HMDB, SuspectList
# 1205            NaN        GNPS, MassBank, SuspectList
# 1207            NaN              MassBank, SuspectList
# 1241            NaN              MassBank, SuspectList
# 1274            NaN              MassBank, SuspectList
# 1338            NaN                SIRIUS, SuspectList
# 1351            NaN                  GNPS, SuspectList
# 1355            NaN                SIRIUS, SuspectList
# 1375            NaN                  GNPS, SuspectList
# 1384            NaN        GNPS, MassBank, SuspectList
# 1394            NaN                  GNPS, SuspectList
# 1417            NaN            GNPS, HMDB, SuspectList
# 1420            NaN              MassBank, SuspectList
# 1421            NaN                  GNPS, SuspectList
# 1437            NaN                SIRIUS, SuspectList
# 1451            NaN              MassBank, SuspectList
# 1473            NaN                SIRIUS, SuspectList
# 1487            NaN                  GNPS, SuspectList
# 1493            NaN                SIRIUS, SuspectList
# 1494            NaN                  HMDB, SuspectList
# 1499            NaN              MassBank, SuspectList
# 1529            NaN                SIRIUS, SuspectList
# 1537            NaN                SIRIUS, SuspectList
# 1538            NaN  GNPS, HMDB, MassBank, SuspectList
# 1583            NaN                SIRIUS, SuspectList
# 1590            NaN                SIRIUS, SuspectList
# 1615            NaN              MassBank, SuspectList
#
#                                            SMILES_final Classification_Source
# 906                           CC[C@H](C)[C@@H](C(=O)O)N            ClassyFire
# 940                                  O=C(O)[C@@H]1CCCN1            ClassyFire
# 964   Nc1nc2c(ncn2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)...            ClassyFire
# 970                       C1=CC=C(C=C1)C[C@@H](C(=O)O)N            ClassyFire
# 982                            C([C@@H](C(=O)O)N)C(=O)O            ClassyFire
# 985                                  CC(C)CC(C(=O)O)[N]               CANOPUS
# 986   CC1=C(C(CCC1=O)(C)C)/C=C/C(=C/C=C/C(=C/C=C/C=C...            ClassyFire
# 1004              C1=CC=C2C(=C1)C(=CN2)C[C@@H](C(=O)O)N            ClassyFire
# 1018                                NCCCC[C@H](N)C(O)=O            ClassyFire
# 1030                          C[N+](C)(C)CCCCC(C(=O)O)N               CANOPUS
# 1092                         C(C(C(C(C(C(=O)O)O)O)O)O)O            ClassyFire
# 1118                           C1=CC=C(C=C1)CC(C(=O)O)N            ClassyFire
# 1169                             C1CC(=O)N[C@@H]1C(=O)O            ClassyFire
# 1170                     C1=CC(=CC=C1C[C@@H](C(=O)O)N)O            ClassyFire
# 1182  C([C@@H]1[C@@H]([C@@H]([C@H]([C@@H](O1)O[C@@H]...            ClassyFire
# 1199                                    C1CC(NC1)C(=O)O            ClassyFire
# 1204  Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(C[C@H](O)[C@H](O)...            ClassyFire
# 1205                             C(CC(C(=O)O)N)CN=C(N)N            ClassyFire
# 1207                             CC1=NCC[C@H](N1)C(=O)O            ClassyFire
# 1241        C(C1C(C(C(C(O1)OC2C(OC(C(C2O)O)O)CO)O)O)O)O            ClassyFire
# 1274                        C(C[C@@H](C(=O)O)N)CN=C(N)N            ClassyFire
# 1338  CC(=CC=CC=C(C)C=CC=C(C)C#CC12C(CC(CC1(O2)C)O)(...               CANOPUS
# 1351                          C(CC(=O)O)[C@@H](C(=O)O)N            ClassyFire
# 1355                        CCCCCCCCCCCCCCCC(=O)OCC1CO1               CANOPUS
# 1375  [C@@H]([C@@H]([C@H](C(=O)O)O)O)([C@@H](C(=O)O)O)O            ClassyFire
# 1384                          C1=CC(=CC=C1CC(C(=O)O)N)O            ClassyFire
# 1394                          C1=CC(=C(C(=C1)O)N)C(=O)O            ClassyFire
# 1417                                     CSCCC(N)C(=O)O            ClassyFire
# 1420                             C(CCN)C[C@@H](C(=O)O)N            ClassyFire
# 1421                              C[N+](C)(C)CC(=O)[O-]            ClassyFire
# 1437  CC1=C(C(CCC1=O)(C)C)C=CC(=CC=CC(=CC=CC=C(C)C=C...               CANOPUS
# 1451  C1=NC(=C2C(=N1)N(C=N2)[C@H]3[C@@H]([C@@H]([C@H...            ClassyFire
# 1473            CCOC(=O)CCCCC(=O)OCC12CC3CC(C1)CC(C3)C2               CANOPUS
# 1487                       CCCCCCCCCCCCCCCC(=O)OCC(CO)O            ClassyFire
# 1493                                     C[N+](C)(C)CCO               CANOPUS
# 1494                                     O=C(O)C1CCC=N1            ClassyFire
# 1499                          C(CC(=O)N)[C@@H](C(=O)O)N            ClassyFire
# 1529                     CCCCCC=CC=CC(=O)CCCCCCCCC(=O)O               CANOPUS
# 1537  CC1=C(CCC(C1=CC=C(C)C=CC=C(C)C=CC(=O)C=C(C)C=C...               CANOPUS
# 1538           CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCC(=O)O            ClassyFire
# 1583                                   C1CCNC(C1)C(=O)O               CANOPUS
# 1590                         CCCCCCCCCCC(=O)CCCCCC(=O)O               CANOPUS
# 1615                               C(CC(=O)O)C(C(=O)O)N            ClassyFire
#
# [43 rows x 21 columns]

# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem

# %%
x = []
y = []
for i, row in cl_sus.iterrows():
    for j, rows in sl.iterrows():
        SKms = [Chem.MolFromSmiles(cl_sus['SMILES_final'][i]), Chem.MolFromSmiles(sl['SMILES'][j])]
        SKfps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in SKms]
        SKtn = DataStructs.FingerprintSimilarity(SKfps[0],SKfps[1])
        if SKtn == 1:
            sl.loc[j, "premz"] = cl_sus['premz'][i]
            sl.loc[j, "rtmed"] = cl_sus['rtmed'][i]
            sl.loc[j, "Annotation_Source"] = cl_sus['Annotation_Source'][i]
            x.append(j)#for suspect list
            y.append(i)# for features
print(x)
print(y)
# Out:
# [14, 15, 892, 17, 867, 862, 7, 5, 308, 17, 189, 321, 11, 80, 15, 851, 403, 530, 80, 403, 9, 297, 592, 11, 373, 870, 5, 731, 889, 84, 694, 784, 868, 97, 9, 297]
# [906, 940, 964, 970, 982, 986, 1004, 1018, 1092, 1118, 1169, 1169, 1170, 1182, 1199, 1204, 1205, 1207, 1241, 1274, 1351, 1351, 1375, 1384, 1394, 1417, 1420, 1421, 1451, 1487, 1493, 1494, 1499, 1538, 1615, 1615]

# %%
s = sl.loc[x, :]
s = s.drop_duplicates(subset = ["Name"])
s[['premz', 'rtmed', 'Name', 'Species', 'SMILES', 'Annotation_Source', 'subclass']].to_csv("SuspectListCandidates.csv")

# %%
#### chemical similarity network

# %%
###Extract information only about SMILES, Names and INdex in the suspect list
ava = []
for index, row in sl.iterrows():
    ava.append({
        'Name':sl['Name'][index],
        'SMILES':sl['SMILES'][index],
        'Subclass':sl["subclass"][index],
        'Class':sl["class"][index],
        'Superclass':sl["superclass"][index]
            })
av = pd.DataFrame(ava)
av = av.drop_duplicates(subset = ["Name"])

# %%
av
# Out:
#                                                   Name  \
# 0                             N-Acetyl-L-glutamic acid
# 1                                       Threonic acid
# 2                                         L-citrulline
# 3                                         DL-HISTIDINE
# 4                                           DL-Leucine
# ..                                                 ...
# 898                            (2E,4Z)-octa-2,4-dienal
# 899                                                NaN
# 900  cobalt(2+);3-[7,13,17-tris(2-carboxyethyl)-3,8...
# 901  7,8-dimethyl-4-oxo-10-(2,3,4,5-tetrahydroxypen...
# 902  6,7-dimethyl-4-oxo-8-(2,3,4,5-tetrahydroxypent...
#
#                                                 SMILES  \
# 0                        CC(=O)N[C@@H](CCC(=O)O)C(=O)O
# 1                                   C(C(C(C(=O)O)O)O)O
# 2                          C(C[C@@H](C(=O)O)N)CNC(=O)N
# 3                                NC(Cc1c[nH]cn1)C(O)=O
# 4                                     CC(C)CC(N)C(O)=O
# ..                                                 ...
# 898                                    CCC/C=C\C=C\C=O
# 899  CC(=CC=CC=C(C)C=CC=C(C)C(=O)CC12C(CC(CC1(O2)C)...
# 900  CC1(C(C2=NC1=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(=C...
# 901  CC1=CC2=C(C=C1C)N(C3=NC(=NC(=O)C3=N2)[O-])CC(C...
# 902  CC1=C(N(C2=NC(=NC(=O)C2=N1)[O-])CC(C(C(CO)O)O)O)C
#
#                                       Subclass  \
# 0         Amino acids, peptides, and analogues
# 1    Carbohydrates and carbohydrate conjugates
# 2         Amino acids, peptides, and analogues
# 3         Amino acids, peptides, and analogues
# 4         Amino acids, peptides, and analogues
# ..                                         ...
# 898                         Carbonyl compounds
# 899                            Tetraterpenoids
# 900                                        NaN
# 901             Alloxazines and isoalloxazines
# 902                                        NaN
#
#                                 Class                       Superclass
# 0    Carboxylic acids and derivatives    Organic acids and derivatives
# 1              Organooxygen compounds         Organic oxygen compounds
# 2    Carboxylic acids and derivatives    Organic acids and derivatives
# 3    Carboxylic acids and derivatives    Organic acids and derivatives
# 4    Carboxylic acids and derivatives    Organic acids and derivatives
# ..                                ...                              ...
# 898            Organooxygen compounds         Organic oxygen compounds
# 899                     Prenol lipids  Lipids and lipid-like molecules
# 900                               NaN                              NaN
# 901        Pteridines and derivatives     Organoheterocyclic compounds
# 902                               NaN                              NaN
#
# [885 rows x 5 columns]

# %%
dbn= []
for i, row in av.iterrows():
    for j, row in av.iterrows():
        if av['SMILES'][i] != av['SMILES'][j]:
            ms = [Chem.MolFromSmiles(av['SMILES'][i]), Chem.MolFromSmiles(av['SMILES'][j])]
            fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=1024) for x in ms]
            tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])
            dbn.append({
                'Namei':sl['Name'][i],
                'Namej':sl['Name'][j],
                'i': sl['SMILES'][i],
                'j': sl['SMILES'][j],
                'Subclassi':sl["subclass"][i],
                'Classi':sl["class"][i],
                'Superclassi':sl["superclass"][i],
                'Subclassj':sl["subclass"][j],
                'Classj':sl["class"][j],
                'Superclassj':sl["superclass"][j],
                'Tanimoto': tn
            })
db_edge = pd.DataFrame(dbn)

# %%
db_edge.to_csv("edges.csv")
