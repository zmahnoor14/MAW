# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
from rdkit.Chem import rdFMCS
from rdkit.Chem import PandasTools

import sys

import pandas as pd

import pubchempy as pcp
import numpy as np


import os
import glob
import re

# %%
input_dir = '/Users/mahnoorzulfiqar/OneDriveUNI/CondaCheck/'
# read the suspect list
slistcsv = "/Users/mahnoorzulfiqar/OneDriveUNI/CondaCheck/SkeletonemaSuspectListV1.csv"
# read input_table.csv generated in the R workflow
input_tablecsv = input_dir + "input_table.csv"
sl = True

# %%
    heavy_atoms = ['C', 'N', 'P', 'O', 'S']

    input_table = pd.read_csv(input_tablecsv)

        for m, row in input_table.iterrows():

        # Result directory
        result = input_dir + (input_table['ResultFileNames'][m] + 
                                 '/insilico/MetFrag').replace("./", "")

        # list of all the csv files in the result directory result_dir/inislico/MetFrag/
        files_met = (glob.glob(result+'/*.csv'))

        # read the csv file that contains all the features from the input .mzml file
        file1  = pd.read_csv(input_dir + (input_table['ResultFileNames'][m] + '/insilico/MS1DATA.csv').replace("./", ""))

        # for each feature in the MS1DATA.csv file
        for i, row in file1.iterrows():

            # take id as a pattern to differentiate between different ids
            pattern = file1.loc[i, "id_X"]

            #check which of the csv result files have the same pattern in their names
            results = [i for i in files_met if pattern in i]

            # find which of the files with that id have KEGG in their names,
            KEGG = [i for i in results if "KEGG" in i]

            # if kegg present in the name
            if KEGG:

                # read the KEGG csv file for that feature
                KEGG_file = pd.read_csv((KEGG)[0])

                # if the KEGG file isn't empty
                if len(KEGG_file) >= 1:

                    # extract only the columns with >0.75 score
                    KEGG_file = KEGG_file.drop(KEGG_file[KEGG_file.Score < 0.75].index)
                    print(KEGG_file)

                    if len(KEGG_file) >= 1:

                        # add the relavnt information to the original MS1DATA csv
                        file1.loc[i, 'KG_ID'] = KEGG_file.loc[0, 'Identifier']
                        file1.loc[i, 'KG_Name'] = KEGG_file.loc[0, 'CompoundName']
                        file1.loc[i, 'KG_Formula'] = KEGG_file.loc[0, 'MolecularFormula']
                        file1.loc[i, 'KG_expPeaks'] = KEGG_file.loc[0, 'NoExplPeaks']
                        file1.loc[i, 'KG_SMILES'] = Chem.MolToSmiles(Chem.MolFromInchi(KEGG_file["InChI"][0]))
                        file1.loc[i, 'KG_file'] = KEGG

                        #create empty list of KEGG top smiles
                        Kegg_smiles = []

                        # extract only the InChI of the top 5
                        for j in KEGG_file["InChI"][0:5].tolist():
                            # convert the InChI to SMILES
                            mol = Chem.MolToSmiles(Chem.MolFromInchi(j))
                            if sl:
                                # read the suspect list
                                slist = pd.read_csv(slistcsv)

                                # Add columns 
                                file1['KG_Top_can_SL'] = np.nan # top candidate among the top 5 candidates, according to similarity with a compound in suspect list
                                file1['KG_tanimotoSLvsCAN'] = np.nan # tanimoto score
                                file1['KG_SL_comp'] = np.nan # Smiles of the suspect listr compund with  high similairity with the one of the top 5 candidates

                                # for each smiles in suspect list
                                for k, row in slist.iterrows():
                                    # Calculate the tanimoto score
                                    SSms = [Chem.MolFromSmiles(mol), Chem.MolFromSmiles(slist['SMILES'][k])]
                                    SSfps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in SSms]
                                    SStn = DataStructs.FingerprintSimilarity(SSfps[0],SSfps[1])
                                    if SStn >= 0.8:
                                        file1.loc[i, 'KG_Top_can_SL'] = j
                                        file1.loc[i, 'KG_tanimotoSLvsCAN'] = SStn
                                        file1.loc[i, 'KG_SL_comp'] = slist['SMILES'][k]
                            mol2 = Chem.MolFromSmiles(mol)
                            Kegg_smiles.append(mol2)
                        # if there are more than 1 top smiles
                        if len(Kegg_smiles) > 1:
                            #calculate the MCSS
                            res = rdFMCS.FindMCS(Kegg_smiles)
                            sm_res = Chem.MolToSmiles(Chem.MolFromSmarts(res.smartsString))
                            # if there are atleast 3 heavy atoms in the MCSS, then add it to the result file
                            elem = [ele for ele in heavy_atoms if(ele in sm_res)]
                            if elem and len(sm_res)>=3:
                                file1.loc[i, 'KG_MCSSstring'] = res.smartsString
                                file1.loc[i, 'KG_MCSS_SMILES'] = Chem.MolToSmiles(Chem.MolFromSmarts(res.smartsString))

            #start here for PubChem; find which of the files with that id have PubChem in their names,
            PubChem = [i for i in results if "PubChem" in i]

            if PubChem:

                PubChem_file = pd.read_csv(PubChem[0])

                # if more candidates
                if len(PubChem_file) >= 1:

                    # take the ones with more than 0.75 score
                    PubChem_file = PubChem_file.drop(PubChem_file[PubChem_file.Score < 0.75].index)

                    if len(PubChem_file) >= 1:

                        # add the relavnt information to the original MS1DATA csv
                        file1.loc[i, 'PC_ID'] = PubChem_file.loc[0, 'Identifier']
                        file1.loc[i, 'PC_Name'] = PubChem_file.loc[0, 'IUPACName']
                        file1.loc[i, 'PC_Formula'] = PubChem_file.loc[0, 'MolecularFormula']
                        file1.loc[i, 'PC_expPeaks'] = PubChem_file.loc[0, 'NoExplPeaks']
                        file1.loc[i, 'PC_SMILES'] = PubChem_file["SMILES"][0]
                        file1.loc[i, 'PC_file'] = PubChem

                        # empty object
                        Pubchem_smiles = []

                        # extract only the SMILES of the top 5
                        for j in PubChem_file["SMILES"][0:5].tolist():

                            # if sl = True
                            if sl:

                                # read the suspect list
                                slist = pd.read_csv(slistcsv)

                                # Add columns 
                                file1['PC_Top_can_SL'] = np.nan # top candidate among the top 5 candidates, according to similarity with a compound in suspect list
                                file1['PC_tanimotoSLvsCAN'] = np.nan # tanimoto score
                                file1['PC_SL_comp'] = np.nan # Smiles of the suspect listr compund with  high similairity with the one of the top 5 candidates
                                # calculate tanimoto
                                for n, row in slist.iterrows():

                                    SSms = [Chem.MolFromSmiles(j), Chem.MolFromSmiles(slist['SMILES'][n])]
                                    SSfps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in SSms]
                                    SStn2 = DataStructs.FingerprintSimilarity(SSfps[0],SSfps[1])

                                    if SStn2 >= 0.8:
                                        file1.loc[i, 'PC_Top_can_SL'] = j
                                        file1.loc[i, 'PC_tanimotoSLvsCAN'] = SStn2
                                        file1.loc[i, 'PC_SL_comp'] = slist['SMILES'][n]

                            # Concert smiles to mol
                            sm2 = Chem.MolFromSmiles(j)
                            # store mol in Pubchem_smiles
                            Pubchem_smiles.append(sm2)

                        if len(Pubchem_smiles) > 1:
                            # calculate MCSS
                            res2 = rdFMCS.FindMCS(Pubchem_smiles)
                            sm_res = Chem.MolToSmiles(Chem.MolFromSmarts(res2.smartsString))
                            # If atleast 3 heavy atoms present
                            elem = [ele for ele in heavy_atoms if(ele in sm_res)]
                            if elem and len(sm_res)>=3:
                                file1.loc[i, 'PC_MCSSstring']= res2.smartsString
                                file1.loc[i, 'PC_MCSS_SMILES'] = Chem.MolToSmiles(Chem.MolFromSmarts(res2.smartsString))
        file1.to_csv(input_dir + (input_table['ResultFileNames'][m] + '/insilico/MetFragResults.csv').replace("./", ""))
# Out:
#    Score                                              InChI  \
# 0    1.0  InChI=1S/C19H14ClF5N4O2/c20-14-7-6-13(8-12(14)...
#
#   FragmenterScore_Values  SuspectListScore  MaximumTreeDepth  \
# 0          1324.0;1572.0               0.0                 2
#
#    MonoisotopicMass CompoundName Identifier MolecularFormula  \
# 0         460.07257     Flupoxam     C18543   C19H14ClF5N4O2
#
#                                  FormulasOfExplPeaks   InChIKey2  \
# 0  66.0469703041635:[C5H5+H]-;193.997356261979:[C...  UHFFFAOYSA
#
#         InChIKey1  FragmenterScore  \
# 0  AOQMRUTZEYVDIL        26.477126
#
#                                        ExplPeaks                     InChIKey  \
# 0  66.0469703041635_818.3;193.997356261979_804.5  AOQMRUTZEYVDIL-UHFFFAOYSA-N
#
#    NoExplPeaks  NumberPeaksUsed
# 0            2               48
# Empty DataFrame
# Columns: [Score, InChI, FragmenterScore_Values, SuspectListScore, MaximumTreeDepth, MonoisotopicMass, CompoundName, Identifier, MolecularFormula, FormulasOfExplPeaks, InChIKey2, InChIKey1, FragmenterScore, ExplPeaks, InChIKey, NoExplPeaks, NumberPeaksUsed]
# Index: []
#       Score                                              InChI  \
# 0  1.000000  InChI=1S/C20H28O3/c1-14(7-6-8-15(2)13-19(22)23...
# 1  1.000000  InChI=1S/C20H28O3/c1-15(7-5-8-16(2)13-19(22)23...
# 2  0.833156  InChI=1S/C20H28O3/c1-12-9-20-10-13(12)5-6-15(2...
# 3  0.828693  InChI=1S/C20H28O3/c1-5-18(2)8-6-13-12(11-18)10...
# 4  0.798096  InChI=1S/C20H28O3/c1-2-3-4-5-6-10-13-18-17(15-...
# 5  0.794192  InChI=1S/C20H28O3/c1-18-11-17(22)16(21)10-12(1...
# 6  0.794192  InChI=1S/C20H28O3/c1-12(21)23-19-8-7-18-17-5-3...
# 7  0.790346  InChI=1S/C20H28O3/c1-15(8-6-9-16(2)14-17(21)22...
# 8  0.763819  InChI=1S/C20H28O3/c1-12(2)14-10-13-6-7-17-19(3...
#
#    FragmenterScore_Values  SuspectListScore  MaximumTreeDepth  \
# 0                   708.0               0.0                 2
# 1                   708.0               0.0                 2
# 2                  1044.0               0.0                 2
# 3                  1056.0               0.0                 2
# 4                  1144.0               0.0                 2
# 5                  1156.0               0.0                 2
# 6                  1156.0               0.0                 2
# 7                  1168.0               0.0                 2
# 8                  1256.0               0.0                 2
#
#    MonoisotopicMass                                       CompoundName  \
# 0         316.20397                   all-trans-4-Hydroxyretinoic acid
# 1         316.20397                  all-trans-18-Hydroxyretinoic acid
# 2         316.20397                           Gibberellin A12 aldehyde
# 3         316.20397  3beta-Hydroxy-9beta-pimara-7,15-diene-19,6beta...
# 4         316.20397                           15-Deoxy-Delta12,14-PGJ2
# 5         316.20397  2,17beta-Dihydroxy-17-methylandrosta-1,4-dien-...
# 6         316.20397          17beta-Hydroxyestr-5(10)-en-3-one acetate
# 7         316.20397                   all-trans-5,6-Epoxyretinoic acid
# 8         316.20397                                     Pisiferic acid
#
#   Identifier MolecularFormula             FormulasOfExplPeaks   InChIKey2  \
# 0     C16677         C20H28O3    147.118024287119:[C11H16]-H-  FRCNGJHJSA
# 1     C16679         C20H28O3    147.118024287119:[C11H16]-H-  FCKHSPHMSA
# 2     C06093         C20H28O3      147.118024287119:[C11H15]-  YBNSQJHGSA
# 3     C18016         C20H28O3      147.118024287119:[C11H15]-  KSYFULEYSA
# 4     C14717         C20H28O3  147.118024287119:[C11H17-H]-H-  GODQJPCRSA
# 5     C15126         C20H28O3  147.118024287119:[C11H17-H]-H-  LUCRAQOWSA
# 6     C15282         C20H28O3  147.118024287119:[C11H17-H]-H-  SLHNCBLASA
# 7     C16680         C20H28O3  147.118024287119:[C11H17-H]-H-  WEDZBJJJSA
# 8     C09163         C20H28O3   147.118024287119:[C11H13+2H]-  PXNSSMCTSA
#
#         InChIKey1  FragmenterScore               ExplPeaks  \
# 0  KGUMXGDKXYTTEY        25.087926  147.118024287119_363.1
# 1  XSJOIRFEYHJNAW        25.087926  147.118024287119_363.1
# 2  ZCTUNYRXJKLWPY        20.902160  147.118024287119_363.1
# 3  SPZLJXUKZRAIQP        20.790185  147.118024287119_363.1
# 4  VHRUMKCAEVRUBK        20.022586  147.118024287119_363.1
# 5  LWCFGFNTFZFVOY        19.924628  147.118024287119_363.1
# 6  JKSYUQKNAOZGAO        19.924628  147.118024287119_363.1
# 7  KEEHJLBAOLGBJZ        19.828153  147.118024287119_363.1
# 8  ATHWSPHADLLZSS        19.162637  147.118024287119_363.1
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  KGUMXGDKXYTTEY-FRCNGJHJSA-N            1               59
# 1  XSJOIRFEYHJNAW-FCKHSPHMSA-N            1               59
# 2  ZCTUNYRXJKLWPY-YBNSQJHGSA-N            1               59
# 3  SPZLJXUKZRAIQP-KSYFULEYSA-N            1               59
# 4  VHRUMKCAEVRUBK-GODQJPCRSA-N            1               59
# 5  LWCFGFNTFZFVOY-LUCRAQOWSA-N            1               59
# 6  JKSYUQKNAOZGAO-SLHNCBLASA-N            1               59
# 7  KEEHJLBAOLGBJZ-WEDZBJJJSA-N            1               59
# 8  ATHWSPHADLLZSS-PXNSSMCTSA-N            1               59
#       Score                                              InChI  \
# 0  1.000000  InChI=1S/C5H9O8P/c6-3-2(1-12-14(9,10)11)13-5(8...
# 1  0.948868  InChI=1S/C5H9O8P/c6-3(7)1-5(10,4(8)9)2-14(11,1...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  1168.0;1168.0;1068.0;1068.0;1068.0;1068.0;1068...               0.0
# 1  712.0;612.0;612.0;612.0;612.0;612.0;612.0;612....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass                       CompoundName  \
# 0                 2         228.00351  L-Arabino-1,4-lactone 5-phosphate
# 1                 2         228.00351      (R)-2-(Phosphonomethyl)malate
#
#   Identifier MolecularFormula  \
# 0     C22036          C5H9O8P
# 1     C21613          C5H9O8P
#
#                                  FormulasOfExplPeaks   InChIKey2  \
# 0  55.0185231310572:[C3H5O-H]-H-;55.0187098743862...  YVZJFKFKSA
# 1  59.0135444876785:[C2H3O2]-;59.0135455403113:[C...  YFKPBYRVSA
#
#         InChIKey1  FragmenterScore  \
# 0  BBDKIROTABXPPX      1130.869391
# 1  PHYKLCHCKYTLRX      1073.045643
#
#                                            ExplPeaks  \
# 0  55.0185231310572_1.5;55.0187098743862_1.7;57.0...
# 1  59.0135444876785_4.3;59.0135455403113_5.1;59.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  BBDKIROTABXPPX-YVZJFKFKSA-N          203              624
# 1  PHYKLCHCKYTLRX-YFKPBYRVSA-N          124              624
#    Score                                      InChI  \
# 0    1.0  InChI=1S/CH4O3S/c1-5(2,3)4/h1H3,(H,2,3,4)
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  448.0;448.0;448.0;448.0;448.0;448.0;448.0;272....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass          CompoundName Identifier  \
# 0                 2          95.98812  Methanesulfonic acid     C11145
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0           CH4O3S  76.96988739274:[CH3O2S-H]-H-;76.9699053819472:...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  AFVFQIVMOAPDHO      1695.913359
#
#                                            ExplPeaks  \
# 0  76.96988739274_877.2;76.9699053819472_644.5;76...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  AFVFQIVMOAPDHO-UHFFFAOYSA-N           14              101
#       Score                                              InChI  \
# 0  1.996840  InChI=1S/C5H9NO4/c6-3(5(9)10)1-2-4(7)8/h3H,1-2...
# 1  1.000000  InChI=1S/C5H9NO4/c1-3(7)10-2-4(6)5(8)9/h4H,2,6...
# 2  0.996840  InChI=1S/C5H9NO4/c1-2(4(7)8)3(6)5(9)10/h2-3H,6...
# 3  0.996840  InChI=1S/C5H9NO4/c6-3(1-4(7)8)2-5(9)10/h3H,1-2...
# 4  0.996840  InChI=1S/C5H9NO4/c6-4(5(9)10)1-3(8)2-7/h2-4,8H...
# 5  0.996840  InChI=1S/C5H9NO4/c6-2-3(7)1-4(8)5(9)10/h3,7H,1...
# 6  0.958369  InChI=1S/C5H9NO4/c1-3(5(9)10)6-2-4(7)8/h3,6H,2...
# 7  0.958369  InChI=1S/C5H9NO4/c1-6-3(5(9)10)2-4(7)8/h3,6H,2...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               1.0
# 1  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 2  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 3  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 4  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 5  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 6  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 7  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass                       CompoundName  \
# 0                 2         147.05318                          Glutamate
# 1                 2         147.05318                  O-Acetyl-L-serine
# 2                 2         147.05318          L-threo-3-Methylaspartate
# 3                 2         147.05318               3-Aminopentanedioate
# 4                 2         147.05318  L-4-Hydroxyglutamate semialdehyde
# 5                 2         147.05318    2-Oxo-4-hydroxy-5-aminovalerate
# 6                 2         147.05318        N-(Carboxymethyl)-D-alanine
# 7                 2         147.05318           N-Methyl-D-aspartic acid
#
#   Identifier MolecularFormula  \
# 0     C00302          C5H9NO4
# 1     C00979          C5H9NO4
# 2     C03618          C5H9NO4
# 3     C05574          C5H9NO4
# 4     C05938          C5H9NO4
# 5     C05941          C5H9NO4
# 6     C03790          C5H9NO4
# 7     C12269          C5H9NO4
#
#                                  FormulasOfExplPeaks   InChIKey2  \
# 0  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  UHFFFAOYSA
# 1  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  BYPYZUCNSA
# 2  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  HRFVKAFMSA
# 3  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  UHFFFAOYSA
# 4  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  DMTCNVIQSA
# 5  85.0293450748916:[C4H6O2]-H-;85.0293451535905:...  GSVOUGTGSA
# 6  102.055989162139:[C4H8NO2]-;102.056003008552:[...  GSVOUGTGSA
# 7  102.055989162139:[C4H8NO2]-;102.056003008552:[...  GSVOUGTGSA
#
#         InChIKey1  FragmenterScore  \
# 0  WHUUTDBJXJRKMK      3599.878898
# 1  VZXPDPZARILFQX      3611.290183
# 2  LXRUAYBIUSUULX      3599.878898
# 3  BBJIPMIXTXKYLZ      3599.878898
# 4  XCXUZPXOFFRGGP      3599.878898
# 5  ICMJZHFYQVZYQN      3599.878898
# 6  XYUPSBLFPTWJLC      3460.947139
# 7  HOKKHZGPKSLGJE      3460.947139
#
#                                            ExplPeaks  \
# 0  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 1  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 2  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 3  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 4  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 5  85.0293450748916_103.9;85.0293451535905_56.9;8...
# 6  102.055989162139_252.7;102.056003008552_232.8;...
# 7  102.055989162139_252.7;102.056003008552_232.8;...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  WHUUTDBJXJRKMK-UHFFFAOYSA-N           55              529
# 1  VZXPDPZARILFQX-BYPYZUCNSA-N           56              529
# 2  LXRUAYBIUSUULX-HRFVKAFMSA-N           55              529
# 3  BBJIPMIXTXKYLZ-UHFFFAOYSA-N           55              529
# 4  XCXUZPXOFFRGGP-DMTCNVIQSA-N           55              529
# 5  ICMJZHFYQVZYQN-GSVOUGTGSA-N           55              529
# 6  XYUPSBLFPTWJLC-GSVOUGTGSA-N           46              529
# 7  HOKKHZGPKSLGJE-GSVOUGTGSA-N           46              529
#    Score                                              InChI  \
# 0    1.0  InChI=1S/C12H23NO4/c1-9(2)6-12(16)17-10(7-11(1...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  708.0;708.0;708.0;708.0;708.0;708.0;448.0;708....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass         CompoundName Identifier  \
# 0                 2          245.1628  Isovalerylcarnitine     C20826
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0        C12H23NO4  56.049413342519:[C3H8N-2H]+;56.0495128523064:[...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  IGQBPDJNUXPEMT       439.580771
#
#                                            ExplPeaks  \
# 0  56.049413342519_0.0;56.0495128523064_0.0;56.04...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  IGQBPDJNUXPEMT-UHFFFAOYSA-N          909             7515
#    Score                                              InChI  \
# 0    1.0  InChI=1S/C11H21NO4/c1-5-6-11(15)16-9(7-10(13)1...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  305.0;305.0;305.0;305.0;305.0;305.0;305.0;305....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass         CompoundName Identifier  \
# 0                 2         231.14714  O-Butanoylcarnitine     C02862
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0        C11H21NO4  57.0331323531842:[C3H4O]+H+;57.0332344942644:[...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  QWYFHHGCZUCMBN        254.44155
#
#                                            ExplPeaks  \
# 0  57.0331323531842_0.0;57.0332344942644_0.0;57.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  QWYFHHGCZUCMBN-UHFFFAOYSA-N          484             4708
#       Score                                              InChI  \
# 0  1.980875      InChI=1S/C5H11NO2/c1-6(2,3)4-5(7)8/h4H2,1-3H3
# 1  1.771803  InChI=1S/C5H11NO2/c1-3(2)4(6)5(7)8/h3-4H,6H2,1...
# 2  1.000000  InChI=1S/C5H11NO2/c1-6-4-2-3-5(7)8/h6H,2-4H2,1...
# 3  0.977623  InChI=1S/C5H11NO2/c6-4-2-1-3-5(7)8/h1-4,6H2,(H...
# 4  0.776609  InChI=1S/C5H11NO2/c1-2-3-4(6)5(7)8/h4H,2-3,6H2...
# 5  0.776415  InChI=1S/C5H11NO2/c1-3-5(2,6)4(7)8/h3,6H2,1-2H...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               1.0
# 1  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               1.0
# 2  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               0.0
# 3  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               0.0
# 4  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               0.0
# 5  843.0;843.0;843.0;843.0;843.0;843.0;843.0;843....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass               CompoundName Identifier  \
# 0                 2         117.07902                    Betaine     C00719
# 1                 2         117.07902                     Valine     C16436
# 2                 2         117.07902      4-Methylaminobutyrate     C15987
# 3                 2         117.07902          5-Aminopentanoate     C00431
# 4                 2         117.07902                L-Norvaline     C01826
# 5                 2         117.07902  2-Amino-2-methylbutanoate     C03571
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0         C5H11NO2  56.049216300273:[C3H8N-2H]+;56.0493031480045:[...
# 1         C5H11NO2  55.0539494005123:[C4H8-H]+;55.0539568266159:[C...
# 2         C5H11NO2  56.049216300273:[C3H7N-H]+;56.0493031480045:[C...
# 3         C5H11NO2  55.0539494005123:[C4H8-H]+;55.0539568266159:[C...
# 4         C5H11NO2  55.0539494005123:[C4H8-H]+;55.0539568266159:[C...
# 5         C5H11NO2  55.0539494005123:[C4H8-H]+;55.0539568266159:[C...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  KWIUHFFTVRNATP      1221.572225
# 1  UHFFFAOYSA  KZSNJWFQEVHDMF       961.196660
# 2  UHFFFAOYSA  AOKCDAVWJLOAHG      1245.390687
# 3  UHFFFAOYSA  JJMDCOVWQOJGCB      1217.522983
# 4  BYPYZUCNSA  SNDPXSYFESPGGJ       967.182096
# 5  UHFFFAOYSA  GCHPUFAZSONQIV       966.939650
#
#                                            ExplPeaks  \
# 0  56.049216300273_0.0;56.0493031480045_0.0;56.04...
# 1  55.0539494005123_0.0;55.0539568266159_0.0;55.0...
# 2  56.049216300273_0.0;56.0493031480045_0.0;56.04...
# 3  55.0539494005123_0.0;55.0539568266159_0.0;55.0...
# 4  55.0539494005123_0.0;55.0539568266159_0.0;55.0...
# 5  55.0539494005123_0.0;55.0539568266159_0.0;55.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  KWIUHFFTVRNATP-UHFFFAOYSA-N         1086             5434
# 1  KZSNJWFQEVHDMF-UHFFFAOYSA-N         1241             5434
# 2  AOKCDAVWJLOAHG-UHFFFAOYSA-N         1136             5434
# 3  JJMDCOVWQOJGCB-UHFFFAOYSA-N         1075             5434
# 4  SNDPXSYFESPGGJ-BYPYZUCNSA-N         1283             5434
# 5  GCHPUFAZSONQIV-UHFFFAOYSA-N         1283             5434
#    Score                                              InChI  \
# 0    1.0  InChI=1S/C10H19NO4/c1-5-10(14)15-8(6-9(12)13)7...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  1091.0;1091.0;1091.0;1091.0;796.0;796.0;796.0;...               0.0
#
#    MaximumTreeDepth  MonoisotopicMass          CompoundName Identifier  \
# 0                 2         217.13148  O-Propanoylcarnitine     C03017
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0        C10H19NO4  57.0326503473227:[C3H5O]+;57.0326699941339:[C3...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  UFAHZIUFPNSHSL       465.046669
#
#                                            ExplPeaks  \
# 0  57.0326503473227_0.0;57.0326699941339_0.0;57.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  UFAHZIUFPNSHSL-UHFFFAOYSA-N          666             4917
#       Score                                              InChI  \
# 0  1.000000  InChI=1S/C6H11NO2/c1-2-5(7)3-4-6(8)9/h2,5H,1,3...
# 1  0.970422  InChI=1S/C6H11NO2/c8-6(9)5-3-1-2-4-7-5/h5,7H,1...
# 2  0.931635  InChI=1S/C6H11NO2/c1-7-4-2-3-5(7)6(8)9/h5H,2-4...
# 3  0.928537  InChI=1S/C6H11NO2/c7-6(5(8)9)3-1-2-4-6/h1-4,7H...
# 4  0.904980  InChI=1S/C6H11NO2/c7-5-2-1-4(3-5)6(8)9/h4-5H,1...
# 5  0.807912  InChI=1S/C6H11NO2/c1-6(9)7-4-2-3-5-8/h5H,2-4H2...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  1455.0;1455.0;1455.0;917.0;917.0;917.0;917.0;9...               0.0
# 1  1539.0;1539.0;1539.0;753.0;753.0;753.0;753.0;7...               0.0
# 2  1048.0;1048.0;1048.0;710.0;710.0;710.0;710.0;7...               0.0
# 3  1539.0;1539.0;1539.0;1001.0;1001.0;1001.0;1001...               0.0
# 4  1539.0;1539.0;1539.0;796.0;796.0;796.0;796.0;7...               0.0
# 5  1091.0;1091.0;1091.0;448.0;448.0;448.0;448.0;4...               0.0
#
#    MaximumTreeDepth  MonoisotopicMass  \
# 0                 2         129.07902
# 1                 2         129.07902
# 2                 2         129.07902
# 3                 2         129.07902
# 4                 2         129.07902
# 5                 2         129.07902
#
#                                   CompoundName Identifier MolecularFormula  \
# 0                                   Vigabatrin     C07500         C6H11NO2
# 1                                 L-Pipecolate     C00408         C6H11NO2
# 2                           N-Methyl-L-proline     C22223         C6H11NO2
# 3               1-Aminocyclopentanecarboxylate     C03969         C6H11NO2
# 4  trans-3-Aminocyclopentane-1-carboxylic acid     C13696         C6H11NO2
# 5                        N4-Acetylaminobutanal     C05936         C6H11NO2
#
#                                  FormulasOfExplPeaks   InChIKey2  \
# 0  56.0249439381176:[C3H5O-H]+;56.0250433827464:[...  UHFFFAOYSA
# 1  56.0249439381176:[C3H4O]+;56.0250433827464:[C3...  YFKPBYRVSA
# 2  56.0249439381176:[C3H4O]+;56.0250433827464:[C3...  YFKPBYRVSA
# 3  57.0694712666988:[C4H8]+H+;57.0694764595374:[C...  UHFFFAOYSA
# 4  56.0249439381176:[C3H4O]+;56.0250433827464:[C3...  RFZPGFLSSA
# 5  56.0249439381176:[C3H5O-H]+;56.0250433827464:[...  UHFFFAOYSA
#
#         InChIKey1  FragmenterScore  \
# 0  PJDFLNIOAUIZSL      1235.699105
# 1  HXEACLLIILLPRG      1199.149166
# 2  CWLQUGTUXBXTLF      1151.220342
# 3  NILQLFBWTXNUOE      1147.392403
# 4  MLLSSTJTARJLHK      1118.283123
# 5  DDSLGZOYEPKPSJ       998.335788
#
#                                            ExplPeaks  \
# 0  56.0249439381176_0.0;56.0250433827464_0.0;56.0...
# 1  56.0249439381176_0.0;56.0250433827464_0.0;56.0...
# 2  56.0249439381176_0.0;56.0250433827464_0.0;56.0...
# 3  57.0694712666988_0.0;57.0694764595374_0.0;57.0...
# 4  56.0249439381176_0.0;56.0250433827464_0.0;56.0...
# 5  56.0249439381176_0.0;56.0250433827464_0.0;56.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  PJDFLNIOAUIZSL-UHFFFAOYSA-N          434             2582
# 1  HXEACLLIILLPRG-YFKPBYRVSA-N          449             2582
# 2  CWLQUGTUXBXTLF-YFKPBYRVSA-N          446             2582
# 3  NILQLFBWTXNUOE-UHFFFAOYSA-N          442             2582
# 4  MLLSSTJTARJLHK-RFZPGFLSSA-N          434             2582
# 5  DDSLGZOYEPKPSJ-UHFFFAOYSA-N          423             2582
#       Score                                              InChI  \
# 0  1.997571      InChI=1S/C5H11NO2/c1-6(2,3)4-5(7)8/h4H2,1-3H3
# 1  1.760120  InChI=1S/C5H11NO2/c1-3(2)4(6)5(7)8/h3-4H,6H2,1...
# 2  1.000000  InChI=1S/C5H11NO2/c1-6-4-2-3-5(7)8/h6H,2-4H2,1...
# 3  0.978095  InChI=1S/C5H11NO2/c6-4-2-1-3-5(7)8/h1-4,6H2,(H...
# 4  0.769270  InChI=1S/C5H11NO2/c1-2-3-4(6)5(7)8/h4H,2-3,6H2...
# 5  0.767898  InChI=1S/C5H11NO2/c1-3-5(2,6)4(7)8/h3,6H2,1-2H...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  448.0;448.0;448.0;448.0;448.0;448.0;448.0;448....               1.0
# 1  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               1.0
# 2  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 3  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 4  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
# 5  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass               CompoundName Identifier  \
# 0                 2         117.07902                    Betaine     C00719
# 1                 2         117.07902                     Valine     C16436
# 2                 2         117.07902      4-Methylaminobutyrate     C15987
# 3                 2         117.07902          5-Aminopentanoate     C00431
# 4                 2         117.07902                L-Norvaline     C01826
# 5                 2         117.07902  2-Amino-2-methylbutanoate     C03571
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0         C5H11NO2  56.0492113748457:[C3H8N-2H]+;56.0493044527658:...
# 1         C5H11NO2  55.0540170759403:[C4H8-H]+;55.0540421778776:[C...
# 2         C5H11NO2  56.0492113748457:[C3H7N-H]+;56.0493044527658:[...
# 3         C5H11NO2  55.0540170759403:[C4H8-H]+;55.0540421778776:[C...
# 4         C5H11NO2  55.0540170759403:[C4H8-H]+;55.0540421778776:[C...
# 5         C5H11NO2  55.0540170759403:[C4H8-H]+;55.0540421778776:[C...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  KWIUHFFTVRNATP       925.479736
# 1  UHFFFAOYSA  KZSNJWFQEVHDMF       705.189152
# 2  UHFFFAOYSA  AOKCDAVWJLOAHG       927.733527
# 3  UHFFFAOYSA  JJMDCOVWQOJGCB       907.411808
# 4  BYPYZUCNSA  SNDPXSYFESPGGJ       713.677246
# 5  UHFFFAOYSA  GCHPUFAZSONQIV       712.404764
#
#                                            ExplPeaks  \
# 0  56.0492113748457_0.0;56.0493044527658_0.0;56.0...
# 1  55.0540170759403_0.0;55.0540421778776_0.0;55.0...
# 2  56.0492113748457_0.0;56.0493044527658_0.0;56.0...
# 3  55.0540170759403_0.0;55.0540421778776_0.0;55.0...
# 4  55.0540170759403_0.0;55.0540421778776_0.0;55.0...
# 5  55.0540170759403_0.0;55.0540421778776_0.0;55.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  KWIUHFFTVRNATP-UHFFFAOYSA-N          817             3764
# 1  KZSNJWFQEVHDMF-UHFFFAOYSA-N          943             3764
# 2  AOKCDAVWJLOAHG-UHFFFAOYSA-N          838             3764
# 3  JJMDCOVWQOJGCB-UHFFFAOYSA-N          806             3764
# 4  SNDPXSYFESPGGJ-BYPYZUCNSA-N          992             3764
# 5  GCHPUFAZSONQIV-UHFFFAOYSA-N          990             3764
#       Score                                              InChI  \
# 0  1.894277      InChI=1S/C5H11NO2/c1-6(2,3)4-5(7)8/h4H2,1-3H3
# 1  1.868340  InChI=1S/C5H11NO2/c1-3(2)4(6)5(7)8/h3-4H,6H2,1...
# 2  1.000000  InChI=1S/C5H11NO2/c1-2-3-4(6)5(7)8/h4H,2-3,6H2...
# 3  0.972551  InChI=1S/C5H11NO2/c1-6-4-2-3-5(7)8/h6H,2-4H2,1...
# 4  0.903862  InChI=1S/C5H11NO2/c1-3-5(2,6)4(7)8/h3,6H2,1-2H...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  853.0;853.0;853.0;853.0;853.0;853.0;853.0;853....               1.0
# 1  1291.0;1291.0;1291.0;1291.0;1291.0;1291.0;1291...               1.0
# 2  1291.0;1291.0;1291.0;1291.0;1291.0;1291.0;1291...               0.0
# 3  1303.0;1303.0;1303.0;1303.0;1303.0;1303.0;1303...               0.0
# 4  1303.0;1303.0;1303.0;1303.0;1303.0;1303.0;1303...               0.0
#
#    MaximumTreeDepth  MonoisotopicMass               CompoundName Identifier  \
# 0                 2         117.07902                    Betaine     C00719
# 1                 2         117.07902                     Valine     C16436
# 2                 2         117.07902                L-Norvaline     C01826
# 3                 2         117.07902      4-Methylaminobutyrate     C15987
# 4                 2         117.07902  2-Amino-2-methylbutanoate     C03571
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0         C5H11NO2  52.9771734872278:[CH3-H]+K+;52.9775389991739:[...
# 1         C5H11NO2  52.9771734872278:[CH3-H]+K+;52.9775389991739:[...
# 2         C5H11NO2  52.9771734872278:[CH3-H]+K+;52.9775389991739:[...
# 3         C5H11NO2  51.9566939759475:[HN-2H]+K+;52.9771734872278:[...
# 4         C5H11NO2  52.9771734872278:[CH3-H]+K+;52.9775389991739:[...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  UHFFFAOYSA  KWIUHFFTVRNATP       463.639142
# 1  UHFFFAOYSA  KZSNJWFQEVHDMF       450.192264
# 2  BYPYZUCNSA  SNDPXSYFESPGGJ       518.451476
# 3  UHFFFAOYSA  AOKCDAVWJLOAHG       504.220419
# 4  UHFFFAOYSA  GCHPUFAZSONQIV       468.608550
#
#                                            ExplPeaks  \
# 0  52.9771734872278_0.3;52.9775389991739_0.0;52.9...
# 1  52.9771734872278_0.3;52.9775389991739_0.0;52.9...
# 2  52.9771734872278_0.3;52.9775389991739_0.0;52.9...
# 3  51.9566939759475_0.0;52.9771734872278_0.3;52.9...
# 4  52.9771734872278_0.3;52.9775389991739_0.0;52.9...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  KWIUHFFTVRNATP-UHFFFAOYSA-N          740             8018
# 1  KZSNJWFQEVHDMF-UHFFFAOYSA-N         1047             8018
# 2  SNDPXSYFESPGGJ-BYPYZUCNSA-N         1250             8018
# 3  AOKCDAVWJLOAHG-UHFFFAOYSA-N          957             8018
# 4  GCHPUFAZSONQIV-UHFFFAOYSA-N         1125             8018
#    Score                                              InChI  \
# 0    1.0  InChI=1S/C5H11NO3S/c1-10(9)3-2-4(6)5(7)8/h4H,2...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  348.0;348.0;348.0;348.0;348.0;348.0;348.0;348....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass              CompoundName Identifier  \
# 0                 2           165.046  L-Methionine (S)-S-oxide     C15999
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0        C5H11NO3S  55.0417521452085:[C3H7N-2H]+;55.0418489835981:...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  MFXDVPHUSA  QEFRNWWLZKMPFJ       7216.77727
#
#                                            ExplPeaks  \
# 0  55.0417521452085_0.0;55.0418489835981_0.0;55.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  QEFRNWWLZKMPFJ-MFXDVPHUSA-N         5181            25097
#       Score                                              InChI  \
# 0  1.000000  InChI=1S/C8H18N4O2/c1-12(2)8(10)11-5-3-4-6(9)7...
# 1  0.890647  InChI=1S/C8H18N4O2/c1-2-14-7(13)6(9)4-3-5-12-8...
#
#                               FragmenterScore_Values  SuspectListScore  \
# 0  665.0;665.0;665.0;665.0;665.0;665.0;665.0;665....               0.0
# 1  665.0;665.0;665.0;665.0;665.0;665.0;665.0;665....               0.0
#
#    MaximumTreeDepth  MonoisotopicMass               CompoundName Identifier  \
# 0                 2         202.14304  NG,NG-Dimethyl-L-arginine     C03626
# 1                 2         202.14304                    Arg-OEt     C01404
#
#   MolecularFormula                                FormulasOfExplPeaks  \
# 0        C8H18N4O2  55.0304261079351:[C2H4N2-H]+;55.0305229164344:...
# 1        C8H18N4O2  55.0304261079351:[C2H5N2-2H]+;55.0305229164344...
#
#     InChIKey2       InChIKey1  FragmenterScore  \
# 0  LURJTMIESA  YDGMGEXADBMOMJ      2989.193397
# 1  LURJTMIESA  AKGWUHIOEVNNPC      2662.317344
#
#                                            ExplPeaks  \
# 0  55.0304261079351_0.0;55.0305229164344_0.0;55.0...
# 1  55.0304261079351_0.0;55.0305229164344_0.0;55.0...
#
#                       InChIKey  NoExplPeaks  NumberPeaksUsed
# 0  YDGMGEXADBMOMJ-LURJTMIESA-N         2468            18799
# 1  AKGWUHIOEVNNPC-LURJTMIESA-N         2463            18799
