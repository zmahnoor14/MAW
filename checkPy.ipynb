# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.2

# %%
import pandas as pd

import pubchempy as pcp
import numpy as np
def isNaN(string):
    return string != string
import os
import glob
import re
from pybatchclassyfire import *
import csv 
import time
import json
from pandas import json_normalize
import wget
import string
import urllib.parse
import openpyxl
import statistics
import sys
from itertools import chain

# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
from rdkit.Chem import rdFMCS
from rdkit.Chem import PandasTools

# %%
# write function for Spectral database results

# %%
input_dir = "/Users/mahnoorzulfiqar/OneDriveUNI/MAW-data/StandardSMarinoi_Data"
input_dir
# Out:
# '/Users/mahnoorzulfiqar/OneDriveUNI/MAW-data/StandardSMarinoi_Data'

# %%
def chemMN_CandidateSelection(df):
    
    one_df = []
    # define empty variable
    dbn= []
    for i, row in df.iterrows():
        # to compare each element with each opther element
        for j, row in df.iterrows():
            try:
                ms = [Chem.MolFromSmiles(df['SMILES'][i]), Chem.MolFromSmiles(df['SMILES'][j])]
                fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in ms]
                tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])
                dbn.append({
                    'Name_i':df['ranks'][i],
                    'Name_j':df['ranks'][j],
                    'i': df['SMILES'][i],
                    'j': df['SMILES'][j],
                    'Source_i':df['Source'][i],
                    'Source_j':df['Source'][j],
                    'Tanimoto': tn
                })

            except Exception as e:
                pass
            #print(i)
            #print(j)
            #print(e)
    # save chemical similarities                    
    db_edgenode = pd.DataFrame(dbn)

    dfe = []
    heavy_atoms = ['C', 'N', 'P', 'O', 'S']
    for i, row in db_edgenode.iterrows():        
        if db_edgenode['Tanimoto'][i] >= 0.85:
            # list of mol used to calaculate the MCSS
            n = [Chem.MolFromSmiles(db_edgenode['i'][i]),Chem.MolFromSmiles(db_edgenode['j'][i])]
            res = rdFMCS.FindMCS(n)
            sm_res = Chem.MolToSmiles(Chem.MolFromSmarts(res.smartsString))
            # Check if the MCSS has one of the heavy atoms and whether they are
            # more than 3
            elem = [ele for ele in heavy_atoms if(ele in sm_res)]
            if elem and len(sm_res)>=3:
                MCSS_SMILES = Chem.MolToSmiles(Chem.MolFromSmarts(res.smartsString))

            dfe.append({
                'Start':db_edgenode['Name_i'][i],
                'End':db_edgenode['Name_j'][i],
                'Tanimoto':db_edgenode['Tanimoto'][i],
                'Start_SMILES':db_edgenode['i'][i],
                'End_SMILES':db_edgenode['j'][i],
                'Start_Source':db_edgenode['Source_i'][i],
                'End_Source':db_edgenode['Source_j'][i],
                'MCSS': MCSS_SMILES
            })
    df_edge = pd.DataFrame(dfe)
    df_edge['Start'] = df_edge['Start'].astype(str)
    df_edge['End'] = df_edge['End'].astype(str)
    df_edge['sorted_row'] = [sorted([a,b]) for a,b in zip(df_edge.Start,df_edge.End)]
    df_edge['sorted_row'] = df_edge['sorted_row'].astype(str)
    df_edge.drop_duplicates(subset=['sorted_row'], inplace=True)

    #nodes= []
    #for i, row in df.iterrows():
        #n = df['ranks'][i]
        #nodes.append({
            #'nodes':n
        #})

    #node= pd.DataFrame(nodes)

    return(df_edge)

# %%
def CandidateSelection_Similarity(input_dir):

    # entry is all files and folders in input_dir
    for entry in os.listdir(input_dir):
         #if the entry is also a directory
        if os.path.isdir(os.path.join(input_dir, entry)):


            # reach spectra_dereplication folder
            sub_dir_spec = input_dir + "/" + entry + '/spectral_dereplication/'
            # reach SIRIUS results
            sub_dir_sir = input_dir + "/" + entry + '/insilico/SIRIUS/'

            #list of all csv files in the spectral dereplication foler
            spec_msp_csv = (glob.glob(input_dir + "/" + entry + '/spectral_dereplication' +'/*.csv'))
            # Sirius csv result file
            sir_msp_csv = input_dir + "/" + entry + "/insilico/MS1DATA.csv"

            # if both exist; which should be the case, even in case of 0 results
            if os.path.exists(sir_msp_csv) and os.path.exists(spec_msp_csv[0]):

                # read both csv files
                spec_msv = pd.read_csv(spec_msp_csv[0])
                sir_msv = pd.read_csv(sir_msp_csv)



                spec_msv = spec_msv[[
                    'id_X',
                    'premz',
                    'rtmin',
                    'rtmax',
                    'rtmed',
                    'rtmean',
                    'col_eng',
                    'pol',
                    'int',
                    'source_file',
                    'mbank_results_csv',
                    ]]
                sir_msv = sir_msv[['id_X',
                    'premz',
                    'rtmed',
                    'rtmean',
                    'int',
                    'col_eng',
                    'pol',
                    'ms2Peaks',
                    'ms1Peaks',
                    'sirius_result_dir']]

                merged_df = sir_msv.merge(spec_msv, 
                              how='inner', 
                              left_on=['premz', 'rtmed','rtmean','int','col_eng','pol'], 
                              right_on=['premz','rtmed','rtmean','int','col_eng','pol'])

                for mer, rows in merged_df.iterrows():

                    sirius_csv = merged_df["sirius_result_dir"][mer].replace("./", input_dir+"/")
                    mbank_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/")
                    gnps_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/").replace('mbank', 'gnps').replace('MassBank', 'GNPS')
                    hmdb_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/").replace('mbank', 'hmdb').replace('MassBank', 'HMDB')


                    if os.path.exists(sirius_csv) and os.path.exists(gnps_csv) and os.path.exists(mbank_csv) and os.path.exists(hmdb_csv):


                        sirius_df = pd.read_csv(sirius_csv)
                        sirius_df = sirius_df.drop_duplicates('smiles')

                        mbank_df = pd.read_csv(mbank_csv)
                        mbank_df = mbank_df.drop_duplicates('MBSMILES')

                        gnps_df = pd.read_csv(gnps_csv)
                        gnps_df = gnps_df.drop_duplicates('GNPSSMILES')

                        hmdb_df = pd.read_csv(hmdb_csv)
                        hmdb_df = hmdb_df.drop_duplicates('HMDBSMILES')

                        #1 SGHM
                        if len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"])), 
                               *(list(gnps_df["Source"]))
                               ,*(list(mbank_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"])), 
                               *(list(gnps_df["rank_ids"]))
                               ,*(list(mbank_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"])), 
                               *(list(gnps_df["GNPSSMILES"]))
                               ,*(list(mbank_df["MBSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])
                            
                            
                            
                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "SGHM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')


                        #2 SGM
                        elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:

                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"])), 
                               *(list(gnps_df["Source"]))
                               ,*(list(mbank_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"])), 
                               *(list(gnps_df["rank_ids"]))
                               ,*(list(mbank_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"])), 
                               *(list(gnps_df["GNPSSMILES"]))
                               ,*(list(mbank_df["MBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "SGM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                        #3 SHM
                        elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:

                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"]))
                               ,*(list(mbank_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"]))
                               ,*(list(mbank_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"]))
                               ,*(list(mbank_df["MBSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "SHM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                        #4 SGH
                        elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                            #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"]))
                               ,*(list(gnps_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"]))
                               ,*(list(gnps_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"]))
                               ,*(list(gnps_df["GNPSSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])

                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "SGH")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                            
                        #5 GHM
                        elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            #sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(gnps_df["Source"]))
                               ,*(list(mbank_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(gnps_df["rank_ids"]))
                               ,*(list(mbank_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(gnps_df["GNPSSMILES"]))
                               ,*(list(mbank_df["MBSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])

                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "GHM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                            
                        #6 SG
                        elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:
                            #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"])), 
                               *(list(gnps_df["Source"]))]
                               #,*(list(mbank_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"])), 
                               *(list(gnps_df["rank_ids"]))]
                               #,*(list(mbank_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"])), 
                               *(list(gnps_df["GNPSSMILES"]))]
                               #,*(list(mbank_df["MBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            
                            one_candidate = one_candidate_selection(sm, Source = "SG")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                        #7 SH
                        elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                            #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])
                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            
                            one_candidate = one_candidate_selection(sm, Source = "SH")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                        #8 SM
                        elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:
                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            #hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(sirius_df["Source"]))
                               ,*(list(mbank_df["Source"]))]

                            rank_l2 = [*(list(sirius_df["rank_ids"]))
                               ,*(list(mbank_df["rank_ids"]))]

                            smiles_l3 = [*(list(sirius_df["smiles"]))
                               ,*(list(mbank_df["MBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            
                            one_candidate = one_candidate_selection(sm, Source = "SM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                        #9 GM
                        elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:
                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            #hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            #sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(mbank_df["Source"])),
                                        *(list(gnps_df["Source"]))]

                            rank_l2 = [*(list(mbank_df["rank_ids"])), 
                                      *(list(gnps_df["rank_ids"]))]

                            smiles_l3 = [*(list(mbank_df["MBSMILES"])),
                                        *(list(gnps_df["GNPSSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            
                            one_candidate = one_candidate_selection(sm, Source = "GM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                        #10 GH
                        elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                            #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            #sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(gnps_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(gnps_df["rank_ids"])),
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(gnps_df["GNPSSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])
                            df_edge = chemMN_CandidateSelection(sm)



                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "GH")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                        #11 HM
                        elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                            mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                            #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                            hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                            #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                            #sirius_df["Source"] = "SIRIUS"


                            source_l1 = [*(list(mbank_df["Source"])),
                                        *(list(hmdb_df["Source"]))]

                            rank_l2 = [*(list(mbank_df["rank_ids"])), 
                                      *(list(hmdb_df["rank_ids"]))]

                            smiles_l3 = [*(list(mbank_df["MBSMILES"])),
                                        *(list(hmdb_df["HMDBSMILES"]))]

                            sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                            df_edge = chemMN_CandidateSelection(sm)

                            df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                            one_candidate = one_candidate_selection(sm, Source = "HM")
                            one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                        # S
                        #elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:

                        # G
                        #elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:

                        # M
                        #elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:

                        # H
                        #elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:

# %%
# entry is all files and folders in input_dir
for entry in os.listdir(input_dir):
     #if the entry is also a directory
    if os.path.isdir(os.path.join(input_dir, entry)):


        # reach spectra_dereplication folder
        sub_dir_spec = input_dir + "/" + entry + '/spectral_dereplication/'
        # reach SIRIUS results
        sub_dir_sir = input_dir + "/" + entry + '/insilico/SIRIUS/'

        #list of all csv files in the spectral dereplication foler
        spec_msp_csv = (glob.glob(input_dir + "/" + entry + '/spectral_dereplication' +'/*.csv'))
        # Sirius csv result file
        sir_msp_csv = input_dir + "/" + entry + "/insilico/MS1DATA.csv"

        # if both exist; which should be the case, even in case of 0 results
        if os.path.exists(sir_msp_csv) and os.path.exists(spec_msp_csv[0]):

            # read both csv files
            spec_msv = pd.read_csv(spec_msp_csv[0])
            sir_msv = pd.read_csv(sir_msp_csv)



            spec_msv = spec_msv[[
                'id_X',
                'premz',
                'rtmin',
                'rtmax',
                'rtmed',
                'rtmean',
                'col_eng',
                'pol',
                'int',
                'source_file',
                'mbank_results_csv',
                ]]
            sir_msv = sir_msv[['id_X',
                'premz',
                'rtmed',
                'rtmean',
                'int',
                'col_eng',
                'pol',
                'ms2Peaks',
                'ms1Peaks',
                'sirius_result_dir']]

            merged_df = sir_msv.merge(spec_msv, 
                          how='inner', 
                          left_on=['premz', 'rtmed','rtmean','int','col_eng','pol'], 
                          right_on=['premz','rtmed','rtmean','int','col_eng','pol'])

            for mer, rows in merged_df.iterrows():

                sirius_csv = merged_df["sirius_result_dir"][mer].replace("./", input_dir+"/")
                mbank_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/")
                gnps_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/").replace('mbank', 'gnps').replace('MassBank', 'GNPS')
                hmdb_csv = merged_df["mbank_results_csv"][mer].replace("./", input_dir+"/").replace('mbank', 'hmdb').replace('MassBank', 'HMDB')


                if os.path.exists(sirius_csv) and os.path.exists(gnps_csv) and os.path.exists(mbank_csv) and os.path.exists(hmdb_csv):


                    sirius_df = pd.read_csv(sirius_csv)
                    sirius_df = sirius_df.drop_duplicates('smiles')

                    mbank_df = pd.read_csv(mbank_csv)
                    mbank_df = mbank_df.drop_duplicates('MBSMILES')

                    gnps_df = pd.read_csv(gnps_csv)
                    gnps_df = gnps_df.drop_duplicates('GNPSSMILES')

                    hmdb_df = pd.read_csv(hmdb_csv)
                    hmdb_df = hmdb_df.drop_duplicates('HMDBSMILES')

                    #1 SGHM
                    if len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"])), 
                           *(list(gnps_df["Source"]))
                           ,*(list(mbank_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"])), 
                           *(list(gnps_df["rank_ids"]))
                           ,*(list(mbank_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"])), 
                           *(list(gnps_df["GNPSSMILES"]))
                           ,*(list(mbank_df["MBSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])



                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "SGHM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')


                    #2 SGM
                    elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:

                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"])), 
                           *(list(gnps_df["Source"]))
                           ,*(list(mbank_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"])), 
                           *(list(gnps_df["rank_ids"]))
                           ,*(list(mbank_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"])), 
                           *(list(gnps_df["GNPSSMILES"]))
                           ,*(list(mbank_df["MBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "SGM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    #3 SHM
                    elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:

                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"]))
                           ,*(list(mbank_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"]))
                           ,*(list(mbank_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"]))
                           ,*(list(mbank_df["MBSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "SHM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    #4 SGH
                    elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                        #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"]))
                           ,*(list(gnps_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"]))
                           ,*(list(gnps_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"]))
                           ,*(list(gnps_df["GNPSSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])

                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "SGH")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    #5 GHM
                    elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        #sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(gnps_df["Source"]))
                           ,*(list(mbank_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(gnps_df["rank_ids"]))
                           ,*(list(mbank_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(gnps_df["GNPSSMILES"]))
                           ,*(list(mbank_df["MBSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])

                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "GHM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    #6 SG
                    elif  len(sirius_df) > 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:
                        #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"])), 
                           *(list(gnps_df["Source"]))]
                           #,*(list(mbank_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"])), 
                           *(list(gnps_df["rank_ids"]))]
                           #,*(list(mbank_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"])), 
                           *(list(gnps_df["GNPSSMILES"]))]
                           #,*(list(mbank_df["MBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')

                        one_candidate = one_candidate_selection(sm, Source = "SG")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    #7 SH
                    elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                        #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])
                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')

                        one_candidate = one_candidate_selection(sm, Source = "SH")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                    #8 SM
                    elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:
                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        #hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(sirius_df["Source"]))
                           ,*(list(mbank_df["Source"]))]

                        rank_l2 = [*(list(sirius_df["rank_ids"]))
                           ,*(list(mbank_df["rank_ids"]))]

                        smiles_l3 = [*(list(sirius_df["smiles"]))
                           ,*(list(mbank_df["MBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')

                        one_candidate = one_candidate_selection(sm, Source = "SM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                    #9 GM
                    elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:
                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        #hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        #sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(mbank_df["Source"])),
                                    *(list(gnps_df["Source"]))]

                        rank_l2 = [*(list(mbank_df["rank_ids"])), 
                                  *(list(gnps_df["rank_ids"]))]

                        smiles_l3 = [*(list(mbank_df["MBSMILES"])),
                                    *(list(gnps_df["GNPSSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')

                        one_candidate = one_candidate_selection(sm, Source = "GM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                    #10 GH
                    elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
                        #mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        #sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(gnps_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(gnps_df["rank_ids"])),
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(gnps_df["GNPSSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])
                        df_edge = chemMN_CandidateSelection(sm)



                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "GH")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')
                    #11 HM
                    elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) > 0:
                        mbank_df["rank_ids"] = ["M_" + str(s+1) for s in range(len(mbank_df))]

                        #gnps_df["rank_ids"] = ["G_" + str(s+1) for s in range(len(gnps_df))]

                        hmdb_df["rank_ids"] = ["H_" + str(s+1) for s in range(len(hmdb_df))]

                        #sirius_df["rank_ids"] = ["S_" + str(s) for s in sirius_df["rank"]]
                        #sirius_df["Source"] = "SIRIUS"


                        source_l1 = [*(list(mbank_df["Source"])),
                                    *(list(hmdb_df["Source"]))]

                        rank_l2 = [*(list(mbank_df["rank_ids"])), 
                                  *(list(hmdb_df["rank_ids"]))]

                        smiles_l3 = [*(list(mbank_df["MBSMILES"])),
                                    *(list(hmdb_df["HMDBSMILES"]))]

                        sm = pd.DataFrame(list(zip(source_l1, rank_l2, smiles_l3)), columns = ["Source", "ranks", "SMILES"])


                        df_edge = chemMN_CandidateSelection(sm)

                        df_edge.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_ChemMNedges.tsv", sep='\t')
                        one_candidate = one_candidate_selection(sm, Source = "HM")
                        print(one_candidate)
                        one_candidate.to_csv(input_dir + "/" + entry + "/" + str(merged_df["premz"][mer]) + "_one_candidate_list.tsv", sep='\t')

                    # S
                    #elif  len(sirius_df) > 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:

                    # G
                    #elif  len(sirius_df) == 0 and len(gnps_df) > 0 and len(mbank_df) == 0 and len(hmdb_df) == 0:

                    # M
                    #elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) > 0 and len(hmdb_df) == 0:

                    # H
                    #elif  len(sirius_df) == 0 and len(gnps_df) == 0 and len(mbank_df) == 0 and len(hmdb_df) > 0:
# Out:
#       Source ranks                 SMILES SIRIUS GNPS MassBank  HMDB  Count
# 0     SIRIUS   S_1    C(C(CS(=O)(=O)O)N)O    S_1  NaN      NaN   NaN    1.0
# 1     SIRIUS   S_2    C(C(CS(=O)(=O)O)O)N    S_2  NaN      NaN   NaN    1.0
# 2     SIRIUS   S_3    C(C(CO)S(=O)(=O)O)N    S_3  NaN      NaN   NaN    1.0
# 3     SIRIUS   S_4    C(CS(=O)(=O)O)C(N)O    S_4  NaN      NaN   NaN    1.0
# 4     SIRIUS   S_5      C(CNO)CS(=O)(=O)O    S_5  NaN      NaN   NaN    1.0
# 5     SIRIUS   S_6    C(CO)C(N)S(=O)(=O)O    S_6  NaN      NaN   NaN    1.0
# 6     SIRIUS   S_7      C(CO)NCS(=O)(=O)O    S_7  NaN      NaN   NaN    1.0
# 7     SIRIUS   S_8      C(CS(=O)(=O)O)NCO    S_8  NaN      NaN   NaN    1.0
# 8     SIRIUS   S_9    C(CN)C(O)S(=O)(=O)O    S_9  NaN      NaN   NaN    1.0
# 9     SIRIUS  S_10      C(CN)COS(=O)(=O)O   S_10  NaN      NaN   NaN    1.0
# 10    SIRIUS  S_11      C(CON)CS(=O)(=O)O   S_11  NaN      NaN   NaN    1.0
# 11    SIRIUS  S_12      C(CNS(=O)(=O)O)CO   S_12  NaN      NaN   NaN    1.0
# 12    SIRIUS  S_13    CC(C(O)S(=O)(=O)O)N   S_13  NaN      NaN   NaN    1.0
# 13    SIRIUS  S_14      C(COCS(=O)(=O)O)N   S_14  NaN      NaN   NaN    1.0
# 14    SIRIUS  S_15    CC(C(N)S(=O)(=O)O)O   S_15  NaN      NaN   NaN    1.0
# 15    SIRIUS  S_16    CC(CO)(N)S(=O)(=O)O   S_16  NaN      NaN   NaN    1.0
# 16    SIRIUS  S_17        CONCCS(=O)(=O)O   S_17  NaN      NaN   NaN    1.0
# 17    SIRIUS  S_18      CC(CNS(=O)(=O)O)O   S_18  NaN      NaN   NaN    1.0
# 18    SIRIUS  S_19      CC(COS(=O)(=O)O)N   S_19  NaN      NaN   NaN    1.0
# 19    SIRIUS  S_20      COC(CS(=O)(=O)O)N   S_20  NaN      NaN   NaN    1.0
# 20    SIRIUS  S_21      CNCC(O)S(=O)(=O)O   S_21  NaN      NaN   NaN    1.0
# 21    SIRIUS  S_22      CC(CN)OS(=O)(=O)O   S_22  NaN      NaN   NaN    1.0
# 22    SIRIUS  S_23       C(C(CO)O)NS(=O)O   S_23  NaN      NaN   NaN    1.0
# 23    SIRIUS  S_24      C(CS(=O)(=O)OCO)N   S_24  NaN      NaN   NaN    1.0
# 24    SIRIUS  S_25      C(CS(=O)(=O)O)OCN   S_25  NaN      NaN   NaN    1.0
# 25    SIRIUS  S_26      COCC(N)S(=O)(=O)O   S_26  NaN      NaN   NaN    1.0
# 26    SIRIUS  S_27       C(CN)C(OO)S(=O)O   S_27  NaN      NaN   NaN    1.0
# 27    SIRIUS  S_28      CN(CCS(=O)(=O)O)O   S_28  NaN      NaN   NaN    1.0
# 28    SIRIUS  S_29      CCC(N)OS(=O)(=O)O   S_29  NaN      NaN   NaN    1.0
# 29    SIRIUS  S_30    C(C(CO)S(=O)(=O)N)O   S_30  NaN      NaN   NaN    1.0
# 30    SIRIUS  S_31    C(C(CS(=O)(=O)N)O)O   S_31  NaN      NaN   NaN    1.0
# 31    SIRIUS  S_32        CNCCOS(=O)(=O)O   S_32  NaN      NaN   NaN    1.0
# 32    SIRIUS  S_33    C(CS(=O)(=O)N)C(O)O   S_33  NaN      NaN   NaN    1.0
# 33    SIRIUS  S_34      C(COS(=O)(=O)CN)O   S_34  NaN      NaN   NaN    1.0
# 34    SIRIUS  S_35        CCNCOS(=O)(=O)O   S_35  NaN      NaN   NaN    1.0
# 35    SIRIUS  S_36        CS(=O)(=O)ONCCO   S_36  NaN      NaN   NaN    1.0
# 36    SIRIUS  S_37      CC(COS(=O)(=O)N)O   S_37  NaN      NaN   NaN    1.0
# 37      GNPS   G_1  C1=CC=C2C(=C1)N=NN2Cl    NaN  G_1      M_1   NaN    2.0
# 38      GNPS   G_2    ClC1=CC2=NNN=C2C=C1    NaN  G_2      M_2   NaN    2.0
# 39  MassBank   M_1  C1=CC=C2C(=C1)N=NN2Cl    NaN  G_1      M_1   NaN    2.0
# 40  MassBank   M_2    C1=CC2=NNN=C2C=C1Cl    NaN  G_2      M_2   NaN    2.0
#       Source ranks                                             SMILES SIRIUS  \
# 0     SIRIUS   S_1                                C(C(CS(=O)(=O)O)O)N    S_1
# 1     SIRIUS   S_2                                C(CS(=O)(=O)O)C(N)O    S_2
# 2     SIRIUS   S_3                                C(C(CS(=O)(=O)O)N)O    S_3
# 3     SIRIUS   S_4                                  C(CNO)CS(=O)(=O)O    S_4
# 4     SIRIUS   S_5                                C(CO)C(N)S(=O)(=O)O    S_5
# 5     SIRIUS   S_6                                C(C(CO)S(=O)(=O)O)N    S_6
# 6     SIRIUS   S_7                                  C(CO)NCS(=O)(=O)O    S_7
# 7     SIRIUS   S_8                                C(CN)C(O)S(=O)(=O)O    S_8
# 8     SIRIUS   S_9                                  C(CN)COS(=O)(=O)O    S_9
# 9     SIRIUS  S_10                                  C(CNS(=O)(=O)O)CO   S_10
# 10    SIRIUS  S_11                                  C(CS(=O)(=O)O)NCO   S_11
# 11    SIRIUS  S_12                                  C(CON)CS(=O)(=O)O   S_12
# 12    SIRIUS  S_13                                  CC(CNS(=O)(=O)O)O   S_13
# 13    SIRIUS  S_14                                CC(C(N)S(=O)(=O)O)O   S_14
# 14    SIRIUS  S_15                                  COC(CS(=O)(=O)O)N   S_15
# 15    SIRIUS  S_16                                CC(C(O)S(=O)(=O)O)N   S_16
# 16    SIRIUS  S_17                                  C(COCS(=O)(=O)O)N   S_17
# 17    SIRIUS  S_18                                    CONCCS(=O)(=O)O   S_18
# 18    SIRIUS  S_19                                  CNCC(O)S(=O)(=O)O   S_19
# 19    SIRIUS  S_20                                  C(CS(=O)(=O)O)OCN   S_20
# 20    SIRIUS  S_21                                  CC(COS(=O)(=O)O)N   S_21
# 21    SIRIUS  S_22                                   C(C(CO)O)NS(=O)O   S_22
# 22    SIRIUS  S_23                                  CC(CN)OS(=O)(=O)O   S_23
# 23    SIRIUS  S_24                                  COCC(N)S(=O)(=O)O   S_24
# 24    SIRIUS  S_25                                  CCC(N)OS(=O)(=O)O   S_25
# 25    SIRIUS  S_26                                  CN(CCS(=O)(=O)O)O   S_26
# 26    SIRIUS  S_27                                   C(CN)C(OO)S(=O)O   S_27
# 27    SIRIUS  S_28                                CC(CO)(N)S(=O)(=O)O   S_28
# 28    SIRIUS  S_29                                  C(CS(=O)(=O)OCO)N   S_29
# 29    SIRIUS  S_30                                C(CS(=O)(=O)N)C(O)O   S_30
# 30    SIRIUS  S_31                                    CCNCOS(=O)(=O)O   S_31
# 31    SIRIUS  S_32                                    CNCCOS(=O)(=O)O   S_32
# 32    SIRIUS  S_33                                  C(COS(=O)(=O)CN)O   S_33
# 33    SIRIUS  S_34                                    CS(=O)(=O)ONCCO   S_34
# 34    SIRIUS  S_35                                    COCCNS(=O)(=O)O   S_35
# 35    SIRIUS  S_36                                CC(C)(N)OS(=O)(=O)O   S_36
# 36      GNPS   G_1  COCCOC(=O)c1c(C)n(CCOc2cccc(Cl)c2Cl)c2c1cc(O)c...    NaN
# 37      GNPS   G_2                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 38      GNPS   G_3                                ClC1=CC2=NNN=C2C=C1    NaN
# 39  MassBank   M_1                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 40  MassBank   M_2                                C1=CC2=NNN=C2C=C1Cl    NaN
#
#    GNPS MassBank  HMDB  Count
# 0   NaN      NaN   NaN    1.0
# 1   NaN      NaN   NaN    1.0
# 2   NaN      NaN   NaN    1.0
# 3   NaN      NaN   NaN    1.0
# 4   NaN      NaN   NaN    1.0
# 5   NaN      NaN   NaN    1.0
# 6   NaN      NaN   NaN    1.0
# 7   NaN      NaN   NaN    1.0
# 8   NaN      NaN   NaN    1.0
# 9   NaN      NaN   NaN    1.0
# 10  NaN      NaN   NaN    1.0
# 11  NaN      NaN   NaN    1.0
# 12  NaN      NaN   NaN    1.0
# 13  NaN      NaN   NaN    1.0
# 14  NaN      NaN   NaN    1.0
# 15  NaN      NaN   NaN    1.0
# 16  NaN      NaN   NaN    1.0
# 17  NaN      NaN   NaN    1.0
# 18  NaN      NaN   NaN    1.0
# 19  NaN      NaN   NaN    1.0
# 20  NaN      NaN   NaN    1.0
# 21  NaN      NaN   NaN    1.0
# 22  NaN      NaN   NaN    1.0
# 23  NaN      NaN   NaN    1.0
# 24  NaN      NaN   NaN    1.0
# 25  NaN      NaN   NaN    1.0
# 26  NaN      NaN   NaN    1.0
# 27  NaN      NaN   NaN    1.0
# 28  NaN      NaN   NaN    1.0
# 29  NaN      NaN   NaN    1.0
# 30  NaN      NaN   NaN    1.0
# 31  NaN      NaN   NaN    1.0
# 32  NaN      NaN   NaN    1.0
# 33  NaN      NaN   NaN    1.0
# 34  NaN      NaN   NaN    1.0
# 35  NaN      NaN   NaN    1.0
# 36  G_1      NaN   NaN    1.0
# 37  G_2      M_1   NaN    2.0
# 38  G_3      M_2   NaN    2.0
# 39  G_2      M_1   NaN    2.0
# 40  G_3      M_2   NaN    2.0
#      Source ranks                                 SMILES SIRIUS  \
# 0    SIRIUS   S_1          CC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1
# 1    SIRIUS   S_2               CCC(=O)OC(CC(=O)O)CN(C)C    S_2
# 2    SIRIUS   S_3               CC(=O)OC(CC(=O)OC)CN(C)C    S_3
# 3    SIRIUS   S_4          CC(=O)OC(C[N+](C)(C)C)OC(=O)C    S_4
# 4    SIRIUS   S_5          CC(=O)OC(=O)CC(C[N+](C)(C)C)O    S_5
# 5      GNPS   G_1   CC(=O)O[C@H](CC(=O)[O-])C[N+](C)(C)C    NaN
# 6      GNPS   G_2       CC(=O)OC(CC([O-])=O)C[N+](C)(C)C    NaN
# 7      GNPS   G_3      CC(=O)O[C@H](CC(O)=O)C[N+](C)(C)C    S_1
# 8      GNPS   G_4       CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN
# 9  MassBank   M_1  CC(=O)O[C@@H](CC(=O)[O-])C[N+](C)(C)C    NaN
#
#             GNPS MassBank  HMDB  Count
# 0            G_3      NaN   NaN    2.0
# 1            NaN      NaN   NaN    1.0
# 2            NaN      NaN   NaN    1.0
# 3            NaN      NaN   NaN    1.0
# 4            NaN      NaN   NaN    1.0
# 5  G_1, G_2, G_4      M_1   NaN    4.0
# 6  G_1, G_2, G_4      M_1   NaN    4.0
# 7            G_3      NaN   NaN    2.0
# 8  G_1, G_2, G_4      M_1   NaN    4.0
# 9  G_1, G_2, G_4      M_1   NaN    4.0
#    Source ranks                                  SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1         CCCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  NaN       NaN
# 1  SIRIUS   S_2       CC(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3         CCC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_3  NaN       NaN
# 3    GNPS   G_1  CCCC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C    NaN  G_1       NaN
#
#    HMDB  Count
# 0   NaN    1.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
#       Source ranks                                             SMILES SIRIUS  \
# 0     SIRIUS   S_1                                   C1CCNC(C1)C(=O)O    S_1
# 1     SIRIUS   S_2                                [CH2-]N1CCCC1C(=O)O    S_2
# 2     SIRIUS   S_3                                     CN1CCCC1C(=O)O    S_3
# 3     SIRIUS   S_4                                   CCC1CC(N1)C(=O)O    S_4
# 4     SIRIUS   S_5                                   CC1CCC(N1)C(=O)O    S_5
# 5     SIRIUS   S_6                                [CH2+]CCCC(C(=O)O)N    S_6
# 6     SIRIUS   S_7                                     CC1CCNC1C(=O)O    S_7
# 7     SIRIUS   S_8                                   C1CCN(C1)CC(=O)O    S_8
# 8     SIRIUS   S_9                                   C1CC(C1)NCC(=O)O    S_9
# 9     SIRIUS  S_10                                   CCCC1C(N1)C(=O)O   S_10
# 10    SIRIUS  S_11                                   C1CC(NC1)CC(=O)O   S_11
# 11    SIRIUS  S_12                                   CCC(C(=O)O)N1CC1   S_12
# 12    SIRIUS  S_13                                     CCC1CNC1C(=O)O   S_13
# 13      GNPS   G_1                                O=C(O)[C@@H]1CCCCN1    S_1
# 14      GNPS   G_2                                NCCCC[C@H](N)C(=O)O    NaN
# 15      GNPS   G_3                             C(CCN)C[C@@H](C(=O)O)N    NaN
# 16      GNPS   G_4                                  C(CCN)CC(C(=O)O)N    NaN
# 17      GNPS   G_5                                    O=C(O)C(N)CCCCN    NaN
# 18      GNPS   G_6                                   C1CCNC(C1)C(=O)O    S_1
# 19      GNPS   G_7       C(CCN[C@@H](CCC(=O)O)C(=O)O)C[C@@H](C(=O)O)N    NaN
# 20      GNPS   G_8                                     OC(=O)C1CCCCN1    S_1
# 21      GNPS   G_9                                NCCCC[C@H](N)C(O)=O    NaN
# 22      GNPS  G_10  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 23      GNPS  G_11  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 24      GNPS  G_12  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 25      GNPS  G_13                             NC(CCCCNC(=O)CO)C(O)=O    NaN
# 26      GNPS  G_14                   OC(=O)CCC(NCCCCC(N)C(O)=O)C(O)=O    NaN
# 27      GNPS  G_15                                   OC(=O)C(C1)NCCC1    S_1
# 28      GNPS  G_16                 C(CCNC(CCC(=O)O)C(=O)O)CC(C(=O)O)N    NaN
# 29      GNPS  G_17                              C1CCN[C@@H](C1)C(=O)O    S_1
# 30      GNPS  G_18  C1=CC=C(C=C1)CC[C@@H](C(=O)O)N[C@@H](CCCCN)C(=...    NaN
# 31      GNPS  G_19                              CC(C)C[C@@H](C(=O)O)N    NaN
# 32      GNPS  G_20                                                NaN    NaN
# 33      GNPS  G_21                  C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O    NaN
# 34      GNPS  G_22                                    NCCCCC(N)C(=O)O    NaN
# 35  MassBank   M_1                     C(CCN)C[C@@H](C(=O)[O-])[NH3+]    NaN
# 36  MassBank   M_2                          C(CCN)CC(C(=O)[O-])[NH3+]    NaN
# 37  MassBank   M_3       C(CCN[C@@H](CCC(=O)O)C(=O)O)C[C@@H](C(=O)O)N    NaN
# 38  MassBank   M_4                           C1CC[NH2+]C(C1)C(=O)[O-]    NaN
# 39  MassBank   M_5                 C(CCNC(CCC(=O)O)C(=O)O)CC(C(=O)O)N    NaN
# 40      HMDB   H_1                                NCCCC[C@H](N)C(=O)O    NaN
# 41      HMDB   H_2                               NCCCC[C@@H](N)C(=O)O    NaN
# 42      HMDB   H_3                                     O=C(O)C1CCCCN1    S_1
# 43      HMDB   H_4         N[C@@H](CCCCN[C@@H](CCC(=O)O)C(=O)O)C(=O)O    NaN
# 44      HMDB   H_5   NC(CCC/C=C(\CCC(N)C(=O)O)CNCCCCC(N)C(=O)O)C(=O)O    NaN
# 45      HMDB   H_6                    NC(CCCCN1C(=O)CCC1C(=O)O)C(=O)O    NaN
# 46      HMDB   H_7                                                NaN    NaN
#
#                              GNPS  MassBank      HMDB  Count
# 0       G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 1                             NaN       NaN       NaN    1.0
# 2                             NaN       NaN       NaN    1.0
# 3                             NaN       NaN       NaN    1.0
# 4                             NaN       NaN       NaN    1.0
# 5                             NaN       NaN       NaN    1.0
# 6                             NaN       NaN       NaN    1.0
# 7                             NaN       NaN       NaN    1.0
# 8                             NaN       NaN       NaN    1.0
# 9                             NaN       NaN       NaN    1.0
# 10                            NaN       NaN       NaN    1.0
# 11                            NaN       NaN       NaN    1.0
# 12                            NaN       NaN       NaN    1.0
# 13      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 14  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 15  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 16  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 17  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 18      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 19                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 20      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 21  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 22                     G_10, G_11       NaN       NaN    2.0
# 23                     G_10, G_11       NaN       NaN    2.0
# 24                           G_12       NaN       NaN    1.0
# 25                           G_13       NaN       NaN    1.0
# 26                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 27      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 28                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 29      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 30                           G_18       NaN       NaN    1.0
# 31                           G_19       NaN       NaN    1.0
# 32                            NaN       NaN       NaN    NaN
# 33                           G_21       NaN       NaN    1.0
# 34  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 35                            NaN  M_1, M_2       NaN    2.0
# 36                            NaN  M_1, M_2       NaN    2.0
# 37                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 38                            NaN       M_4       NaN    1.0
# 39                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 40  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 41  G_2, G_3, G_4, G_5, G_9, G_22       NaN  H_1, H_2    8.0
# 42      G_1, G_6, G_8, G_15, G_17       NaN       H_3    7.0
# 43                G_7, G_14, G_16  M_3, M_5       H_4    6.0
# 44                            NaN       NaN       H_5    1.0
# 45                            NaN       NaN       H_6    1.0
# 46                            NaN       NaN       NaN    NaN
#    Source ranks                                 SMILES SIRIUS      GNPS  \
# 0  SIRIUS   S_1     CC(C)CC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1       NaN
# 1  SIRIUS   S_2     CCC(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_2       NaN
# 2  SIRIUS   S_3       CCCCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_3       NaN
# 3  SIRIUS   S_4     CC(C)OC(=O)CC(C[N+](C)(C)C)OC(=O)C    S_4       NaN
# 4  SIRIUS   S_5   CC(C)(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_5       NaN
# 5  SIRIUS   S_6       CCCC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_6       NaN
# 6    GNPS   G_1    CCCCC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN       G_1
# 7    GNPS   G_2  CC(C)CC(=O)OC(CC([O-])=O)C[N+](C)(C)C    NaN  G_2, G_3
# 8    GNPS   G_3  CC(C)CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN  G_2, G_3
#
#    MassBank  HMDB  Count
# 0       NaN   NaN    1.0
# 1       NaN   NaN    1.0
# 2       NaN   NaN    1.0
# 3       NaN   NaN    1.0
# 4       NaN   NaN    1.0
# 5       NaN   NaN    1.0
# 6       NaN   NaN    1.0
# 7       NaN   NaN    2.0
# 8       NaN   NaN    2.0
#    Source ranks                                  SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1         CCCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  NaN       NaN
# 1  SIRIUS   S_2       CC(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3         CCC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_3  NaN       NaN
# 3    GNPS   G_1  CCCC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C    NaN  G_1       NaN
#
#    HMDB  Count
# 0   NaN    1.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
#    Source ranks                              SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1      CCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  G_1       NaN
# 1  SIRIUS   S_2      CC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3           CCCC(=O)OC(CC(=O)O)CN(C)C    S_3  NaN       NaN
# 3  SIRIUS   S_4      CC(=O)COC(CC(=O)O)C[N+](C)(C)C    S_4  NaN       NaN
# 4  SIRIUS   S_5      CC[N+](C)(C)CC(CC(=O)O)OC(=O)C    S_5  NaN       NaN
# 5  SIRIUS   S_6    CC(=O)OC(C)(CC(=O)O)C[N+](C)(C)C    S_6  NaN       NaN
# 6    GNPS   G_1  CCC(=O)O[C@H](CC(O)=O)C[N+](C)(C)C    S_1  G_1       NaN
# 7    GNPS   G_2   CCC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN  G_2       NaN
#
#    HMDB  Count
# 0   NaN    2.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
# 4   NaN    1.0
# 5   NaN    1.0
# 6   NaN    2.0
# 7   NaN    1.0
#       Source ranks                                             SMILES SIRIUS  \
# 0     SIRIUS   S_1                                   C1CCNC(C1)C(=O)O    S_1
# 1     SIRIUS   S_2                                [CH2-]N1CCCC1C(=O)O    S_2
# 2     SIRIUS   S_3                                     CN1CCCC1C(=O)O    S_3
# 3     SIRIUS   S_4                                [CH2+]CCCC(C(=O)O)N    S_4
# 4     SIRIUS   S_5                                   C1CC(NC1)CC(=O)O    S_5
# 5     SIRIUS   S_6                                     C1CNC1CCC(=O)O    S_6
# 6     SIRIUS   S_7                                   CCC1CC(N1)C(=O)O    S_7
# 7     SIRIUS   S_8                                   C1CCN(C1)CC(=O)O    S_8
# 8     SIRIUS   S_9                                   C1CC(C1)NCC(=O)O    S_9
# 9     SIRIUS  S_10                                     CC1CCNC1C(=O)O   S_10
# 10    SIRIUS  S_11                                   CC1CCC(N1)C(=O)O   S_11
# 11    SIRIUS  S_12                                   CCC(C(=O)O)N1CC1   S_12
# 12    SIRIUS  S_13                                     CCC1CNC1C(=O)O   S_13
# 13    SIRIUS  S_14                                   CCC1C(CN1)C(=O)O   S_14
# 14    SIRIUS  S_15                                   CCCC1C(N1)C(=O)O   S_15
# 15    SIRIUS  S_16                                     CCN1CCC1C(=O)O   S_16
# 16    SIRIUS  S_17                                   C1C(N1)CCCC(=O)O   S_17
# 17    SIRIUS  S_18                                 C1CCC(C1)(C(=O)O)N   S_18
# 18    SIRIUS  S_19                                   CC1(CCCN1)C(=O)O   S_19
# 19      GNPS   G_1                                O=C(O)[C@@H]1CCCCN1    S_1
# 20      GNPS   G_2                                NCCCC[C@H](N)C(=O)O    NaN
# 21      GNPS   G_3                                     OC(=O)C1CCCCN1    S_1
# 22      GNPS   G_4                                OC(=O)[C@@H]1CCCCN1    S_1
# 23      GNPS   G_5                             C(CCN)C[C@@H](C(=O)O)N    NaN
# 24      GNPS   G_6                                    O=C(O)C(N)CCCCN    NaN
# 25      GNPS   G_7                                  C(CCN)CC(C(=O)O)N    NaN
# 26      GNPS   G_8  CCC(C)[C@@H]1NC(=O)[C@@H](CC2=CC=CC=C2)NC(=O)C...    NaN
# 27      GNPS   G_9                                NCCCC[C@H](N)C(O)=O    NaN
# 28      GNPS  G_10  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 29      GNPS  G_11  C[C@H](CCC(N[C@@H](CCCCN)C(O)=O)=O)[C@H]1CC[C@...    NaN
# 30      GNPS  G_12                             NC(CCCCNC(=O)CO)C(O)=O    NaN
# 31      GNPS  G_13                                    NCCCCC(N)C(=O)O    NaN
# 32      GNPS  G_14                                   OC(=O)C(C1)NCCC1    S_1
# 33      GNPS  G_15                                   C1CCNC(C1)C(=O)O    S_1
# 34      GNPS  G_16                              C1CCN[C@@H](C1)C(=O)O    S_1
# 35      GNPS  G_17                              CC(C)C[C@@H](C(=O)O)N    NaN
# 36      GNPS  G_18                                                NaN    NaN
# 37      GNPS  G_19  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 38      GNPS  G_20       C(CCN[C@@H](CCC(=O)O)C(=O)O)C[C@@H](C(=O)O)N    NaN
# 39      GNPS  G_21                 C(CCNC(CCC(=O)O)C(=O)O)CC(C(=O)O)N    NaN
# 40      GNPS  G_22  C[C@H](CCC(N[C@H](C(O)=O)CCCCN)=O)[C@H]1CC[C@@...    NaN
# 41      GNPS  G_23         C1CCN2C[C@@H](NC(=O)[C@@H]2C1)CC3=CC=CC=C3    NaN
# 42      GNPS  G_24                              CC(=O)NC(CCCCN)C(O)=O    NaN
# 43  MassBank   M_1                     C(CCN)C[C@@H](C(=O)[O-])[NH3+]    NaN
# 44  MassBank   M_2                          C(CCN)CC(C(=O)[O-])[NH3+]    NaN
# 45  MassBank   M_3       C(CCN[C@@H](CCC(=O)O)C(=O)O)C[C@@H](C(=O)O)N    NaN
# 46  MassBank   M_4                           C1CC[NH2+]C(C1)C(=O)[O-]    NaN
# 47  MassBank   M_5                 C(CCNC(CCC(=O)O)C(=O)O)CC(C(=O)O)N    NaN
# 48      HMDB   H_1                                NCCCC[C@H](N)C(=O)O    NaN
# 49      HMDB   H_2                               NCCCC[C@@H](N)C(=O)O    NaN
# 50      HMDB   H_3                                     O=C(O)C1CCCCN1    S_1
# 51      HMDB   H_4         N[C@@H](CCCCN[C@@H](CCC(=O)O)C(=O)O)C(=O)O    NaN
# 52      HMDB   H_5   NC(CCC/C=C(\CCC(N)C(=O)O)CNCCCCC(N)C(=O)O)C(=O)O    NaN
# 53      HMDB   H_6                    NC(CCCCN1C(=O)CCC1C(=O)O)C(=O)O    NaN
# 54      HMDB   H_7                                                NaN    NaN
#
#                                GNPS  MassBank      HMDB  Count
# 0   G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 1                               NaN       NaN       NaN    1.0
# 2                               NaN       NaN       NaN    1.0
# 3                               NaN       NaN       NaN    1.0
# 4                               NaN       NaN       NaN    1.0
# 5                               NaN       NaN       NaN    1.0
# 6                               NaN       NaN       NaN    1.0
# 7                               NaN       NaN       NaN    1.0
# 8                               NaN       NaN       NaN    1.0
# 9                               NaN       NaN       NaN    1.0
# 10                              NaN       NaN       NaN    1.0
# 11                              NaN       NaN       NaN    1.0
# 12                              NaN       NaN       NaN    1.0
# 13                              NaN       NaN       NaN    1.0
# 14                              NaN       NaN       NaN    1.0
# 15                              NaN       NaN       NaN    1.0
# 16                              NaN       NaN       NaN    1.0
# 17                              NaN       NaN       NaN    1.0
# 18                              NaN       NaN       NaN    1.0
# 19  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 20    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 21  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 22  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 23    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 24    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 25    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 26                              G_8       NaN       NaN    1.0
# 27    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 28                       G_10, G_22       NaN       NaN    2.0
# 29                             G_11       NaN       NaN    1.0
# 30                             G_12       NaN       NaN    1.0
# 31    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 32  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 33  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 34  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 35                             G_17       NaN       NaN    1.0
# 36                              NaN       NaN       NaN    NaN
# 37                             G_19       NaN       NaN    1.0
# 38                       G_20, G_21  M_3, M_5       H_4    5.0
# 39                       G_20, G_21  M_3, M_5       H_4    5.0
# 40                       G_10, G_22       NaN       NaN    2.0
# 41                             G_23       NaN       NaN    1.0
# 42                             G_24       NaN       NaN    1.0
# 43                              NaN  M_1, M_2       NaN    2.0
# 44                              NaN  M_1, M_2       NaN    2.0
# 45                       G_20, G_21  M_3, M_5       H_4    5.0
# 46                              NaN       M_4       NaN    1.0
# 47                       G_20, G_21  M_3, M_5       H_4    5.0
# 48    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 49    G_2, G_5, G_6, G_7, G_9, G_13       NaN  H_1, H_2    8.0
# 50  G_1, G_3, G_4, G_14, G_15, G_16       NaN       H_3    8.0
# 51                       G_20, G_21  M_3, M_5       H_4    5.0
# 52                              NaN       NaN       H_5    1.0
# 53                              NaN       NaN       H_6    1.0
# 54                              NaN       NaN       NaN    NaN
#    Source ranks                   SMILES SIRIUS GNPS  MassBank  HMDB  Count
# 0  SIRIUS   S_1       C[N+](C)(C)CC(=O)O    S_1  G_1       NaN   NaN    2.0
# 1  SIRIUS   S_2  C[N+](C)([CH2-])CC(=O)O    S_2  NaN       NaN   NaN    1.0
# 2  SIRIUS   S_3            CN(C)CC(=O)OC    S_3  NaN       NaN   NaN    1.0
# 3  SIRIUS   S_4            CN(C)CCC(=O)O    S_4  NaN       NaN   NaN    1.0
# 4  SIRIUS   S_5       CC(=O)O[N+](C)(C)C    S_5  NaN       NaN   NaN    1.0
# 5  SIRIUS   S_6            CCN(C)CC(=O)O    S_6  NaN       NaN   NaN    1.0
# 6  SIRIUS   S_7         C[N+](C)(CC=C)OO    S_7  NaN       NaN   NaN    1.0
# 7    GNPS   G_1       C[N+](C)(C)CC(=O)O    S_1  G_1       NaN   NaN    2.0
# 8    GNPS   G_2    C[N+](C)(C)CC(=O)[O-]    NaN  G_2       NaN   NaN    1.0
#       Source ranks                               SMILES SIRIUS GNPS MassBank  \
# 0     SIRIUS   S_1             CN(C)C(=NCCCC(C(=O)O)N)N    S_1  G_1      NaN
# 1     SIRIUS   S_2               CCNC(=NCCCC(C(=O)O)N)N    S_2  NaN      NaN
# 2     SIRIUS   S_3               CNC(=NC)NCCCC(C(=O)O)N    S_3  NaN      NaN
# 3     SIRIUS   S_4             CN=C(N)N(C)CCCC(C(=O)O)N    S_4  NaN      NaN
# 4     SIRIUS   S_5          C[N+](=C(N)NCCCC(C(=O)O)N)C    S_5  NaN      NaN
# 5     SIRIUS   S_6               CN=C(N)NCCCC(C(=O)OC)N    S_6  NaN      NaN
# 6     SIRIUS   S_7               CN=C(N)NCCCCC(C(=O)O)N    S_7  NaN      NaN
# 7     SIRIUS   S_8               CCOC(=O)C(CCCN=C(N)N)N    S_8  NaN      NaN
# 8     SIRIUS   S_9               CN(C)NC=NCCCC(C(=O)O)N    S_9  NaN      NaN
# 9     SIRIUS  S_10             CN(C)C(CCCN=C(N)N)C(=O)O   S_10  NaN      NaN
# 10    SIRIUS  S_11             CN(C)C(=NC(CCCN)C(=O)O)N   S_11  NaN      NaN
# 11    SIRIUS  S_12             C(CCC(C(=O)O)N)CCN=C(N)N   S_12  NaN      NaN
# 12    SIRIUS  S_13               CNC(CCCNC(=NC)N)C(=O)O   S_13  NaN      NaN
# 13    SIRIUS  S_14          CN(C)N[N+](=C)CCCC(C(=O)O)N   S_14  NaN      NaN
# 14    SIRIUS  S_15               CNCC(=NCCCC(C(=O)O)N)N   S_15  NaN      NaN
# 15    SIRIUS  S_16               CCCN=C(N)NCCC(C(=O)O)N   S_16  NaN      NaN
# 16    SIRIUS  S_17             CCC(CCC(C(=O)O)N)N=C(N)N   S_17  NaN      NaN
# 17    SIRIUS  S_18             CC(CCCC(C(=O)O)N)N=C(N)N   S_18  NaN      NaN
# 18    SIRIUS  S_19             CC(CC(C(=O)O)N)CNC(=NC)N   S_19  NaN      NaN
# 19    SIRIUS  S_20             CN(CCCC(C(=O)OC)N)C(=N)N   S_20  NaN      NaN
# 20    SIRIUS  S_21             CC(C)NC(=NCCC(C(=O)O)N)N   S_21  NaN      NaN
# 21    SIRIUS  S_22           CC(C)(CCC(C(=O)O)N)N=C(N)N   S_22  NaN      NaN
# 22    SIRIUS  S_23             CC(CCNC(=NC)N)C(C(=O)O)N   S_23  NaN      NaN
# 23    SIRIUS  S_24                 CCNNC=NCCCC(C(=O)O)N   S_24  NaN      NaN
# 24    SIRIUS  S_25             CN(CCCCC(C(=O)O)N)C(=N)N   S_25  NaN      NaN
# 25    SIRIUS  S_26               COC(=O)C(CCCCN=C(N)N)N   S_26  NaN      NaN
# 26    SIRIUS  S_27             CC(CCCNC(=NC)N)(C(=O)O)N   S_27  NaN      NaN
# 27    SIRIUS  S_28               CNC(CCCN=C(N)N)C(=O)OC   S_28  NaN      NaN
# 28    SIRIUS  S_29             CCC(CC(C(=O)O)N)CN=C(N)N   S_29  NaN      NaN
# 29    SIRIUS  S_30           CC(C)(CC(C(=O)O)N)CN=C(N)N   S_30  NaN      NaN
# 30    SIRIUS  S_31             CCN(CCCC(C(=O)O)N)C(=N)N   S_31  NaN      NaN
# 31    SIRIUS  S_32           C(CCC(C(=O)O)N)CC(C(=N)N)N   S_32  NaN      NaN
# 32    SIRIUS  S_33             CN(C)C(=NCCC(C(=O)OC)N)N   S_33  NaN      NaN
# 33    SIRIUS  S_34                 CCCNC(=O)NNC(=O)NCCC   S_34  NaN      NaN
# 34    SIRIUS  S_35               CCNC(CCCN=C(N)N)C(=O)O   S_35  NaN      NaN
# 35    SIRIUS  S_36             CN(C)C(=NCCC(CC(=O)O)N)N   S_36  NaN      NaN
# 36    SIRIUS  S_37             CNC(CCCN(C)C(=N)N)C(=O)O   S_37  NaN      NaN
# 37    SIRIUS  S_38           CC(CC(C(=O)O)N)CN(C)C(=N)N   S_38  NaN      NaN
# 38      GNPS   G_1             CN(C)C(=NCCCC(C(=O)O)N)N    S_1  G_1      NaN
# 39  MassBank   M_1  CNC(=NC)NCCC[C@@H](C(=O)[O-])[NH3+]    NaN  NaN      M_1
#
#     HMDB  Count
# 0    NaN    2.0
# 1    NaN    1.0
# 2    NaN    1.0
# 3    NaN    1.0
# 4    NaN    1.0
# 5    NaN    1.0
# 6    NaN    1.0
# 7    NaN    1.0
# 8    NaN    1.0
# 9    NaN    1.0
# 10   NaN    1.0
# 11   NaN    1.0
# 12   NaN    1.0
# 13   NaN    1.0
# 14   NaN    1.0
# 15   NaN    1.0
# 16   NaN    1.0
# 17   NaN    1.0
# 18   NaN    1.0
# 19   NaN    1.0
# 20   NaN    1.0
# 21   NaN    1.0
# 22   NaN    1.0
# 23   NaN    1.0
# 24   NaN    1.0
# 25   NaN    1.0
# 26   NaN    1.0
# 27   NaN    1.0
# 28   NaN    1.0
# 29   NaN    1.0
# 30   NaN    1.0
# 31   NaN    1.0
# 32   NaN    1.0
# 33   NaN    1.0
# 34   NaN    1.0
# 35   NaN    1.0
# 36   NaN    1.0
# 37   NaN    1.0
# 38   NaN    2.0
# 39   NaN    1.0
#    Source ranks                                  SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1         CCCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  NaN       NaN
# 1  SIRIUS   S_2       CC(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3         CCC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_3  NaN       NaN
# 3    GNPS   G_1  CCCC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C    NaN  G_1       NaN
#
#    HMDB  Count
# 0   NaN    1.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
#    Source ranks                              SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1      CCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  G_1       NaN
# 1  SIRIUS   S_2      CC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3           CCCC(=O)OC(CC(=O)O)CN(C)C    S_3  NaN       NaN
# 3  SIRIUS   S_4      CC(=O)COC(CC(=O)O)C[N+](C)(C)C    S_4  NaN       NaN
# 4  SIRIUS   S_5    CC(=O)OC(C)(CC(=O)O)C[N+](C)(C)C    S_5  NaN       NaN
# 5  SIRIUS   S_6      CC[N+](C)(C)CC(CC(=O)O)OC(=O)C    S_6  NaN       NaN
# 6    GNPS   G_1  CCC(=O)O[C@H](CC(O)=O)C[N+](C)(C)C    S_1  G_1       NaN
# 7    GNPS   G_2   CCC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN  G_2       NaN
#
#    HMDB  Count
# 0   NaN    2.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
# 4   NaN    1.0
# 5   NaN    1.0
# 6   NaN    2.0
# 7   NaN    1.0
#     Source ranks                   SMILES SIRIUS GNPS  MassBank  HMDB  Count
# 0   SIRIUS   S_1       C[N+](C)(C)CC(=O)O    S_1  G_1       NaN   NaN    2.0
# 1   SIRIUS   S_2  C[N+](C)([CH2-])CC(=O)O    S_2  NaN       NaN   NaN    1.0
# 2   SIRIUS   S_3            CN(C)CCC(=O)O    S_3  NaN       NaN   NaN    1.0
# 3   SIRIUS   S_4            CCN(C)CC(=O)O    S_4  NaN       NaN   NaN    1.0
# 4   SIRIUS   S_5            CN(C)CC(=O)OC    S_5  NaN       NaN   NaN    1.0
# 5   SIRIUS   S_6       CC(=O)O[N+](C)(C)C    S_6  NaN       NaN   NaN    1.0
# 6   SIRIUS   S_7              CCNCCC(=O)O    S_7  NaN       NaN   NaN    1.0
# 7   SIRIUS   S_8            CC(C)NCC(=O)O    S_8  NaN       NaN   NaN    1.0
# 8   SIRIUS   S_9            COC(CN[CH])OC    S_9  NaN       NaN   NaN    1.0
# 9   SIRIUS  S_10              CNCCCC(=O)O   S_10  NaN       NaN   NaN    1.0
# 10  SIRIUS  S_11            CC(CC(=O)O)NC   S_11  NaN       NaN   NaN    1.0
# 11  SIRIUS  S_12          CC(C(=O)O)N(C)C   S_12  NaN       NaN   NaN    1.0
# 12  SIRIUS  S_13         C[N+](C)(CC=C)OO   S_13  NaN       NaN   NaN    1.0
# 13  SIRIUS  S_14                COCCNCC=O   S_14  NaN       NaN   NaN    1.0
# 14  SIRIUS  S_15              CCCNCC(=O)O   S_15  NaN       NaN   NaN    1.0
# 15  SIRIUS  S_16          CC(C)(CN)C(=O)O   S_16  NaN       NaN   NaN    1.0
# 16  SIRIUS  S_17            CC(CC(=O)O)CN   S_17  NaN       NaN   NaN    1.0
# 17  SIRIUS  S_18            CCN(C)OC(=O)C   S_18  NaN       NaN   NaN    1.0
# 18  SIRIUS  S_19            CC(CNC)C(=O)O   S_19  NaN       NaN   NaN    1.0
# 19    GNPS   G_1       C[N+](C)(C)CC(=O)O    S_1  G_1       NaN   NaN    2.0
# 20    GNPS   G_2    C[N+](C)(C)CC(=O)[O-]    NaN  G_2       NaN   NaN    1.0
#    Source ranks                                SMILES SIRIUS      GNPS  \
# 0  SIRIUS   S_1         CC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1       NaN
# 1  SIRIUS   S_2              CCC(=O)OC(CC(=O)O)CN(C)C    S_2       NaN
# 2  SIRIUS   S_3              CC(=O)OC(CC(=O)OC)CN(C)C    S_3       NaN
# 3  SIRIUS   S_4         CC(=O)OC(C[N+](C)(C)C)OC(=O)C    S_4       NaN
# 4  SIRIUS   S_5         CC(=O)OC(=O)CC(C[N+](C)(C)C)O    S_5       NaN
# 5    GNPS   G_1  CC(=O)O[C@H](CC(=O)[O-])C[N+](C)(C)C    NaN  G_1, G_2
# 6    GNPS   G_2      CC(=O)OC(CC([O-])=O)C[N+](C)(C)C    NaN  G_1, G_2
#
#    MassBank  HMDB  Count
# 0       NaN   NaN    1.0
# 1       NaN   NaN    1.0
# 2       NaN   NaN    1.0
# 3       NaN   NaN    1.0
# 4       NaN   NaN    1.0
# 5       NaN   NaN    2.0
# 6       NaN   NaN    2.0
#       Source ranks                               SMILES SIRIUS GNPS MassBank  \
# 0     SIRIUS   S_1             CN(C)C(=NCCCC(C(=O)O)N)N    S_1  G_1      M_2
# 1     SIRIUS   S_2               CNC(=NC)NCCCC(C(=O)O)N    S_2  NaN      NaN
# 2     SIRIUS   S_3               CCNC(=NCCCC(C(=O)O)N)N    S_3  NaN      NaN
# 3     SIRIUS   S_4             CN=C(N)N(C)CCCC(C(=O)O)N    S_4  NaN      NaN
# 4     SIRIUS   S_5          C[N+](=C(N)NCCCC(C(=O)O)N)C    S_5  NaN      NaN
# 5     SIRIUS   S_6               CN=C(N)NCCCC(C(=O)OC)N    S_6  NaN      NaN
# 6     SIRIUS   S_7               CNC(CCCNC(=NC)N)C(=O)O    S_7  NaN      NaN
# 7     SIRIUS   S_8               CN=C(N)NCCCCC(C(=O)O)N    S_8  NaN      NaN
# 8     SIRIUS   S_9               CN(C)NC=NCCCC(C(=O)O)N    S_9  NaN      NaN
# 9     SIRIUS  S_10             CN(C)C(=NC(CCCN)C(=O)O)N   S_10  NaN      NaN
# 10    SIRIUS  S_11             CN(C)C(CCCN=C(N)N)C(=O)O   S_11  NaN      NaN
# 11    SIRIUS  S_12               CCOC(=O)C(CCCN=C(N)N)N   S_12  NaN      NaN
# 12    SIRIUS  S_13             C(CCC(C(=O)O)N)CCN=C(N)N   S_13  NaN      NaN
# 13    SIRIUS  S_14             CC(CCCC(C(=O)O)N)N=C(N)N   S_14  NaN      NaN
# 14    SIRIUS  S_15          CN(C)N[N+](=C)CCCC(C(=O)O)N   S_15  NaN      NaN
# 15    SIRIUS  S_16               CNC(CCCN=C(N)N)C(=O)OC   S_16  NaN      NaN
# 16    SIRIUS  S_17             CC(CC(C(=O)O)N)CNC(=NC)N   S_17  NaN      NaN
# 17    SIRIUS  S_18             CC(CCCNC(=NC)N)(C(=O)O)N   S_18  NaN      NaN
# 18    SIRIUS  S_19             CN(CCCC(C(=O)OC)N)C(=N)N   S_19  NaN      NaN
# 19    SIRIUS  S_20               CNCC(=NCCCC(C(=O)O)N)N   S_20  NaN      NaN
# 20    SIRIUS  S_21             CNC(CCCN(C)C(=N)N)C(=O)O   S_21  NaN      NaN
# 21    SIRIUS  S_22                 CCNNC=NCCCC(C(=O)O)N   S_22  NaN      NaN
# 22    SIRIUS  S_23             CCC(CCC(C(=O)O)N)N=C(N)N   S_23  NaN      NaN
# 23    SIRIUS  S_24             CC(CCNC(=NC)N)C(C(=O)O)N   S_24  NaN      NaN
# 24    SIRIUS  S_25             CN(CCCCC(C(=O)O)N)C(=N)N   S_25  NaN      NaN
# 25    SIRIUS  S_26               CCCN=C(N)NCCC(C(=O)O)N   S_26  NaN      NaN
# 26    SIRIUS  S_27               CNC(CCCCN=C(N)N)C(=O)O   S_27  NaN      NaN
# 27    SIRIUS  S_28               COC(=O)C(CCCCN=C(N)N)N   S_28  NaN      NaN
# 28    SIRIUS  S_29             CCN(CCCC(C(=O)O)N)C(=N)N   S_29  NaN      NaN
# 29    SIRIUS  S_30           CC(C)(CCC(C(=O)O)N)N=C(N)N   S_30  NaN      NaN
# 30    SIRIUS  S_31               CCNC(CCCN=C(N)N)C(=O)O   S_31  NaN      NaN
# 31    SIRIUS  S_32               CN(C)NC=NC(CCCN)C(=O)O   S_32  NaN      NaN
# 32    SIRIUS  S_33           C(CCC(C(=O)O)N)CC(C(=N)N)N   S_33  NaN      NaN
# 33    SIRIUS  S_34             CC(C)NC(=NCCC(C(=O)O)N)N   S_34  NaN      NaN
# 34    SIRIUS  S_35             CC(CCCN=C(N)N)(C(=O)O)NC   S_35  NaN      NaN
# 35    SIRIUS  S_36             CCC(CC(C(=O)O)N)CN=C(N)N   S_36  NaN      NaN
# 36    SIRIUS  S_37           CC(CC(C(=O)O)N)CN(C)C(=N)N   S_37  NaN      NaN
# 37    SIRIUS  S_38           CC(C)(CC(C(=O)O)N)CN=C(N)N   S_38  NaN      NaN
# 38    SIRIUS  S_39             CN(C)C(=NCCC(CC(=O)O)N)N   S_39  NaN      NaN
# 39    SIRIUS  S_40             CC(CCC(C(=O)OC)N)N=C(N)N   S_40  NaN      NaN
# 40      GNPS   G_1             CN(C)C(=NCCCC(C(=O)O)N)N    S_1  G_1      M_2
# 41  MassBank   M_1  CNC(=NC)NCCC[C@@H](C(=O)[O-])[NH3+]    NaN  NaN      M_1
# 42  MassBank   M_2        CN(C)C(=NCCC[C@@H](C(=O)O)N)N    S_1  G_1      M_2
#
#     HMDB  Count
# 0    NaN    3.0
# 1    NaN    1.0
# 2    NaN    1.0
# 3    NaN    1.0
# 4    NaN    1.0
# 5    NaN    1.0
# 6    NaN    1.0
# 7    NaN    1.0
# 8    NaN    1.0
# 9    NaN    1.0
# 10   NaN    1.0
# 11   NaN    1.0
# 12   NaN    1.0
# 13   NaN    1.0
# 14   NaN    1.0
# 15   NaN    1.0
# 16   NaN    1.0
# 17   NaN    1.0
# 18   NaN    1.0
# 19   NaN    1.0
# 20   NaN    1.0
# 21   NaN    1.0
# 22   NaN    1.0
# 23   NaN    1.0
# 24   NaN    1.0
# 25   NaN    1.0
# 26   NaN    1.0
# 27   NaN    1.0
# 28   NaN    1.0
# 29   NaN    1.0
# 30   NaN    1.0
# 31   NaN    1.0
# 32   NaN    1.0
# 33   NaN    1.0
# 34   NaN    1.0
# 35   NaN    1.0
# 36   NaN    1.0
# 37   NaN    1.0
# 38   NaN    1.0
# 39   NaN    1.0
# 40   NaN    3.0
# 41   NaN    1.0
# 42   NaN    3.0
#    Source ranks                                 SMILES SIRIUS      GNPS  \
# 0  SIRIUS   S_1     CC(C)CC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1       NaN
# 1  SIRIUS   S_2     CCC(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_2       NaN
# 2  SIRIUS   S_3       CCCCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_3       NaN
# 3  SIRIUS   S_4     CC(C)OC(=O)CC(C[N+](C)(C)C)OC(=O)C    S_4       NaN
# 4  SIRIUS   S_5   CC(C)(C)C(=O)OC(CC(=O)O)C[N+](C)(C)C    S_5       NaN
# 5  SIRIUS   S_6       CCCC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_6       NaN
# 6    GNPS   G_1    CCCCC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN       G_1
# 7    GNPS   G_2  CC(C)CC(=O)OC(CC([O-])=O)C[N+](C)(C)C    NaN  G_2, G_3
# 8    GNPS   G_3  CC(C)CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN  G_2, G_3
#
#    MassBank  HMDB  Count
# 0       NaN   NaN    1.0
# 1       NaN   NaN    1.0
# 2       NaN   NaN    1.0
# 3       NaN   NaN    1.0
# 4       NaN   NaN    1.0
# 5       NaN   NaN    1.0
# 6       NaN   NaN    1.0
# 7       NaN   NaN    2.0
# 8       NaN   NaN    2.0
#    Source ranks                              SMILES SIRIUS GNPS  MassBank  \
# 0  SIRIUS   S_1      CCC(=O)OC(CC(=O)O)C[N+](C)(C)C    S_1  G_1       NaN
# 1  SIRIUS   S_2      CC(=O)OC(CC(=O)OC)C[N+](C)(C)C    S_2  NaN       NaN
# 2  SIRIUS   S_3           CCCC(=O)OC(CC(=O)O)CN(C)C    S_3  NaN       NaN
# 3  SIRIUS   S_4      CC(=O)COC(CC(=O)O)C[N+](C)(C)C    S_4  NaN       NaN
# 4  SIRIUS   S_5      CC[N+](C)(C)CC(CC(=O)O)OC(=O)C    S_5  NaN       NaN
# 5  SIRIUS   S_6    CC(=O)OC(C)(CC(=O)O)C[N+](C)(C)C    S_6  NaN       NaN
# 6    GNPS   G_1  CCC(=O)O[C@H](CC(O)=O)C[N+](C)(C)C    S_1  G_1       NaN
# 7    GNPS   G_2   CCC(=O)OC(CC(=O)[O-])C[N+](C)(C)C    NaN  G_2       NaN
#
#    HMDB  Count
# 0   NaN    2.0
# 1   NaN    1.0
# 2   NaN    1.0
# 3   NaN    1.0
# 4   NaN    1.0
# 5   NaN    1.0
# 6   NaN    2.0
# 7   NaN    1.0
#       Source ranks                                             SMILES SIRIUS  \
# 0     SIRIUS   S_1                                C(C(CS(=O)(=O)O)N)O    S_1
# 1     SIRIUS   S_2                                C(C(CS(=O)(=O)O)O)N    S_2
# 2     SIRIUS   S_3                                C(CS(=O)(=O)O)C(N)O    S_3
# 3     SIRIUS   S_4                                  C(CNO)CS(=O)(=O)O    S_4
# 4     SIRIUS   S_5                                C(CO)C(N)S(=O)(=O)O    S_5
# 5     SIRIUS   S_6                                C(C(CO)S(=O)(=O)O)N    S_6
# 6     SIRIUS   S_7                                C(CN)C(O)S(=O)(=O)O    S_7
# 7     SIRIUS   S_8                                  C(CO)NCS(=O)(=O)O    S_8
# 8     SIRIUS   S_9                                  C(CS(=O)(=O)O)NCO    S_9
# 9     SIRIUS  S_10                                  C(CN)COS(=O)(=O)O   S_10
# 10    SIRIUS  S_11                                  C(CNS(=O)(=O)O)CO   S_11
# 11    SIRIUS  S_12                                  C(CON)CS(=O)(=O)O   S_12
# 12    SIRIUS  S_13                                  CC(CNS(=O)(=O)O)O   S_13
# 13    SIRIUS  S_14                                  COC(CS(=O)(=O)O)N   S_14
# 14    SIRIUS  S_15                                CC(C(O)S(=O)(=O)O)N   S_15
# 15    SIRIUS  S_16                                CC(C(N)S(=O)(=O)O)O   S_16
# 16    SIRIUS  S_17                                  CNCC(O)S(=O)(=O)O   S_17
# 17    SIRIUS  S_18                                   C(C(CO)O)NS(=O)O   S_18
# 18    SIRIUS  S_19                                  C(COCS(=O)(=O)O)N   S_19
# 19    SIRIUS  S_20                                    CONCCS(=O)(=O)O   S_20
# 20    SIRIUS  S_21                                  C(CS(=O)(=O)O)OCN   S_21
# 21    SIRIUS  S_22                                  CC(COS(=O)(=O)O)N   S_22
# 22    SIRIUS  S_23                                CC(CO)(N)S(=O)(=O)O   S_23
# 23    SIRIUS  S_24                                  COCC(N)S(=O)(=O)O   S_24
# 24    SIRIUS  S_25                                  CC(CN)OS(=O)(=O)O   S_25
# 25    SIRIUS  S_26                                  CCC(N)OS(=O)(=O)O   S_26
# 26    SIRIUS  S_27                                   C(CN)C(OO)S(=O)O   S_27
# 27    SIRIUS  S_28                                  C(CS(=O)(=O)OCO)N   S_28
# 28    SIRIUS  S_29                                C(CS(=O)(=O)N)C(O)O   S_29
# 29    SIRIUS  S_30                                  CN(CCS(=O)(=O)O)O   S_30
# 30    SIRIUS  S_31                                C(C(CO)S(=O)(=O)N)O   S_31
# 31    SIRIUS  S_32                                    CCNCOS(=O)(=O)O   S_32
# 32    SIRIUS  S_33                                C(C(CS(=O)(=O)N)O)O   S_33
# 33    SIRIUS  S_34                                    CNCCOS(=O)(=O)O   S_34
# 34    SIRIUS  S_35                                  C(COS(=O)(=O)CN)O   S_35
# 35    SIRIUS  S_36                                    COCCNS(=O)(=O)O   S_36
# 36    SIRIUS  S_37                                  CN(CO)CS(=O)(=O)O   S_37
# 37      GNPS   G_1  COCCOC(=O)c1c(C)n(CCOc2cccc(Cl)c2Cl)c2c1cc(O)c...    NaN
# 38      GNPS   G_2                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 39      GNPS   G_3                                ClC1=CC2=NNN=C2C=C1    NaN
# 40  MassBank   M_1                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 41  MassBank   M_2                                C1=CC2=NNN=C2C=C1Cl    NaN
#
#    GNPS MassBank  HMDB  Count
# 0   NaN      NaN   NaN    1.0
# 1   NaN      NaN   NaN    1.0
# 2   NaN      NaN   NaN    1.0
# 3   NaN      NaN   NaN    1.0
# 4   NaN      NaN   NaN    1.0
# 5   NaN      NaN   NaN    1.0
# 6   NaN      NaN   NaN    1.0
# 7   NaN      NaN   NaN    1.0
# 8   NaN      NaN   NaN    1.0
# 9   NaN      NaN   NaN    1.0
# 10  NaN      NaN   NaN    1.0
# 11  NaN      NaN   NaN    1.0
# 12  NaN      NaN   NaN    1.0
# 13  NaN      NaN   NaN    1.0
# 14  NaN      NaN   NaN    1.0
# 15  NaN      NaN   NaN    1.0
# 16  NaN      NaN   NaN    1.0
# 17  NaN      NaN   NaN    1.0
# 18  NaN      NaN   NaN    1.0
# 19  NaN      NaN   NaN    1.0
# 20  NaN      NaN   NaN    1.0
# 21  NaN      NaN   NaN    1.0
# 22  NaN      NaN   NaN    1.0
# 23  NaN      NaN   NaN    1.0
# 24  NaN      NaN   NaN    1.0
# 25  NaN      NaN   NaN    1.0
# 26  NaN      NaN   NaN    1.0
# 27  NaN      NaN   NaN    1.0
# 28  NaN      NaN   NaN    1.0
# 29  NaN      NaN   NaN    1.0
# 30  NaN      NaN   NaN    1.0
# 31  NaN      NaN   NaN    1.0
# 32  NaN      NaN   NaN    1.0
# 33  NaN      NaN   NaN    1.0
# 34  NaN      NaN   NaN    1.0
# 35  NaN      NaN   NaN    1.0
# 36  NaN      NaN   NaN    1.0
# 37  G_1      NaN   NaN    1.0
# 38  G_2      M_1   NaN    2.0
# 39  G_3      M_2   NaN    2.0
# 40  G_2      M_1   NaN    2.0
# 41  G_3      M_2   NaN    2.0

# %%
one_candidate_selection(sm, Source = "SGM")
# Out:
#       Source ranks                                             SMILES SIRIUS  \
# 0     SIRIUS   S_1                                C(C(CS(=O)(=O)O)N)O    S_1
# 1     SIRIUS   S_2                                C(C(CS(=O)(=O)O)O)N    S_2
# 2     SIRIUS   S_3                                C(CS(=O)(=O)O)C(N)O    S_3
# 3     SIRIUS   S_4                                  C(CNO)CS(=O)(=O)O    S_4
# 4     SIRIUS   S_5                                C(CO)C(N)S(=O)(=O)O    S_5
# 5     SIRIUS   S_6                                C(C(CO)S(=O)(=O)O)N    S_6
# 6     SIRIUS   S_7                                C(CN)C(O)S(=O)(=O)O    S_7
# 7     SIRIUS   S_8                                  C(CO)NCS(=O)(=O)O    S_8
# 8     SIRIUS   S_9                                  C(CS(=O)(=O)O)NCO    S_9
# 9     SIRIUS  S_10                                  C(CN)COS(=O)(=O)O   S_10
# 10    SIRIUS  S_11                                  C(CNS(=O)(=O)O)CO   S_11
# 11    SIRIUS  S_12                                  C(CON)CS(=O)(=O)O   S_12
# 12    SIRIUS  S_13                                  CC(CNS(=O)(=O)O)O   S_13
# 13    SIRIUS  S_14                                  COC(CS(=O)(=O)O)N   S_14
# 14    SIRIUS  S_15                                CC(C(O)S(=O)(=O)O)N   S_15
# 15    SIRIUS  S_16                                CC(C(N)S(=O)(=O)O)O   S_16
# 16    SIRIUS  S_17                                  CNCC(O)S(=O)(=O)O   S_17
# 17    SIRIUS  S_18                                   C(C(CO)O)NS(=O)O   S_18
# 18    SIRIUS  S_19                                  C(COCS(=O)(=O)O)N   S_19
# 19    SIRIUS  S_20                                    CONCCS(=O)(=O)O   S_20
# 20    SIRIUS  S_21                                  C(CS(=O)(=O)O)OCN   S_21
# 21    SIRIUS  S_22                                  CC(COS(=O)(=O)O)N   S_22
# 22    SIRIUS  S_23                                CC(CO)(N)S(=O)(=O)O   S_23
# 23    SIRIUS  S_24                                  COCC(N)S(=O)(=O)O   S_24
# 24    SIRIUS  S_25                                  CC(CN)OS(=O)(=O)O   S_25
# 25    SIRIUS  S_26                                  CCC(N)OS(=O)(=O)O   S_26
# 26    SIRIUS  S_27                                   C(CN)C(OO)S(=O)O   S_27
# 27    SIRIUS  S_28                                  C(CS(=O)(=O)OCO)N   S_28
# 28    SIRIUS  S_29                                C(CS(=O)(=O)N)C(O)O   S_29
# 29    SIRIUS  S_30                                  CN(CCS(=O)(=O)O)O   S_30
# 30    SIRIUS  S_31                                C(C(CO)S(=O)(=O)N)O   S_31
# 31    SIRIUS  S_32                                    CCNCOS(=O)(=O)O   S_32
# 32    SIRIUS  S_33                                C(C(CS(=O)(=O)N)O)O   S_33
# 33    SIRIUS  S_34                                    CNCCOS(=O)(=O)O   S_34
# 34    SIRIUS  S_35                                  C(COS(=O)(=O)CN)O   S_35
# 35    SIRIUS  S_36                                    COCCNS(=O)(=O)O   S_36
# 36    SIRIUS  S_37                                  CN(CO)CS(=O)(=O)O   S_37
# 37      GNPS   G_1  COCCOC(=O)c1c(C)n(CCOc2cccc(Cl)c2Cl)c2c1cc(O)c...    NaN
# 38      GNPS   G_2                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 39      GNPS   G_3                                ClC1=CC2=NNN=C2C=C1    NaN
# 40  MassBank   M_1                              C1=CC=C2C(=C1)N=NN2Cl    NaN
# 41  MassBank   M_2                                C1=CC2=NNN=C2C=C1Cl    NaN
#
#    GNPS MassBank  HMDB  Count
# 0   NaN      NaN   NaN    1.0
# 1   NaN      NaN   NaN    1.0
# 2   NaN      NaN   NaN    1.0
# 3   NaN      NaN   NaN    1.0
# 4   NaN      NaN   NaN    1.0
# 5   NaN      NaN   NaN    1.0
# 6   NaN      NaN   NaN    1.0
# 7   NaN      NaN   NaN    1.0
# 8   NaN      NaN   NaN    1.0
# 9   NaN      NaN   NaN    1.0
# 10  NaN      NaN   NaN    1.0
# 11  NaN      NaN   NaN    1.0
# 12  NaN      NaN   NaN    1.0
# 13  NaN      NaN   NaN    1.0
# 14  NaN      NaN   NaN    1.0
# 15  NaN      NaN   NaN    1.0
# 16  NaN      NaN   NaN    1.0
# 17  NaN      NaN   NaN    1.0
# 18  NaN      NaN   NaN    1.0
# 19  NaN      NaN   NaN    1.0
# 20  NaN      NaN   NaN    1.0
# 21  NaN      NaN   NaN    1.0
# 22  NaN      NaN   NaN    1.0
# 23  NaN      NaN   NaN    1.0
# 24  NaN      NaN   NaN    1.0
# 25  NaN      NaN   NaN    1.0
# 26  NaN      NaN   NaN    1.0
# 27  NaN      NaN   NaN    1.0
# 28  NaN      NaN   NaN    1.0
# 29  NaN      NaN   NaN    1.0
# 30  NaN      NaN   NaN    1.0
# 31  NaN      NaN   NaN    1.0
# 32  NaN      NaN   NaN    1.0
# 33  NaN      NaN   NaN    1.0
# 34  NaN      NaN   NaN    1.0
# 35  NaN      NaN   NaN    1.0
# 36  NaN      NaN   NaN    1.0
# 37  G_1      NaN   NaN    1.0
# 38  G_2      M_1   NaN    2.0
# 39  G_3      M_2   NaN    2.0
# 40  G_2      M_1   NaN    2.0
# 41  G_3      M_2   NaN    2.0

# %%
def one_candidate_selection(df, Source = "SGHM"):
    df["SIRIUS"] = np.nan
    df["GNPS"] = np.nan
    df["MassBank"] = np.nan
    df["HMDB"] = np.nan
    df["Count"] = np.nan

    for smiles, rows in df.iterrows():

        if Source == "SGHM" or Source == "SGM" or Source == "SGH" or Source == "SHM" or Source == "SG" or Source == "SM" or Source == "SH":
            for sirius_i, row in sirius_df.iterrows():
                try:
                    ms = [Chem.MolFromSmiles(df["SMILES"][smiles]), Chem.MolFromSmiles(sirius_df["smiles"][sirius_i])]
                    fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in ms]
                    tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])
                    if tn >= 0.99:
                        if isNaN(df["SIRIUS"][smiles]):

                            df.loc[smiles, "SIRIUS"] = sirius_df["rank_ids"][sirius_i]

                        else:
                            df.loc[smiles, "SIRIUS"] = str(df["SIRIUS"][smiles]) + ", "+ sirius_df["rank_ids"][sirius_i]
                            
                        if isNaN(df["Count"][smiles]):
                            df.loc[smiles, "Count"] = 1
                        else:
                            df.loc[smiles, "Count"] = df["Count"][smiles] + 1
                except:
                    pass

        if Source == "SGHM" or Source == "SGM" or Source == "SGH" or Source == "GHM" or Source == "SG" or Source == "GM" or Source == "GH":


            for gnps_i, row in gnps_df.iterrows():
                try:
                    ms = [Chem.MolFromSmiles(df["SMILES"][smiles]), Chem.MolFromSmiles(gnps_df["GNPSSMILES"][gnps_i])]
                    fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in ms]
                    tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])

                    if tn >= 0.99:
                        if isNaN(df["GNPS"][smiles]):

                            df.loc[smiles, "GNPS"] = gnps_df["rank_ids"][gnps_i]

                        else:
                            df.loc[smiles, "GNPS"] = str(df["GNPS"][smiles]) + ", "+ gnps_df["rank_ids"][gnps_i]
                            
                            
                        if isNaN(df["Count"][smiles]):
                            df.loc[smiles, "Count"] = 1
                        else:
                            df.loc[smiles, "Count"] = df["Count"][smiles] + 1
                except:
                    pass


        if Source == "SGHM" or Source == "SGM" or Source == "SHM" or Source == "GHM" or Source == "SM" or Source == "GM" or Source == "HM":
            for mbank_i, row in mbank_df.iterrows():
                try:
                    ms = [Chem.MolFromSmiles(df["SMILES"][smiles]), Chem.MolFromSmiles(mbank_df["MBSMILES"][mbank_i])]
                    fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in ms]
                    tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])
                    if tn >= 0.99:
                        if isNaN(df["MassBank"][smiles]):

                            df.loc[smiles, "MassBank"] = mbank_df["rank_ids"][mbank_i]

                        else:
                            df.loc[smiles, "MassBank"] = str(df["MassBank"][smiles]) + ", "+ mbank_df["rank_ids"][mbank_i]
                            
                        if isNaN(df["Count"][smiles]):
                            df.loc[smiles, "Count"] = 1
                        else:
                            df.loc[smiles, "Count"] = df["Count"][smiles] + 1
                except:
                    pass



        if Source == "SGHM" or Source == "SGH" or Source == "SHM" or Source == "GHM" or Source == "SH" or Source == "GH" or Source == "HM":


            for hmdb_i, row in hmdb_df.iterrows():
                try:
                    ms = [Chem.MolFromSmiles(df["SMILES"][smiles]), Chem.MolFromSmiles(hmdb_df["HMDBSMILES"][hmdb_i])]
                    fps = [AllChem.GetMorganFingerprintAsBitVect(x,2, nBits=2048) for x in ms]
                    tn = DataStructs.FingerprintSimilarity(fps[0],fps[1])
                    if tn >= 0.99:
                        if isNaN(df["HMDB"][smiles]):

                            df.loc[smiles, "HMDB"] = hmdb_df["rank_ids"][hmdb_i]

                        else:
                            df.loc[smiles, "HMDB"] = str(df["HMDB"][smiles]) + ", "+ hmdb_df["rank_ids"][hmdb_i]
                            
                        if isNaN(df["Count"][smiles]):
                            df.loc[smiles, "Count"] = 1
                        else:
                            df.loc[smiles, "Count"] = df["Count"][smiles] + 1
                except:
                    pass
 
    return(df)

# %%
#1 SGHM
#2 SGM
#3 SHM
#4 SGH
#5 GHM
#6 SG
#7 SH
#8 SM
#9 GM
#10 GH
#11 HM

# %%
one_can = pd.read_csv("/Users/mahnoorzulfiqar/OneDriveUNI/MAW-data/StandardSMarinoi_Data/VN_211016_acetyl_carnitine/204.122756958008_one_candidate_list.tsv", sep = "\t")

# %%
del one_can["Count"]

# %%
df =one_can

# %%
df[df.eq(df["SIRIUS"], axis=0)]
# Out:
#    Unnamed: 0 Source ranks SMILES SIRIUS GNPS MassBank  HMDB
# 0         NaN    NaN   S_1    NaN    S_1  NaN      NaN   NaN
# 1         NaN    NaN   S_2    NaN    S_2  NaN      NaN   NaN
# 2         NaN    NaN   S_3    NaN    S_3  NaN      NaN   NaN
# 3         NaN    NaN   S_4    NaN    S_4  NaN      NaN   NaN
# 4         NaN    NaN   S_5    NaN    S_5  NaN      NaN   NaN
# 5         NaN    NaN   NaN    NaN    NaN  NaN      NaN   NaN
# 6         NaN    NaN   NaN    NaN    NaN  NaN      NaN   NaN
# 7         NaN    NaN   NaN    NaN    S_1  NaN      NaN   NaN
# 8         NaN    NaN   NaN    NaN    NaN  NaN      NaN   NaN
# 9         NaN    NaN   NaN    NaN    NaN  NaN      NaN   NaN
